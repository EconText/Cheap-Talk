# %% [markdown]
# # Topic Model Visualization

# %% [markdown]
# Uses tmplot topic modeling visualization library to visualize topic models generated by `biterm_topic_modeling.py`.

# %%
NUM_TOPICS = 50
MODEL_FOLDER = f"{NUM_TOPICS}_topics_model"

# %%
import tmplot as tmp
import pandas as pd
import os
import pickle
import altair_saver

# %%
###############
# IMPORT DATA #
###############
# Read text from all S&P 500 tweets into a Python list.
data_folder = "../data/tweets/ten_years"
texts = []
for comp_csv in os.listdir(data_folder):
    print(f"Reading tweets from CSV: {comp_csv}")
    df = pd.read_csv(f"{data_folder}/{comp_csv}", lineterminator='\n')
    texts += df['text'].str.strip().tolist()
# Out:
# Reading tweets from CSV: pncbank_tweets.csv
# Reading tweets from CSV: teradyneinc_tweets.csv
# Reading tweets from CSV: bakerhughesco_tweets.csv
# Reading tweets from CSV: ceridian_tweets.csv
# Reading tweets from CSV: aiginsurance_tweets.csv
# Reading tweets from CSV: expediamedia_tweets.csv
# Reading tweets from CSV: costargroup_tweets.csv
# Reading tweets from CSV: cboe_tweets.csv
# Reading tweets from CSV: skyworksinc_tweets.csv
# Reading tweets from CSV: bathbodyworks_tweets.csv
# Reading tweets from CSV: raytheontech_tweets.csv
# Reading tweets from CSV: kelloggcompany_tweets.csv
# Reading tweets from CSV: truistnews_tweets.csv
# Reading tweets from CSV: royalcaribbean_tweets.csv
# Reading tweets from CSV: eastmanchemco_tweets.csv
# Reading tweets from CSV: dominos_tweets.csv
# Reading tweets from CSV: edwardslifesci_tweets.csv
# Reading tweets from CSV: labcorp_tweets.csv
# Reading tweets from CSV: allegionplc_tweets.csv
# Reading tweets from CSV: kraftheinzco_tweets.csv
# Reading tweets from CSV: evergypower_tweets.csv
# Reading tweets from CSV: fbhs_news_tweets.csv
# Reading tweets from CSV: ups_tweets.csv
# Reading tweets from CSV: fti_us_tweets.csv
# Reading tweets from CSV: guycarpenter_tweets.csv
# Reading tweets from CSV: synchrony_tweets.csv
# Reading tweets from CSV: steris_tweets.csv
# Reading tweets from CSV: netflix_tweets.csv
# Reading tweets from CSV: downewsroom_tweets.csv
# Reading tweets from CSV: agilent_tweets.csv
# Reading tweets from CSV: exocad_tweets.csv
# Reading tweets from CSV: bookingcom_tweets.csv
# Reading tweets from CSV: tinder_tweets.csv
# Reading tweets from CSV: vlasicstork_tweets.csv
# Reading tweets from CSV: chrobinson_tweets.csv
# Reading tweets from CSV: google_tweets.csv
# Reading tweets from CSV: intuitivesurg_tweets.csv
# Reading tweets from CSV: lamresearch_tweets.csv
# Reading tweets from CSV: extraspace_tweets.csv
# Reading tweets from CSV: keysight_tweets.csv
# Reading tweets from CSV: heycisco_tweets.csv
# Reading tweets from CSV: mhkgreenworks_tweets.csv
# Reading tweets from CSV: lyondellbasell_tweets.csv
# Reading tweets from CSV: fiserv_tweets.csv
# Reading tweets from CSV: admupdates_tweets.csv
# Reading tweets from CSV: twitter_tweets.csv
# Reading tweets from CSV: verizonfios_tweets.csv
# Reading tweets from CSV: centerpoint_tweets.csv
# Reading tweets from CSV: hiltonnewsroom_tweets.csv
# Reading tweets from CSV: stanleyblkdeckr_tweets.csv
# Reading tweets from CSV: intlpaperco_tweets.csv
# Reading tweets from CSV: gallagherglobal_tweets.csv
# Reading tweets from CSV: agoda_tweets.csv
# Reading tweets from CSV: catalentpharma_tweets.csv
# Reading tweets from CSV: pplcorp_tweets.csv
# Reading tweets from CSV: larsondoors_tweets.csv
# Reading tweets from CSV: priceline_tweets.csv
# Reading tweets from CSV: ironmountain_tweets.csv
# Reading tweets from CSV: altrianews_tweets.csv
# Reading tweets from CSV: factset_tweets.csv
# Reading tweets from CSV: bioradcellbio_tweets.csv
# Reading tweets from CSV: visa_tweets.csv
# Reading tweets from CSV: take2interactiv_tweets.csv
# Reading tweets from CSV: corninglifesci_tweets.csv
# Reading tweets from CSV: genuinepartsco_tweets.csv
# Reading tweets from CSV: cruisenorwegian_tweets.csv
# Reading tweets from CSV: kayak_tweets.csv
# Reading tweets from CSV: exelon_tweets.csv
# Reading tweets from CSV: healthy_choice_tweets.csv
# Reading tweets from CSV: conocophillips_tweets.csv
# Reading tweets from CSV: wynnlasvegas_tweets.csv
# Reading tweets from CSV: newell_brands_tweets.csv
# Reading tweets from CSV: bookingholdings_tweets.csv
# Reading tweets from CSV: moderna_tx_tweets.csv
# Reading tweets from CSV: weareoxy_tweets.csv
# Reading tweets from CSV: realreddiwip_tweets.csv
# Reading tweets from CSV: ametekinc_tweets.csv
# Reading tweets from CSV: nortonlifelock_tweets.csv
# Reading tweets from CSV: tmobile_tweets.csv
# Reading tweets from CSV: leidosinc_tweets.csv
# Reading tweets from CSV: drhorton_tweets.csv
# Reading tweets from CSV: masterlockus_tweets.csv
# Reading tweets from CSV: ice_markets_tweets.csv
# Reading tweets from CSV: martinmarietta_tweets.csv
# Reading tweets from CSV: marshmclennan_tweets.csv
# Reading tweets from CSV: habitburger_tweets.csv
# Reading tweets from CSV: att_tweets.csv
# Reading tweets from CSV: criverlabs_tweets.csv
# Reading tweets from CSV: turbotax_tweets.csv
# Reading tweets from CSV: enphase_tweets.csv
# Reading tweets from CSV: nielsen_tweets.csv
# Reading tweets from CSV: valeroenergy_tweets.csv
# Reading tweets from CSV: charternewsroom_tweets.csv
# Reading tweets from CSV: wastemanagement_tweets.csv
# Reading tweets from CSV: regencycenters_tweets.csv
# Reading tweets from CSV: thermofisher_tweets.csv
# Reading tweets from CSV: zebratechnology_tweets.csv
# Reading tweets from CSV: publicstorage_tweets.csv
# Reading tweets from CSV: packagingcorp_tweets.csv
# Reading tweets from CSV: usbank_tweets.csv
# Reading tweets from CSV: iqvia_global_tweets.csv
# Reading tweets from CSV: garmin_tweets.csv
# Reading tweets from CSV: unitedhealthgrp_tweets.csv
# Reading tweets from CSV: verisign_tweets.csv
# Reading tweets from CSV: bnymellon_tweets.csv
# Reading tweets from CSV: carmax_tweets.csv
# Reading tweets from CSV: ross_stores_tweets.csv
# Reading tweets from CSV: aristanetworks_tweets.csv
# Reading tweets from CSV: broadcom_tweets.csv
# Reading tweets from CSV: avalonbay_tweets.csv
# Reading tweets from CSV: synopsys_tweets.csv
# Reading tweets from CSV: spglobal_tweets.csv
# Reading tweets from CSV: travelocity_tweets.csv
# Reading tweets from CSV: vertexpharma_tweets.csv
# Reading tweets from CSV: homedepot_tweets.csv
# Reading tweets from CSV: mastercard_tweets.csv
# Reading tweets from CSV: askamex_tweets.csv
# Reading tweets from CSV: nscorp_tweets.csv
# Reading tweets from CSV: xylem_tweets.csv
# Reading tweets from CSV: moen_tweets.csv
# Reading tweets from CSV: mailchimp_tweets.csv
# Reading tweets from CSV: howmetaerospace_tweets.csv
# Reading tweets from CSV: whirlpoolcorp_tweets.csv
# Reading tweets from CSV: nordson_corp_tweets.csv
# Reading tweets from CSV: dccomics_tweets.csv
# Reading tweets from CSV: conagrabrands_tweets.csv
# Reading tweets from CSV: dexcom_tweets.csv
# Reading tweets from CSV: monolithicpower_tweets.csv
# Reading tweets from CSV: cbre_tweets.csv
# Reading tweets from CSV: southwestair_tweets.csv
# Reading tweets from CSV: humana_tweets.csv
# Reading tweets from CSV: kroger_tweets.csv
# Reading tweets from CSV: cisco_tweets.csv
# Reading tweets from CSV: citizensbank_tweets.csv
# Reading tweets from CSV: mcdonalds_tweets.csv
# Reading tweets from CSV: mosaiccompany_tweets.csv
# Reading tweets from CSV: viatrisinc_tweets.csv
# Reading tweets from CSV: shopsimon_tweets.csv
# Reading tweets from CSV: vulcan_concrete_tweets.csv
# Reading tweets from CSV: target_tweets.csv
# Reading tweets from CSV: paramountco_tweets.csv
# Reading tweets from CSV: crowncastle_tweets.csv
# Reading tweets from CSV: amphenol_tweets.csv
# Reading tweets from CSV: regeneron_tweets.csv
# Reading tweets from CSV: welltower_tweets.csv
# Reading tweets from CSV: fisglobal_tweets.csv
# Reading tweets from CSV: northerntrust_tweets.csv
# Reading tweets from CSV: merck_tweets.csv
# Reading tweets from CSV: expedia_tweets.csv
# Reading tweets from CSV: averydennison_tweets.csv
# Reading tweets from CSV: ameriprise_tweets.csv
# Reading tweets from CSV: onsemi_tweets.csv
# Reading tweets from CSV: pxdtweets_tweets.csv
# Reading tweets from CSV: akamai_tweets.csv
# Reading tweets from CSV: paychex_tweets.csv
# Reading tweets from CSV: kccorp_tweets.csv
# Reading tweets from CSV: chipotletweets_tweets.csv
# Reading tweets from CSV: costco_tweets.csv
# Reading tweets from CSV: keurigpepper_tweets.csv
# Reading tweets from CSV: principal_tweets.csv
# Reading tweets from CSV: broadridge_tweets.csv
# Reading tweets from CSV: healthcare_abc_tweets.csv
# Reading tweets from CSV: wabteccorp_tweets.csv
# Reading tweets from CSV: blizzard_ent_tweets.csv
# Reading tweets from CSV: marathonoil_tweets.csv
# Reading tweets from CSV: chevron_tweets.csv
# Reading tweets from CSV: txinstruments_tweets.csv
# Reading tweets from CSV: equifax_tweets.csv
# Reading tweets from CSV: cigna_tweets.csv
# Reading tweets from CSV: autodesk_tweets.csv
# Reading tweets from CSV: thehartford_tweets.csv
# Reading tweets from CSV: qualcomm_tweets.csv
# Reading tweets from CSV: americantowerus_tweets.csv
# Reading tweets from CSV: meta_tweets.csv
# Reading tweets from CSV: dukerealty_tweets.csv
# Reading tweets from CSV: ultabeauty_tweets.csv
# Reading tweets from CSV: atmosenergy_tweets.csv
# Reading tweets from CSV: okcupid_tweets.csv
# Reading tweets from CSV: esteelauder_tweets.csv
# Reading tweets from CSV: csx_tweets.csv
# Reading tweets from CSV: abbvie_tweets.csv
# Reading tweets from CSV: equinix_tweets.csv
# Reading tweets from CSV: dupont_news_tweets.csv
# Reading tweets from CSV: solaredgepv_tweets.csv
# Reading tweets from CSV: cvshealth_tweets.csv
# Reading tweets from CSV: lowes_tweets.csv
# Reading tweets from CSV: idexcorp_tweets.csv
# Reading tweets from CSV: aligntechinc_tweets.csv
# Reading tweets from CSV: b_binsurance_tweets.csv
# Reading tweets from CSV: teleflex_tweets.csv
# Reading tweets from CSV: mgmresortsintl_tweets.csv
# Reading tweets from CSV: fleetcor_tweets.csv
# Reading tweets from CSV: mandt_bank_tweets.csv
# Reading tweets from CSV: sbasite_tweets.csv
# Reading tweets from CSV: incyte_tweets.csv
# Reading tweets from CSV: resmed_tweets.csv
# Reading tweets from CSV: waterscorp_tweets.csv
# Reading tweets from CSV: ventasreit_tweets.csv
# Reading tweets from CSV: federalrealty_tweets.csv
# Reading tweets from CSV: epamsystems_tweets.csv
# Reading tweets from CSV: aon_plc_tweets.csv
# Reading tweets from CSV: campbellsoupco_tweets.csv
# Reading tweets from CSV: charlesschwab_tweets.csv
# Reading tweets from CSV: amwater_tweets.csv
# Reading tweets from CSV: klacorp_tweets.csv
# Reading tweets from CSV: raymondjames_tweets.csv
# Reading tweets from CSV: alaskaair_tweets.csv
# Reading tweets from CSV: hesscorporation_tweets.csv
# Reading tweets from CSV: ea_tweets.csv
# Reading tweets from CSV: firstenergycorp_tweets.csv
# Reading tweets from CSV: alliantenergy_tweets.csv
# Reading tweets from CSV: intel_tweets.csv
# Reading tweets from CSV: paypal_tweets.csv
# Reading tweets from CSV: cfindustries_tweets.csv
# Reading tweets from CSV: invitationhomes_tweets.csv
# Reading tweets from CSV: lennar_tweets.csv
# Reading tweets from CSV: lambweston_tweets.csv
# Reading tweets from CSV: expediagroup_tweets.csv
# Reading tweets from CSV: cintascorp_tweets.csv
# Reading tweets from CSV: molsoncoors_tweets.csv
# Reading tweets from CSV: dominionenergy_tweets.csv
# Reading tweets from CSV: gartner_inc_tweets.csv
# Reading tweets from CSV: atvi_ab_tweets.csv
# Reading tweets from CSV: morganstanley_tweets.csv
# Reading tweets from CSV: wtwcorporate_tweets.csv
# Reading tweets from CSV: nasdaq_tweets.csv
# Reading tweets from CSV: monsterenergy_tweets.csv
# Reading tweets from CSV: dukesmeats_tweets.csv
# Reading tweets from CSV: amd_tweets.csv
# Reading tweets from CSV: otiselevatorco_tweets.csv
# Reading tweets from CSV: americanair_tweets.csv
# Reading tweets from CSV: oracle_tweets.csv
# Reading tweets from CSV: netapp_tweets.csv
# Reading tweets from CSV: wecenergygroup_tweets.csv
# Reading tweets from CSV: realtyincome_tweets.csv
# Reading tweets from CSV: hormelfoods_tweets.csv
# Reading tweets from CSV: globelife_tweets.csv
# Reading tweets from CSV: celanese_tweets.csv
# Reading tweets from CSV: apa_corp_tweets.csv
# Reading tweets from CSV: oliverwyman_tweets.csv
# Reading tweets from CSV: activision_tweets.csv
# Reading tweets from CSV: nexteraenergy_tweets.csv
# Reading tweets from CSV: f5_tweets.csv
# Reading tweets from CSV: thermatru_tweets.csv
# Reading tweets from CSV: celebritycruise_tweets.csv
# Reading tweets from CSV: tesla_tweets.csv
# Reading tweets from CSV: udrmarketing_tweets.csv
# Reading tweets from CSV: amgen_tweets.csv
# Reading tweets from CSV: dukeenergy_tweets.csv
# Reading tweets from CSV: theaescorp_tweets.csv
# Reading tweets from CSV: capitalone_tweets.csv
# Reading tweets from CSV: ansys_tweets.csv
# Reading tweets from CSV: adobe_tweets.csv
# Reading tweets from CSV: mccormickcorp_tweets.csv
# Reading tweets from CSV: firstrepublic_tweets.csv
# Reading tweets from CSV: cp_news_tweets.csv
# Reading tweets from CSV: cognizant_tweets.csv
# Reading tweets from CSV: globalpayinc_tweets.csv
# Reading tweets from CSV: slimjim_tweets.csv
# Reading tweets from CSV: oneok_tweets.csv
# Reading tweets from CSV: ford_tweets.csv
# Reading tweets from CSV: wrberkleycorp_tweets.csv
# Reading tweets from CSV: ballcorphq_tweets.csv
# Reading tweets from CSV: salesforce_tweets.csv
# Reading tweets from CSV: tuicruises_tweets.csv
# Reading tweets from CSV: comericabank_tweets.csv
# Reading tweets from CSV: essexapartments_tweets.csv
# Reading tweets from CSV: corninggorilla_tweets.csv
# Reading tweets from CSV: hersheycompany_tweets.csv
# Reading tweets from CSV: abbottnews_tweets.csv
# Reading tweets from CSV: cbrands_tweets.csv
# Reading tweets from CSV: smuckers_tweets.csv
# Reading tweets from CSV: textron_tweets.csv
# Reading tweets from CSV: huntington_bank_tweets.csv
# Reading tweets from CSV: trane_tech_tweets.csv
# Reading tweets from CSV: intuit_tweets.csv
# Reading tweets from CSV: corningopcomm_tweets.csv
# Reading tweets from CSV: poolcorp_tweets.csv
# Reading tweets from CSV: waltdisneyco_tweets.csv
# Reading tweets from CSV: pfizer_tweets.csv
# Reading tweets from CSV: iteroscanner_tweets.csv
# Reading tweets from CSV: progressive_tweets.csv
# Reading tweets from CSV: mettlertoledo_tweets.csv
# Reading tweets from CSV: pultehomes_tweets.csv
# Reading tweets from CSV: hpe_tweets.csv
# Reading tweets from CSV: jh_fintech_tweets.csv
# Reading tweets from CSV: irproducts_tweets.csv
# Reading tweets from CSV: microchiptech_tweets.csv
# Reading tweets from CSV: chase_tweets.csv
# Reading tweets from CSV: kinder_morgan_tweets.csv
# Reading tweets from CSV: teledynedalsa_tweets.csv
# Reading tweets from CSV: bioradflowabs_tweets.csv
# Reading tweets from CSV: bankofamerica_tweets.csv
# Reading tweets from CSV: dentsplysirona_tweets.csv
# Reading tweets from CSV: grainger_tweets.csv
# Reading tweets from CSV: warnerbrostv_tweets.csv
# Reading tweets from CSV: opentable_tweets.csv
# Reading tweets from CSV: marriottbonvoy_tweets.csv
# Reading tweets from CSV: marshglobal_tweets.csv
# Reading tweets from CSV: united_tweets.csv
# Reading tweets from CSV: generalmills_tweets.csv
# Reading tweets from CSV: sherwinwilliams_tweets.csv
# Reading tweets from CSV: cardinalhealth_tweets.csv
# Reading tweets from CSV: moodysinvsvc_tweets.csv
# Reading tweets from CSV: applied4tech_tweets.csv
# Reading tweets from CSV: paccarfinancial_tweets.csv
# Reading tweets from CSV: sealed_air_tweets.csv
# Reading tweets from CSV: airproducts_tweets.csv
# Reading tweets from CSV: brownforman_tweets.csv
# Reading tweets from CSV: idexx_tweets.csv
# Reading tweets from CSV: gileadsciences_tweets.csv
# Reading tweets from CSV: aosmithhotwater_tweets.csv
# Reading tweets from CSV: apple_tweets.csv
# Reading tweets from CSV: hcahealthcare_tweets.csv
# Reading tweets from CSV: nisourceinc_tweets.csv
# Reading tweets from CSV: nxp_tweets.csv
# Reading tweets from CSV: mckesson_tweets.csv
# Reading tweets from CSV: northropgrumman_tweets.csv
# Reading tweets from CSV: prologis_tweets.csv
# Reading tweets from CSV: fortivecorp_tweets.csv
# Reading tweets from CSV: servicenow_tweets.csv
# Reading tweets from CSV: cdwcorp_tweets.csv
# Reading tweets from CSV: dollargeneral_tweets.csv
# Reading tweets from CSV: kimcorealty_tweets.csv
# Reading tweets from CSV: spectrumbiz_tweets.csv
# Reading tweets from CSV: advanceauto_tweets.csv
# Reading tweets from CSV: regionsbank_tweets.csv
# Reading tweets from CSV: ebay_tweets.csv
# Reading tweets from CSV: nvidia_tweets.csv
# Reading tweets from CSV: verisk_tweets.csv
# Reading tweets from CSV: wbd_tweets.csv
# Reading tweets from CSV: gardein_tweets.csv
# Reading tweets from CSV: qorvoinc_tweets.csv
# Reading tweets from CSV: ecolab_tweets.csv
# Reading tweets from CSV: hp_tweets.csv
# Reading tweets from CSV: generaldynamics_tweets.csv
# Reading tweets from CSV: boeing_tweets.csv
# Reading tweets from CSV: kelloggsus_tweets.csv
# Reading tweets from CSV: tylertech_tweets.csv
# Reading tweets from CSV: jnjnews_tweets.csv
# Reading tweets from CSV: wellsfargo_tweets.csv
# Reading tweets from CSV: hologic_tweets.csv
# Reading tweets from CSV: nrgenergy_tweets.csv
# Reading tweets from CSV: dxctechnology_tweets.csv
# Reading tweets from CSV: newmontcorp_tweets.csv
# Reading tweets from CSV: westpharma_tweets.csv
# Reading tweets from CSV: walmart_tweets.csv
# Reading tweets from CSV: emerson_news_tweets.csv
# Reading tweets from CSV: nike_tweets.csv
# Reading tweets from CSV: chubb_tweets.csv
# Reading tweets from CSV: omnicom_tweets.csv
# Reading tweets from CSV: autozone_tweets.csv
# Reading tweets from CSV: microntech_tweets.csv
# Reading tweets from CSV: danahercorp_tweets.csv
# Reading tweets from CSV: exxonmobil_tweets.csv
# Reading tweets from CSV: uhs_inc_tweets.csv
# Reading tweets from CSV: entergy_tweets.csv
# Reading tweets from CSV: prudential_tweets.csv
# Reading tweets from CSV: wba_global_tweets.csv
# Reading tweets from CSV: mdlz_tweets.csv
# Reading tweets from CSV: edison_energy_tweets.csv
# Reading tweets from CSV: bioradlifesci_tweets.csv
# Reading tweets from CSV: zoetis_tweets.csv
# Reading tweets from CSV: henryschein_tweets.csv
# Reading tweets from CSV: comcast_tweets.csv
# Reading tweets from CSV: servicenownews_tweets.csv
# Reading tweets from CSV: gm_tweets.csv
# Reading tweets from CSV: cloroxco_tweets.csv
# Reading tweets from CSV: pentair_tweets.csv
# Reading tweets from CSV: quanta_services_tweets.csv
# Reading tweets from CSV: southerncompany_tweets.csv
# Reading tweets from CSV: bostonsci_tweets.csv
# Reading tweets from CSV: biotechne_tweets.csv
# Reading tweets from CSV: marathonpetroco_tweets.csv
# Reading tweets from CSV: interpublicipg_tweets.csv
# Reading tweets from CSV: microsoft_tweets.csv
# Reading tweets from CSV: psegdelivers_tweets.csv
# Reading tweets from CSV: ptc_tweets.csv
# Reading tweets from CSV: sempra_tweets.csv
# Reading tweets from CSV: questdx_tweets.csv
# Reading tweets from CSV: cocacolaco_tweets.csv
# Reading tweets from CSV: digitalrealty_tweets.csv
# Reading tweets from CSV: travelers_tweets.csv
# Reading tweets from CSV: camdenliving_tweets.csv
# Reading tweets from CSV: campbells_tweets.csv
# Reading tweets from CSV: iff_tweets.csv
# Reading tweets from CSV: silversea_tweets.csv
# Reading tweets from CSV: devonenergy_tweets.csv
# Reading tweets from CSV: cadence_tweets.csv
# Reading tweets from CSV: abiomed_tweets.csv
# Reading tweets from CSV: newsfromrcgroup_tweets.csv
# Reading tweets from CSV: coterraenergy_tweets.csv
# Reading tweets from CSV: aflac_tweets.csv
# Reading tweets from CSV: wearehii_tweets.csv
# Reading tweets from CSV: eversourcema_tweets.csv
# Reading tweets from CSV: elevancehealth_tweets.csv
# Reading tweets from CSV: halliburton_tweets.csv
# Reading tweets from CSV: pizzahut_tweets.csv
# Reading tweets from CSV: goldmansachs_tweets.csv
# Reading tweets from CSV: bestbuy_tweets.csv
# Reading tweets from CSV: 3m_tweets.csv
# Reading tweets from CSV: proctergamble_tweets.csv
# Reading tweets from CSV: edisonintl_tweets.csv
# Reading tweets from CSV: delta_tweets.csv
# Reading tweets from CSV: insidepmi_tweets.csv
# Reading tweets from CSV: medtronic_tweets.csv
# Reading tweets from CSV: zimmerbiomet_tweets.csv
# Reading tweets from CSV: amazonnews_tweets.csv
# Reading tweets from CSV: mercer_tweets.csv
# Reading tweets from CSV: hotwire_tweets.csv
# Reading tweets from CSV: hinge_tweets.csv
# Reading tweets from CSV: xcelenergy_tweets.csv
# Reading tweets from CSV: unionpacific_tweets.csv
# Reading tweets from CSV: snapon_tools_tweets.csv
# Reading tweets from CSV: amcorpackaging_tweets.csv
# Reading tweets from CSV: statestreet_tweets.csv
# Reading tweets from CSV: nucorcorp_tweets.csv
# Reading tweets from CSV: bdandco_tweets.csv
# Reading tweets from CSV: fifththird_tweets.csv
# Reading tweets from CSV: citi_tweets.csv
# Reading tweets from CSV: perkinelmer_tweets.csv
# Reading tweets from CSV: carnivalplc_tweets.csv
# Reading tweets from CSV: lkqcorp_tweets.csv
# Reading tweets from CSV: protiviti_tweets.csv
# Reading tweets from CSV: albemarlecorp_tweets.csv
# Reading tweets from CSV: msci_inc_tweets.csv
# Reading tweets from CSV: centene_tweets.csv
# Reading tweets from CSV: biogen_tweets.csv
# Reading tweets from CSV: conedison_tweets.csv
# Reading tweets from CSV: expd_official_tweets.csv
# Reading tweets from CSV: dovercorp_tweets.csv
# Reading tweets from CSV: keybank_tweets.csv
# Reading tweets from CSV: rokautomation_tweets.csv
# Reading tweets from CSV: constellationeg_tweets.csv
# Reading tweets from CSV: fastenalcompany_tweets.csv
# Reading tweets from CSV: livenation_tweets.csv
# Reading tweets from CSV: fmccorp_tweets.csv
# Reading tweets from CSV: boomchickapop_tweets.csv
# Reading tweets from CSV: jbhunt360_tweets.csv
# Reading tweets from CSV: amazon_tweets.csv
# Reading tweets from CSV: pepsico_tweets.csv
# Reading tweets from CSV: vfcorp_tweets.csv
# Reading tweets from CSV: dish_tweets.csv
# Reading tweets from CSV: oreillyauto_tweets.csv
# Reading tweets from CSV: tacobell_tweets.csv
# Reading tweets from CSV: aepnews_tweets.csv
# Reading tweets from CSV: johnsoncontrols_tweets.csv
# Reading tweets from CSV: etsy_tweets.csv
# Reading tweets from CSV: honeywell_tweets.csv
# Reading tweets from CSV: sce_tweets.csv
# Reading tweets from CSV: republicservice_tweets.csv
# Reading tweets from CSV: eatoncorp_tweets.csv
# Reading tweets from CSV: caesarsent_tweets.csv
# Reading tweets from CSV: quickbooks_tweets.csv
# Reading tweets from CSV: lockheedmartin_tweets.csv
# Reading tweets from CSV: carrier_tweets.csv
# Reading tweets from CSV: weyerhaeuser_tweets.csv
# Reading tweets from CSV: troweprice_tweets.csv
# Reading tweets from CSV: westerndigital_tweets.csv
# Reading tweets from CSV: everest_re_tweets.csv
# Reading tweets from CSV: borgwarner_tweets.csv
# Reading tweets from CSV: assurant_tweets.csv
# Reading tweets from CSV: getspectrum_tweets.csv
# Reading tweets from CSV: darden_tweets.csv
# Reading tweets from CSV: williamsupdates_tweets.csv
# Reading tweets from CSV: yumbrands_tweets.csv
# Reading tweets from CSV: maacommunities_tweets.csv
# Reading tweets from CSV: king_games_tweets.csv
# Reading tweets from CSV: allstate_tweets.csv
# Reading tweets from CSV: fiberondecking_tweets.csv
# Reading tweets from CSV: plentyoffish_tweets.csv
# Reading tweets from CSV: creditkarma_tweets.csv
# Reading tweets from CSV: hasbro_tweets.csv
# Reading tweets from CSV: johndeere_tweets.csv
# Reading tweets from CSV: brinknewsnow_tweets.csv
# Reading tweets from CSV: match_tweets.csv
# Reading tweets from CSV: hlcruises_tweets.csv
# Reading tweets from CSV: molinahealth_tweets.csv
# Reading tweets from CSV: amerencorp_tweets.csv
# Reading tweets from CSV: lincolnfingroup_tweets.csv
# Reading tweets from CSV: ibm_tweets.csv
# Reading tweets from CSV: seagate_tweets.csv
# Reading tweets from CSV: aptiv_tweets.csv
# Reading tweets from CSV: dte_energy_tweets.csv
# Reading tweets from CSV: junipernetworks_tweets.csv
# Reading tweets from CSV: motosolutions_tweets.csv
# Reading tweets from CSV: corning_tweets.csv
# Reading tweets from CSV: marketaxess_tweets.csv
# Reading tweets from CSV: vrbo_tweets.csv
# Reading tweets from CSV: lillypad_tweets.csv
# Reading tweets from CSV: stryker_st_tweets.csv
# Reading tweets from CSV: westrock_tweets.csv
# Reading tweets from CSV: paycom_tweets.csv
# Reading tweets from CSV: orbitz_tweets.csv
# Reading tweets from CSV: ralphlauren_tweets.csv
# Reading tweets from CSV: invescous_tweets.csv
# Reading tweets from CSV: bmsnews_tweets.csv
# Reading tweets from CSV: chubbna_tweets.csv
# Reading tweets from CSV: blackrock_tweets.csv
# Reading tweets from CSV: sysco_tweets.csv
# Reading tweets from CSV: parkerhannifin_tweets.csv
# Reading tweets from CSV: baxter_intl_tweets.csv
# Reading tweets from CSV: ourtimedating_tweets.csv
# Reading tweets from CSV: tractorsupply_tweets.csv
# Reading tweets from CSV: equityres_tweets.csv
# Reading tweets from CSV: metlife_tweets.csv
# Reading tweets from CSV: ppg_tweets.csv
# Reading tweets from CSV: illumina_tweets.csv
# Reading tweets from CSV: lumentechco_tweets.csv
# Reading tweets from CSV: fm_fcx_tweets.csv
# Reading tweets from CSV: roberthalf_tweets.csv
# Reading tweets from CSV: hotelsdotcom_tweets.csv
# Reading tweets from CSV: teconnectivity_tweets.csv
# Reading tweets from CSV: jacobsconnects_tweets.csv
# Reading tweets from CSV: unitedrentals_tweets.csv
# Reading tweets from CSV: adp_tweets.csv
# Reading tweets from CSV: corteva_tweets.csv
# Reading tweets from CSV: kfc_tweets.csv
# Reading tweets from CSV: invisalign_tweets.csv
# Reading tweets from CSV: fedex_tweets.csv
# Reading tweets from CSV: jpmorgan_tweets.csv
# Reading tweets from CSV: generalelectric_tweets.csv
# Reading tweets from CSV: cmegroup_tweets.csv
# Reading tweets from CSV: davita_tweets.csv
# Reading tweets from CSV: accenture_us_tweets.csv
# Reading tweets from CSV: discover_tweets.csv
# Reading tweets from CSV: generac_tweets.csv
# Reading tweets from CSV: dollartree_tweets.csv
# Reading tweets from CSV: fortinet_tweets.csv
# Reading tweets from CSV: trimblecorpnews_tweets.csv
# Reading tweets from CSV: caterpillarinc_tweets.csv
# Reading tweets from CSV: verizon_tweets.csv
# Reading tweets from CSV: l3harristech_tweets.csv
# Reading tweets from CSV: phillips66co_tweets.csv
# Reading tweets from CSV: lindeplc_tweets.csv
# Reading tweets from CSV: adi_news_tweets.csv

# %%
##########################
# LOAD A PRE-SAVED MODEL #
##########################
# Load the model.
print("Loading presaved model")
with open(f"{MODEL_FOLDER}/model.pkl", "rb") as file:
    model = pickle.load(file)
# Out:
# Loading presaved model

# %%
#######################
# VISUALIZE RESULTS #
#######################
# Run the interactive report interface
tmp.report(model=model, docs=texts)
# Out:
# VBox(children=(VBox(children=(HBox(children=(HTML(value='<b>Select a topic</b>:'), Dropdown(options=((0, 0), (…

# %%
##################################################################
# SAVE SCATTERPLOT OF TOPICS BASED ON INTERTOPIC DISTANCE VALUES #
##################################################################

# %%
# Calculate the coordinates of topics based on intertopic distance values.
# By default, the combination of t-distributed Stochastic Neighbor Embedding
# and symmetric Kullback-Leibler divergence is used to calculate topics coordinates in 2D.
topics_coords = tmp.prepare_coords(model)

# %%
# Plot topics
topic_scatterplot = tmp.plot_scatter_topics(topics_coords, size_col='size', label_col='label')
altair_saver.save(topic_scatterplot, f"{MODEL_FOLDER}/intertopicdistance_tsne.html")

# %%
############################################
# PHI MATRIX (WORDS VS TOPICS PROBABILITY) #
############################################
phi = tmp.get_phi(model)
phi.head()
# Out:
# topics            0             1             2             3             4   \
# words
#  ‍      1.122633e-08  7.543783e-09  8.310515e-09  5.063248e-09  5.356695e-09
#  ‍@     1.122633e-08  7.543783e-09  8.310515e-09  5.063248e-09  5.356695e-09
#  ‍p     1.122633e-08  7.543783e-09  8.310515e-09  5.063248e-09  5.356695e-09
#  ‍t     1.122633e-08  7.543783e-09  8.310515e-09  5.063248e-09  5.356695e-09
#  ‍‍     1.122633e-08  7.543783e-09  8.310515e-09  5.063248e-09  5.356695e-09
#
# topics            5             6             7             8             9   \
# words
#  ‍      9.505678e-09  1.018730e-08  1.042539e-08  7.150831e-09  6.657103e-09
#  ‍@     9.505678e-09  1.018730e-08  1.042539e-08  7.150831e-09  6.657103e-09
#  ‍p     9.505678e-09  1.018730e-08  1.042539e-08  7.150831e-09  6.657103e-09
#  ‍t     9.505678e-09  1.018730e-08  1.042539e-08  7.150831e-09  6.657103e-09
#  ‍‍     9.505678e-09  1.018730e-08  1.042539e-08  7.150831e-09  6.657103e-09
#
# topics  ...            40            41            42            43  \
# words   ...
#  ‍      ...  6.126449e-09  5.043646e-09  6.170437e-09  5.465840e-09
#  ‍@     ...  6.126449e-09  5.043646e-09  6.170437e-09  5.465840e-09
#  ‍p     ...  6.126449e-09  5.043646e-09  6.170437e-09  5.465840e-09
#  ‍t     ...  6.126449e-09  5.043646e-09  6.170437e-09  5.465840e-09
#  ‍‍     ...  6.126449e-09  5.043646e-09  6.170437e-09  5.465840e-09
#
# topics            44            45            46            47            48  \
# words
#  ‍      3.546810e-09  8.251773e-09  9.393368e-09  3.869435e-09  7.574972e-09
#  ‍@     3.546810e-09  8.251773e-09  9.393368e-09  3.869435e-09  7.574972e-09
#  ‍p     3.546810e-09  8.251773e-09  9.393368e-09  3.869435e-09  7.574972e-09
#  ‍t     3.546810e-09  8.251773e-09  9.393368e-09  3.869435e-09  7.574972e-09
#  ‍‍     3.546810e-09  8.251773e-09  9.393368e-09  3.869435e-09  7.574972e-09
#
# topics            49
# words
#  ‍      1.171146e-08
#  ‍@     1.171146e-08
#  ‍p     1.171146e-08
#  ‍t     1.171146e-08
#  ‍‍     1.171146e-08
#
# [5 rows x 50 columns]

# %%
#######################################
# FOR EACH TOPIC, SAVE RELEVANT WORDS #
#######################################
for i in range(0, NUM_TOPICS):
    terms_probs = tmp.calc_terms_probs_ratio(phi, topic=i, lambda_=0.60)
    tmp.plot_terms(terms_probs).save(f"{MODEL_FOLDER}/topic{i}_relevantwords.html")

# %%
##################################################
# THETA MATRIX (TOPICS VS DOCUMENTS PROBABILITY) #
##################################################
theta = tmp.get_theta(model)
theta.head()
# Out:
# docs     0             1         2         3         4         5        \
# topics
# 0       0.008496  4.190155e-04  0.007215  0.004104  0.010844  0.003224
# 1       0.030035  3.282900e-02  0.001988  0.004772  0.007032  0.021364
# 2       0.011068  5.957034e-05  0.027090  0.008768  0.000175  0.004295
# 3       0.011663  7.447948e-09  0.024118  0.012973  0.010109  0.002516
# 4       0.002631  5.330783e-04  0.006495  0.004518  0.000016  0.002236
#
# docs     6         7         8         9        ...  1004174   1004175  \
# topics                                          ...
# 0       0.000692  0.023247  0.003367  0.027114  ...      0.0  0.007459
# 1       0.000361  0.012171  0.019154  0.023248  ...      0.0  0.018211
# 2       0.000053  0.006682  0.004373  0.032464  ...      0.0  0.005248
# 3       0.000441  0.047507  0.000442  0.029814  ...      0.0  0.135543
# 4       0.000337  0.007751  0.018097  0.028531  ...      0.0  0.011952
#
# docs     1004176   1004177   1004178       1004179   1004180   1004181  \
# topics
# 0       0.099934  0.001634  0.028477  4.364889e-04  0.000857  0.001941
# 1       0.003118  0.004687  0.000236  2.108498e-03  0.004286  0.000245
# 2       0.001845  0.000329  0.005428  3.028636e-07  0.001656  0.000328
# 3       0.000580  0.029977  0.030733  7.708663e-05  0.003500  0.172282
# 4       0.003130  0.002890  0.185355  4.312373e-06  0.001623  0.001529
#
# docs     1004182  1004183
# topics
# 0       0.002965      0.0
# 1       0.077908      0.0
# 2       0.004261      0.0
# 3       0.145928      0.0
# 4       0.009774      0.0
#
# [5 rows x 1004184 columns]

# %%
##################################################################
# Get documents with maximum probabilities P(t|d) for each topic #
##################################################################
tmp.get_top_docs(texts, model=model)
# Out:
#                                               topic0  \
# 0  How is machine learning being used to improve ...
# 1     2 years. $400T in assets. 1 global phenomenon.
# 2  Transitional Design using NERI Industrial #Cha...
# 3  UP's new online magazine for #transportation a...
# 4  Brea Oasis not a mirage:$2.5M sculpture, tribu...
#
#                                               topic1  \
# 0  PostyFest is coming to your living room today!...
# 1  Lessons from #tech products that failed early....
# 2  It’s #tbt Throwback Thursday! In January 1960,...
# 3  Parker's #Mobile #IoT a digital integrated sol...
# 4  We bought a gene gun! Thanks @BioRadLifeSci! #...
#
#                                               topic2  \
# 0  Get the inside scoop on potential disruptors t...
# 1  Genomic biomarkers lead to a reduction in trea...
# 2  The #packaging industry has so many great care...
# 3  We're glad that we could be good company! Look...
# 4  Not a bad afternoon after a good two days of c...
#
#                                               topic3  \
# 0  At VF we are committed to Inclusion, Diversity...
# 1  We have an average household income of $100,00...
# 2  @Ableroofing brightened a newlywed couple's ou...
# 3  May is women's health month and my friend @She...
# 4  No plans for the weekend? Write a science blog...
#
#                                               topic4  \
# 0  #PCA Vincennes donated boxes to the Evansville...
# 1  When Webb begins to beam back images of the ea...
# 2  #inthenews: Our Linea Lite line scan cameras f...
# 3  @Ruaan_L @davide_2010 @Anka_T @EurocharmGroup ...
# 4  @farasatk @Race2Diversity @fleejack @Vaillanco...
#
#                                               topic5  \
# 0  Ice melt ✓ Chimney sweep ✓ Wreathes ✓ A winter...
# 1  Putting a ring on it? Nice! Here's how you can...
# 2  Brian Duperrault, President &amp; CEO of @AIGi...
# 3  700 miles and counting. See how a researcher i...
# 4  Reminder that we stop accepting orders via htt...
#
#                                               topic6  \
# 0  8 tips for a better life at home this year: ht...
# 1  Patients with #diabetes are more likely to suf...
# 2  Not every corporate headquarters has a bottlin...
# 3  RT @4Rnutrients: @MosaicCompany and @nature_or...
# 4  Launching at #CES2020, this tiny drive offers ...
#
#                                               topic7  \
# 0  How can #Automotive system designers ensure th...
# 1  Parker can help avoid dry running in fluid tra...
# 2  Looking to convert your #Diesel fleet to #NatG...
# 3  Watch the video on how Parker is making #Minin...
# 4  Attending #bauma2022? Meet us at Booth 215, Ha...
#
#                                               topic8  \
# 0  Join two conservation groups, the @AmForestFnd...
# 1  Happy National Cat Day from those of us at Zoe...
# 2  There are different types of leukemia, includi...
# 3  Santa, carolers &amp; holiday merriment at Gra...
# 4  Check out one of our long-time grant partners ...
#
#                                               topic9  ...  \
# 0  . @cellectis Details Proof-of-Concept for “Sma...  ...
# 1  Do you know the #4Rs of #NutrientStewardship? ...  ...
# 2  Do you need to refresh your knowledge of #Flow...  ...
# 3  Say 👋 to Vanessa, our #reallifescientist of th...  ...
# 4  Yes, humans already have the ability to edit g...  ...
#
#                                              topic40  \
# 0  20932 Shine Dr., Saugus, CA $2,300/Month, 3 BR...
# 1  $1550 / 3br - 29676 Woodlands Ave - Classy Hom...
# 2  @roofstock @americanhomes4 @firstkeyhomes @Inv...
# 3  How would you use this spacious backyard? To s...
# 4  What do you think about this beautiful bathroo...
#
#                                              topic41  \
# 0  We’re gonna REWIND and BRING BACK TWO previous...
# 1  We're excited to be kicking off #SNAXPO2018 in...
# 2  BIO-RAD: Accelerate Analysis of Immune Respons...
# 3  INSIGHT: The future goals around #carbondioxid...
# 4  That’s one good lookin’ spud! Our colleagues @...
#
#                                              topic42  \
# 0  “While 2020 will be remembered as the year of ...
# 1  Making gels for a western blot today @BioRadLi...
# 2  Now on @ReutersInsider https://t.co/zxjMLGqjhp...
# 3  RT @FFAfoundation: @ADMupdates marks 55 years ...
# 4  #ICYMI: "The work to be performed here will ex...
#
#                                              topic43  \
# 0  Portland workshop, 9/6/13: Exposing the Potent...
# 1  Our friends at @bostonsci gave their best toda...
# 2  ICYMI: @ConstellationEG signed an agreement w/...
# 3  The team from Constellation played in yesterda...
# 4  Jayshree Ullal, Andy Bechtolsheim named semifi...
#
#                                              topic44  \
# 0  Restock your shelves with new discounts on ant...
# 1  Foresight filter plates and columns are prepac...
# 2  Only 30 minutes until our #KBtribechat fun hos...
# 3  TOMORROW at #KBtribechat -\n\nThe Laundry Room...
# 4  The Extreme Makeover: Home Edition designers k...
#
#                                              topic45  \
# 0  Chadd and Val share a bit of Illidan Stormrage...
# 1  What's your favorite Activision game of all ti...
# 2  No call for a moratorium on CRISPR babies at t...
# 3  Onsite Account Specialist Brendan Doyle's late...
# 4  What does one wear to a moon rocket launch?  🚀...
#
#                                              topic46  \
# 0  It’s National Pollinators Week! Did you know t...
# 1  #Xylem deploys teams in #China to meet the nee...
# 2  Prostate Cancer “Spews” Tumor-Promoting Protei...
# 3  Congrats to Alex Davis, one of this year's rec...
# 4  A warranted honor: The @USArmy recognizes our ...
#
#                                              topic47  \
# 0  @3dr_Amendment Thanks for the RTs. We apprecia...
# 1  Our CEO Kristin Peck shares what each of her p...
# 2  Do you believe, Cleveland? \n\n#ALLin216 https...
# 3  BRING BACK THE TIME” IS OUT NOW!! Listen here:...
# 4  LIVE on #Periscope: Live on Periscope with @JR...
#
#                                              topic48  \
# 0  Thx for following us @14landase @SnackIndustry...
# 1  It’s Day 2 (Tuesday) of #ISPD2022 and we want ...
# 2  RT @Pursuitof300: Weed mgmt. is important for ...
# 3  What is T-cell therapy? Watch to learn how thi...
# 4  Thx for following our Twitter! @directsupply1 ...
#
#                                              topic49
# 0  On-Premises vs. Cloud? How @Equinix &amp; @Ora...
# 1  Enterprises can now provision @Alibaba_Cloud E...
# 2  Sincere congratulations to Andreas Lutz, DuPon...
# 3  Congratulations to our 2020 DuPont Laureates!\...
# 4  Download this @TechTarget success story and re...
#
# [5 rows x 50 columns]
