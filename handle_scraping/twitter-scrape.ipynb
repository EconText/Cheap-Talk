# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %%
# get the response in the form of html
wikiurl="https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
response=requests.get(wikiurl)
print(response.status_code)
# Out:
# 200

# %%
# parse data from the html into a beautifulsoup object
soup = BeautifulSoup(response.text, 'html.parser')
main_table=soup.find('table',{'id':"constituents"})

# %%
df=pd.read_html(str(main_table))
# convert list to dataframe
df=pd.DataFrame(df[0])
print(df.head())
# Out:
#   Symbol     Security SEC filings  GICS Sector         GICS Sub-Industry  \
# 0    MMM           3M     reports  Industrials  Industrial Conglomerates
# 1    AOS  A. O. Smith     reports  Industrials         Building Products
# 2    ABT       Abbott     reports  Health Care     Health Care Equipment
# 3   ABBV       AbbVie     reports  Health Care           Pharmaceuticals
# 4   ABMD      Abiomed     reports  Health Care     Health Care Equipment
#
#      Headquarters Location Date first added      CIK      Founded
# 0    Saint Paul, Minnesota       1976-08-09    66740         1902
# 1     Milwaukee, Wisconsin       2017-07-26    91142         1916
# 2  North Chicago, Illinois       1964-03-31     1800         1888
# 3  North Chicago, Illinois       2012-12-31  1551152  2013 (1888)
# 4   Danvers, Massachusetts       2018-05-31   815094         1981

# %% [markdown]
# #### Getting Company Wiki Links

# %% [markdown]
# Get all the tags within the table that have a wiki link.
#
# Ex. `<a href="/wiki/Accenture" title="Accenture">Accenture</a>`

# %%
WIKI = "\/wiki\/([\w]+)"
wiki_link_tags = main_table.findAll('a', attrs={'href': re.compile(WIKI)})
wiki_link_tags = wiki_link_tags[4:] # Jump to the first company
wiki_link_tags[:5]
# Out:
# [<a href="/wiki/3M" title="3M">3M</a>,
#  <a href="/wiki/Saint_Paul,_Minnesota" title="Saint Paul, Minnesota">Saint Paul, Minnesota</a>,
#  <a href="/wiki/A._O._Smith" title="A. O. Smith">A. O. Smith</a>,
#  <a class="mw-redirect" href="/wiki/Milwaukee,_Wisconsin" title="Milwaukee, Wisconsin">Milwaukee, Wisconsin</a>,
#  <a href="/wiki/Abbott_Laboratories" title="Abbott Laboratories">Abbott</a>]

# %% [markdown]
# Now we only want to get the tags of actual companies.

# %%
company_names_from_df = df.Security.values

company_tags = []
company_names_from_tags = []
for tag in wiki_link_tags: 
    name = tag.contents[0]

    if name in company_names_from_df:
        company_tags.append(tag)
        company_names_from_tags.append(name)
        
print(company_tags[:5])
print(company_names_from_tags[:5])
# Out:
# [<a href="/wiki/3M" title="3M">3M</a>, <a href="/wiki/A._O._Smith" title="A. O. Smith">A. O. Smith</a>, <a href="/wiki/Abbott_Laboratories" title="Abbott Laboratories">Abbott</a>, <a href="/wiki/AbbVie" title="AbbVie">AbbVie</a>, <a href="/wiki/Abiomed" title="Abiomed">Abiomed</a>]
# ['3M', 'A. O. Smith', 'Abbott', 'AbbVie', 'Abiomed']

# %%
# Companies that are in the dataframe but not in the names we got
set(company_names_from_df) - set(company_names_from_tags)
# Out:
# {'Alphabet Inc. (Class A)',
#  'Alphabet Inc. (Class C)',
#  'Fox Corporation (Class A)',
#  'Fox Corporation (Class B)',
#  'News Corp (Class A)',
#  'News Corp (Class B)',
#  'Pool Corporation'}

# %% [markdown]
# Now we get the wikipedia links of all the companies in the list of tags. We can use the `href` attribute. We make this a mapping of company name to link.

# %%
WIKI_LINK_BEGINNING = "https://en.wikipedia.org"  # All wikipedia links start like this

wiki_links_map = {}
for tag in company_tags:
    name = tag.contents[0]
    link = WIKI_LINK_BEGINNING + tag['href']
    wiki_links_map[name] =  link

# %% [markdown]
# Add this links to the dataframe.

# %%
def get_wiki_link(row):
    try:
        return wiki_links_map[row.Security]
    except:
        return None
df["Wiki Link"] = df.apply(lambda row: get_wiki_link(row), axis=1)
df.head()
# Out:
#   Symbol     Security SEC filings  GICS Sector         GICS Sub-Industry  \
# 0    MMM           3M     reports  Industrials  Industrial Conglomerates
# 1    AOS  A. O. Smith     reports  Industrials         Building Products
# 2    ABT       Abbott     reports  Health Care     Health Care Equipment
# 3   ABBV       AbbVie     reports  Health Care           Pharmaceuticals
# 4   ABMD      Abiomed     reports  Health Care     Health Care Equipment
#
#      Headquarters Location Date first added      CIK      Founded  \
# 0    Saint Paul, Minnesota       1976-08-09    66740         1902
# 1     Milwaukee, Wisconsin       2017-07-26    91142         1916
# 2  North Chicago, Illinois       1964-03-31     1800         1888
# 3  North Chicago, Illinois       2012-12-31  1551152  2013 (1888)
# 4   Danvers, Massachusetts       2018-05-31   815094         1981
#
#                                            Wiki Link
# 0                   https://en.wikipedia.org/wiki/3M
# 1          https://en.wikipedia.org/wiki/A._O._Smith
# 2  https://en.wikipedia.org/wiki/Abbott_Laboratories
# 3               https://en.wikipedia.org/wiki/AbbVie
# 4              https://en.wikipedia.org/wiki/Abiomed

# %% [markdown]
# #### Getting Official Website from Wiki Page: Method 1
#
# 1. Get the soup for the company wiki page
# 2. Search for a `span` tag with a class "official-website"
# 3. Find `a` tag within that and get the href associated with it

# %% [markdown]
# Example on 3M wiki page

# %%
threeM = "https://en.wikipedia.org/wiki/3M"
threeM_response=requests.get(threeM)
print(threeM_response.status_code)
response_soup = BeautifulSoup(threeM_response.text, 'html.parser')
threeM_tag = response_soup.find('span', {'class':"official-website"})

threeM_tag.find('a')['href']
# Out:
# 200
# 'https://www.3m.com/'

# %% [markdown]
# Make a function that does this.

# %%
def get_company_website_from_wiki(wiki_page: str) -> str:
    try:
        wiki_response = requests.get(wiki_page)
        company_soup = BeautifulSoup(wiki_response.text, 'html.parser')
        website_tag = company_soup.find('span', {'class':'official-website'})
        return website_tag.find('a')['href']
    except:
        return None
    
threeM = "https://en.wikipedia.org/wiki/3M"
get_company_website_from_wiki(threeM)
# Out:
# 'https://www.3m.com/'

# %%
df_official_website = df.copy(deep=True)
df_official_website.head()
# Out:
#   Symbol     Security SEC filings  GICS Sector         GICS Sub-Industry  \
# 0    MMM           3M     reports  Industrials  Industrial Conglomerates
# 1    AOS  A. O. Smith     reports  Industrials         Building Products
# 2    ABT       Abbott     reports  Health Care     Health Care Equipment
# 3   ABBV       AbbVie     reports  Health Care           Pharmaceuticals
# 4   ABMD      Abiomed     reports  Health Care     Health Care Equipment
#
#      Headquarters Location Date first added      CIK      Founded  \
# 0    Saint Paul, Minnesota       1976-08-09    66740         1902
# 1     Milwaukee, Wisconsin       2017-07-26    91142         1916
# 2  North Chicago, Illinois       1964-03-31     1800         1888
# 3  North Chicago, Illinois       2012-12-31  1551152  2013 (1888)
# 4   Danvers, Massachusetts       2018-05-31   815094         1981
#
#                                            Wiki Link
# 0                   https://en.wikipedia.org/wiki/3M
# 1          https://en.wikipedia.org/wiki/A._O._Smith
# 2  https://en.wikipedia.org/wiki/Abbott_Laboratories
# 3               https://en.wikipedia.org/wiki/AbbVie
# 4              https://en.wikipedia.org/wiki/Abiomed

# %%
df_official_website["Official Website"] = df_official_website.apply(lambda row: get_company_website_from_wiki(row["Wiki Link"]), axis=1)

# %%
df_official_website.head()
# Out:
#   Symbol     Security SEC filings  GICS Sector         GICS Sub-Industry  \
# 0    MMM           3M     reports  Industrials  Industrial Conglomerates
# 1    AOS  A. O. Smith     reports  Industrials         Building Products
# 2    ABT       Abbott     reports  Health Care     Health Care Equipment
# 3   ABBV       AbbVie     reports  Health Care           Pharmaceuticals
# 4   ABMD      Abiomed     reports  Health Care     Health Care Equipment
#
#      Headquarters Location Date first added      CIK      Founded  \
# 0    Saint Paul, Minnesota       1976-08-09    66740         1902
# 1     Milwaukee, Wisconsin       2017-07-26    91142         1916
# 2  North Chicago, Illinois       1964-03-31     1800         1888
# 3  North Chicago, Illinois       2012-12-31  1551152  2013 (1888)
# 4   Danvers, Massachusetts       2018-05-31   815094         1981
#
#                                            Wiki Link         Official Website
# 0                   https://en.wikipedia.org/wiki/3M      https://www.3m.com/
# 1          https://en.wikipedia.org/wiki/A._O._Smith                     None
# 2  https://en.wikipedia.org/wiki/Abbott_Laboratories   https://www.abbott.com
# 3               https://en.wikipedia.org/wiki/AbbVie   https://www.abbvie.com
# 4              https://en.wikipedia.org/wiki/Abiomed  https://www.abiomed.com

# %%
len(df_official_website[df_official_website["Official Website"].isnull()])
# Out:
# 140

# %% [markdown]
# Looks like we have 140 companies for which the first method of extracting their official website did not work.

# %% [markdown]
# #### Getting Official Website from Wiki Page: Infobox Method
#
# Doing this since there were quite a few wiki pages for which the first method didn't work.
#
# 1. Get the soup for the company wiki page
# 2. Search for the table `table` tag with a class "infobox vcard"
# 3. Find the table row that has the text "Website"
# 4. Find the `a` tag within that row and get the href associated with it.

# %% [markdown]
# Example on A.O. Smith (a company for which the other method didn't work)

# %%
aosmith = "https://en.wikipedia.org/wiki/A._O._Smith"
response = requests.get(aosmith)
print(response.status_code)

aosmith_soup = BeautifulSoup(response.text)
info_table=aosmith_soup.find('table',{'class':"infobox vcard"})
# Out:
# 200

# %%
rows = info_table.findAll('tr')

for row in rows:
    header = row.find('th')
    if header and header.contents[0] == "Website":
        website = row.find('a')['href']
        break
    
print(website)
# Out:
# http://aosmith.com

# %% [markdown]
# Make a function that does this.

# %%
def get_company_website_from_infobox(wiki_page: str) -> str:
    if not wiki_page:
        return None
    
    response = requests.get(wiki_page)
    soup = BeautifulSoup(response.text)
    info_table=soup.find('table',{'class':"infobox vcard"})
    rows = info_table.findAll('tr')

    for row in rows:
        header = row.find('th')
        if header and header.contents[0] == "Website":
            website = row.find('a')['href']
            return website

    return None

# %%
df_infobox = df.copy(deep=True)
df_infobox["Official Website"] = df_infobox.apply(lambda row: get_company_website_from_infobox(row["Wiki Link"]), axis=1)

# %%
df_infobox.head()
# Out:
#   Symbol     Security SEC filings  GICS Sector         GICS Sub-Industry  \
# 0    MMM           3M     reports  Industrials  Industrial Conglomerates
# 1    AOS  A. O. Smith     reports  Industrials         Building Products
# 2    ABT       Abbott     reports  Health Care     Health Care Equipment
# 3   ABBV       AbbVie     reports  Health Care           Pharmaceuticals
# 4   ABMD      Abiomed     reports  Health Care     Health Care Equipment
#
#      Headquarters Location Date first added      CIK      Founded  \
# 0    Saint Paul, Minnesota       1976-08-09    66740         1902
# 1     Milwaukee, Wisconsin       2017-07-26    91142         1916
# 2  North Chicago, Illinois       1964-03-31     1800         1888
# 3  North Chicago, Illinois       2012-12-31  1551152  2013 (1888)
# 4   Danvers, Massachusetts       2018-05-31   815094         1981
#
#                                            Wiki Link       Official Website
# 0                   https://en.wikipedia.org/wiki/3M    https://www.3m.com/
# 1          https://en.wikipedia.org/wiki/A._O._Smith     http://aosmith.com
# 2  https://en.wikipedia.org/wiki/Abbott_Laboratories  http://www.abbott.com
# 3               https://en.wikipedia.org/wiki/AbbVie      http://abbvie.com
# 4              https://en.wikipedia.org/wiki/Abiomed     http://abiomed.com

# %%
len(df_infobox[df_infobox["Official Website"].isnull()])
# Out:
# 12

# %% [markdown]
# This is a bit better than the other method. There are only 12 companies for which the method did not succeed. View them below.

# %%
df_infobox[df_infobox["Official Website"].isnull()]
# Out:
#     Symbol                   Security SEC filings             GICS Sector  \
# 23   GOOGL    Alphabet Inc. (Class A)     reports  Communication Services
# 24    GOOG    Alphabet Inc. (Class C)     reports  Communication Services
# 156    DOV          Dover Corporation     reports             Industrials
# 205    FTV                    Fortive     reports             Industrials
# 207   FOXA  Fox Corporation (Class A)     reports  Communication Services
# 208    FOX  Fox Corporation (Class B)     reports  Communication Services
# 219   GILD            Gilead Sciences     reports             Health Care
# 331   NFLX                    Netflix     reports  Communication Services
# 334   NWSA        News Corp (Class A)     reports  Communication Services
# 335    NWS        News Corp (Class B)     reports  Communication Services
# 376   POOL           Pool Corporation     reports  Consumer Discretionary
# 467   VRSN                   Verisign     reports  Information Technology
#
#                       GICS Sub-Industry      Headquarters Location  \
# 23         Interactive Media & Services  Mountain View, California
# 24         Interactive Media & Services  Mountain View, California
# 156                Industrial Machinery    Downers Grove, Illinois
# 205                Industrial Machinery        Everett, Washington
# 207              Movies & Entertainment    New York City, New York
# 208              Movies & Entertainment    New York City, New York
# 219                       Biotechnology    Foster City, California
# 331              Movies & Entertainment      Los Gatos, California
# 334                          Publishing    New York City, New York
# 335                          Publishing    New York City, New York
# 376                        Distributors       Covington, Louisiana
# 467  Internet Services & Infrastructure           Dulles, Virginia
#
#     Date first added      CIK      Founded  \
# 23        2014-04-03  1652044         1998
# 24        2006-04-03  1652044         1998
# 156       1985-10-31    29905         1955
# 205       2016-07-01  1659166         2016
# 207       2013-07-01  1754301         2019
# 208       2015-09-18  1754301         2019
# 219       2004-07-01   882095         1987
# 331       2010-12-20  1065280         1997
# 334       2013-08-01  1564708  2013 (1980)
# 335       2015-09-18  1564708  2013 (1980)
# 376       2020-10-07   945841         1993
# 467       2006-02-01  1014473         1995
#
#                                            Wiki Link Official Website
# 23                                              None             None
# 24                                              None             None
# 156  https://en.wikipedia.org/wiki/Dover_Corporation             None
# 205            https://en.wikipedia.org/wiki/Fortive             None
# 207                                             None             None
# 208                                             None             None
# 219    https://en.wikipedia.org/wiki/Gilead_Sciences             None
# 331            https://en.wikipedia.org/wiki/Netflix             None
# 334                                             None             None
# 335                                             None             None
# 376                                             None             None
# 467           https://en.wikipedia.org/wiki/Verisign             None

# %% [markdown]
# #### Getting Twitter Handles from Company Websites: Method 1

# %% [markdown]
# 1. Get the soup for the company website
# 2. Search for an `a` tag with an `href` that matches the Twitter link regex `(https:\/\/twitter.com\/(?![a-zA-Z0-9_]+\/)([a-zA-Z0-9_]+))`. That will be the Twitter URL.
# 3. Split the Twitter URL at backslashes, and take the part after the last backslash as the Twitter handle.

# %% [markdown]
# Example on A.O. Smith page

# %%
aosmith = "http://aosmith.com"
response = requests.get(aosmith)
print(response.status_code)

aosmith_soup = BeautifulSoup(response.text)

TWITTER_HANDLE_LINK_REGEX = '(https:\/\/twitter.com\/(?![a-zA-Z0-9_]+\/)([a-zA-Z0-9_]+))'
twitter_link_tag = aosmith_soup.find('a', attrs={'href': re.compile(TWITTER_HANDLE_LINK_REGEX)})
print(twitter_link_tag['href'])
print(twitter_link_tag['href'].split("/")[-1])
# Out:
# 200
# https://twitter.com/aosmithhotwater
# aosmithhotwater

# %% [markdown]
# #### Getting Twitter Handles from Company Websites: Method 2

# %% [markdown]
# 1. Get the soup for the company website
# 2. Search for a single `a` tag with an `href` that contains the string `twitter`.
# 3. Split that URL at `?` which indicates the start of query params, and take the part before `?` as the Twitter URL.
# 4. Split the Twitter URL at backslashes, and take the part after the last backslash as the Twitter handle.

# %% [markdown]
# Example on Activision Blizzard page (which has its Twitter URL listed as [https://twitter.com/atvi_ab?lang=en](https://twitter.com/atvi_ab?lang=en))

# %%
activisionblizzard = "https://activisionblizzard.com/"
response = requests.get(activisionblizzard)
print(response.status_code)

activisionblizzard_soup = BeautifulSoup(response.text)

twitter_link_tag = activisionblizzard_soup.select_one("a[href*=twitter]")
twitter_url = twitter_link_tag['href']
twitter_url_no_params = twitter_link_tag['href'].split("?")[0]
twitter_handle = twitter_url_no_params.split("/")[-1]
print(twitter_url_no_params)
print(twitter_handle)
# Out:
# 200
# https://twitter.com/atvi_ab
# atvi_ab

# %% [markdown]
# Make this a function!

# %%
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

# Create a new requests session that allows 0 retries 
session = requests.Session()
retry = Retry(total=0)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)

# User-Agent header is required to successfully request some sites
HEADERS = {"User-Agent": "Mozilla/5.0 (X11; CrOS x86_64 12871.102.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.141 Safari/537.36"}

# Map each company's Twitter URL to its corresponding Twitter handle
twitter_url_to_handle_map = {}

def get_twitter_from_website(website: str, mergr: bool = False) -> str:
    """
    Returns company Twitter URL.
    Also updates Twitter URL to Twitter handle map.
    """
    print(website)
    if not website:
        # print("No website")
        return None

    if mergr:
        website = 'https://' + website
            
    try:
        response = session.get(website, headers=HEADERS)
    except:
        print("Request failed")
        return None
    
    print("Scraping", website)
    company_soup = BeautifulSoup(response.text)

    twitter_link_tag = company_soup.select_one("a[href*=twitter]")

    if twitter_link_tag and twitter_link_tag['href']:
        twitter_url = twitter_link_tag['href']
        twitter_url_no_params = twitter_link_tag['href'].split("?")[0]
        twitter_handle = twitter_url_no_params.split("/")[-1]
        twitter_url_to_handle_map[twitter_url_no_params] = twitter_handle
        # print(twitter_url_no_params)
        # print(twitter_handle)
        return twitter_url_no_params
        
    print("Request succeeded but Twitter not found")
    return None

# %%
# Try this on 3M
threem = "https://www.3m.com/"
get_twitter_from_website(threem)
# Out:
# 'https://twitter.com/3M'

# %% [markdown]
# Add the Twitter URLs to the dataframe.

# %%
df_twitter = df_infobox.copy(deep=True)
df_twitter["Twitter URL"] = df_twitter.apply(lambda row: get_twitter_from_website(row["Official Website"]), axis=1)

df_twitter
# Out:
#     Symbol              Security SEC filings             GICS Sector  \
# 0      MMM                    3M     reports             Industrials
# 1      AOS           A. O. Smith     reports             Industrials
# 2      ABT                Abbott     reports             Health Care
# 3     ABBV                AbbVie     reports             Health Care
# 4     ABMD               Abiomed     reports             Health Care
# ..     ...                   ...         ...                     ...
# 497    YUM           Yum! Brands     reports  Consumer Discretionary
# 498   ZBRA    Zebra Technologies     reports  Information Technology
# 499    ZBH         Zimmer Biomet     reports             Health Care
# 500   ZION  Zions Bancorporation     reports              Financials
# 501    ZTS                Zoetis     reports             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota
# 1                     Building Products     Milwaukee, Wisconsin
# 2                 Health Care Equipment  North Chicago, Illinois
# 3                       Pharmaceuticals  North Chicago, Illinois
# 4                 Health Care Equipment   Danvers, Massachusetts
# ..                                  ...                      ...
# 497                         Restaurants     Louisville, Kentucky
# 498  Electronic Equipment & Instruments   Lincolnshire, Illinois
# 499               Health Care Equipment          Warsaw, Indiana
# 500                      Regional Banks     Salt Lake City, Utah
# 501                     Pharmaceuticals   Parsippany, New Jersey
#
#     Date first added      CIK      Founded  \
# 0         1976-08-09    66740         1902
# 1         2017-07-26    91142         1916
# 2         1964-03-31     1800         1888
# 3         2012-12-31  1551152  2013 (1888)
# 4         2018-05-31   815094         1981
# ..               ...      ...          ...
# 497       1997-10-06  1041061         1997
# 498       2019-12-23   877212         1969
# 499       2001-08-07  1136869         1927
# 500       2001-06-22   109380         1873
# 501       2013-06-21  1555280         1952
#
#                                              Wiki Link  \
# 0                     https://en.wikipedia.org/wiki/3M
# 1            https://en.wikipedia.org/wiki/A._O._Smith
# 2    https://en.wikipedia.org/wiki/Abbott_Laboratories
# 3                 https://en.wikipedia.org/wiki/AbbVie
# 4                https://en.wikipedia.org/wiki/Abiomed
# ..                                                 ...
# 497          https://en.wikipedia.org/wiki/Yum!_Brands
# 498   https://en.wikipedia.org/wiki/Zebra_Technologies
# 499        https://en.wikipedia.org/wiki/Zimmer_Biomet
# 500  https://en.wikipedia.org/wiki/Zions_Bancorpora...
# 501               https://en.wikipedia.org/wiki/Zoetis
#
#                    Official Website                             Twitter URL
# 0               https://www.3m.com/                  https://twitter.com/3M
# 1                http://aosmith.com     https://twitter.com/aosmithhotwater
# 2             http://www.abbott.com          https://twitter.com/AbbottNews
# 3                 http://abbvie.com              https://twitter.com/abbvie
# 4                http://abiomed.com             https://twitter.com/abiomed
# ..                              ...                                     ...
# 497             https://www.yum.com                 https://twitter.com/kfc
# 498            http://www.zebra.com  http://www.twitter.com/zebratechnology
# 499         http://zimmerbiomet.com        https://twitter.com/zimmerbiomet
# 500  http://zionsbancorporation.com                                    None
# 501         https://www.zoetis.com/              https://twitter.com/zoetis
#
# [502 rows x 12 columns]

# %% [markdown]
# Use the Twitter URL to Twitter handle map to add Twitter handles to the dataframe.

# %%
def get_handle_from_twitter_url(row):
    try:
        return twitter_url_to_handle_map[row["Twitter URL"]]
    except:
        return None

# %%
df_twitter["Twitter Handle"] = df_twitter.apply(lambda row: get_handle_from_twitter_url(row), axis=1)
df_twitter
# Out:
#     Symbol              Security SEC filings             GICS Sector  \
# 0      MMM                    3M     reports             Industrials
# 1      AOS           A. O. Smith     reports             Industrials
# 2      ABT                Abbott     reports             Health Care
# 3     ABBV                AbbVie     reports             Health Care
# 4     ABMD               Abiomed     reports             Health Care
# ..     ...                   ...         ...                     ...
# 497    YUM           Yum! Brands     reports  Consumer Discretionary
# 498   ZBRA    Zebra Technologies     reports  Information Technology
# 499    ZBH         Zimmer Biomet     reports             Health Care
# 500   ZION  Zions Bancorporation     reports              Financials
# 501    ZTS                Zoetis     reports             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota
# 1                     Building Products     Milwaukee, Wisconsin
# 2                 Health Care Equipment  North Chicago, Illinois
# 3                       Pharmaceuticals  North Chicago, Illinois
# 4                 Health Care Equipment   Danvers, Massachusetts
# ..                                  ...                      ...
# 497                         Restaurants     Louisville, Kentucky
# 498  Electronic Equipment & Instruments   Lincolnshire, Illinois
# 499               Health Care Equipment          Warsaw, Indiana
# 500                      Regional Banks     Salt Lake City, Utah
# 501                     Pharmaceuticals   Parsippany, New Jersey
#
#     Date first added      CIK      Founded  \
# 0         1976-08-09    66740         1902
# 1         2017-07-26    91142         1916
# 2         1964-03-31     1800         1888
# 3         2012-12-31  1551152  2013 (1888)
# 4         2018-05-31   815094         1981
# ..               ...      ...          ...
# 497       1997-10-06  1041061         1997
# 498       2019-12-23   877212         1969
# 499       2001-08-07  1136869         1927
# 500       2001-06-22   109380         1873
# 501       2013-06-21  1555280         1952
#
#                                              Wiki Link  \
# 0                     https://en.wikipedia.org/wiki/3M
# 1            https://en.wikipedia.org/wiki/A._O._Smith
# 2    https://en.wikipedia.org/wiki/Abbott_Laboratories
# 3                 https://en.wikipedia.org/wiki/AbbVie
# 4                https://en.wikipedia.org/wiki/Abiomed
# ..                                                 ...
# 497          https://en.wikipedia.org/wiki/Yum!_Brands
# 498   https://en.wikipedia.org/wiki/Zebra_Technologies
# 499        https://en.wikipedia.org/wiki/Zimmer_Biomet
# 500  https://en.wikipedia.org/wiki/Zions_Bancorpora...
# 501               https://en.wikipedia.org/wiki/Zoetis
#
#                    Official Website                             Twitter URL  \
# 0               https://www.3m.com/                  https://twitter.com/3M
# 1                http://aosmith.com     https://twitter.com/aosmithhotwater
# 2             http://www.abbott.com          https://twitter.com/AbbottNews
# 3                 http://abbvie.com              https://twitter.com/abbvie
# 4                http://abiomed.com             https://twitter.com/abiomed
# ..                              ...                                     ...
# 497             https://www.yum.com                 https://twitter.com/kfc
# 498            http://www.zebra.com  http://www.twitter.com/zebratechnology
# 499         http://zimmerbiomet.com        https://twitter.com/zimmerbiomet
# 500  http://zionsbancorporation.com                                    None
# 501         https://www.zoetis.com/              https://twitter.com/zoetis
#
#       Twitter Handle
# 0                 3M
# 1    aosmithhotwater
# 2         AbbottNews
# 3             abbvie
# 4            abiomed
# ..               ...
# 497              kfc
# 498  zebratechnology
# 499     zimmerbiomet
# 500             None
# 501           zoetis
#
# [502 rows x 13 columns]

# %%
len(df_twitter[df_twitter["Twitter URL"].isnull()])
# Out:
# 165

# %% [markdown]
# Looks like we have 165 companies for which we weren't able to extract Twitter URLs. Let's see what those companies are.

# %%
df_twitter[df_twitter["Twitter URL"].isnull()]
# Out:
#     Symbol                         Security SEC filings  \
# 7      ADM                              ADM     reports
# 8     ADBE                       Adobe Inc.     reports
# 16     ALK                 Alaska Air Group     reports
# 18     ARE  Alexandria Real Estate Equities     reports
# 23   GOOGL          Alphabet Inc. (Class A)     reports
# ..     ...                              ...         ...
# 481     WM                 Waste Management     reports
# 489     WY                     Weyerhaeuser     reports
# 494   WYNN                     Wynn Resorts     reports
# 495    XEL                      Xcel Energy     reports
# 500   ZION             Zions Bancorporation     reports
#
#                 GICS Sector                    GICS Sub-Industry  \
# 7          Consumer Staples                Agricultural Products
# 8    Information Technology                 Application Software
# 16              Industrials                             Airlines
# 18              Real Estate                         Office REITs
# 23   Communication Services         Interactive Media & Services
# ..                      ...                                  ...
# 481             Industrials  Environmental & Facilities Services
# 489             Real Estate                    Specialized REITs
# 494  Consumer Discretionary                     Casinos & Gaming
# 495               Utilities                      Multi-Utilities
# 500              Financials                       Regional Banks
#
#          Headquarters Location Date first added      CIK Founded  \
# 7            Chicago, Illinois       1981-07-29     7084    1902
# 8         San Jose, California       1997-05-05   796343    1982
# 16          SeaTac, Washington       2016-05-13   766421    1985
# 18        Pasadena, California       2017-03-20  1035443    1994
# 23   Mountain View, California       2014-04-03  1652044    1998
# ..                         ...              ...      ...     ...
# 481             Houston, Texas              NaN   823768    1968
# 489        Seattle, Washington              NaN   106535    1900
# 494           Paradise, Nevada       2008-11-14  1174922    2002
# 495     Minneapolis, Minnesota       1957-03-04    72903    1909
# 500       Salt Lake City, Utah       2001-06-22   109380    1873
#
#                                              Wiki Link  \
# 7          https://en.wikipedia.org/wiki/ADM_(company)
# 8             https://en.wikipedia.org/wiki/Adobe_Inc.
# 16      https://en.wikipedia.org/wiki/Alaska_Air_Group
# 18   https://en.wikipedia.org/wiki/Alexandria_Real_...
# 23                                                None
# ..                                                 ...
# 481  https://en.wikipedia.org/wiki/Waste_Management...
# 489         https://en.wikipedia.org/wiki/Weyerhaeuser
# 494         https://en.wikipedia.org/wiki/Wynn_Resorts
# 495          https://en.wikipedia.org/wiki/Xcel_Energy
# 500  https://en.wikipedia.org/wiki/Zions_Bancorpora...
#
#                    Official Website Twitter URL Twitter Handle
# 7                    http://adm.com        None           None
# 8                  http://adobe.com        None           None
# 16             http://alaskaair.com        None           None
# 18             https://www.are.com/        None           None
# 23                             None        None           None
# ..                              ...         ...            ...
# 481              https://www.wm.com        None           None
# 489   https://www.weyerhaeuser.com/        None           None
# 494          http://wynnresorts.com        None           None
# 495      https://www.xcelenergy.com        None           None
# 500  http://zionsbancorporation.com        None           None
#
# [165 rows x 13 columns]

# %%
len(df_twitter[df_twitter["Twitter Handle"].isnull()])
# Out:
# 165

# %% [markdown]
# Looks like we have 165 companies for which we weren't able to map Twitter Handles. Let's see what those companies are.

# %%
df_twitter[df_twitter["Twitter Handle"].isnull()]
# Out:
#     Symbol                         Security SEC filings  \
# 7      ADM                              ADM     reports
# 8     ADBE                       Adobe Inc.     reports
# 16     ALK                 Alaska Air Group     reports
# 18     ARE  Alexandria Real Estate Equities     reports
# 23   GOOGL          Alphabet Inc. (Class A)     reports
# ..     ...                              ...         ...
# 481     WM                 Waste Management     reports
# 489     WY                     Weyerhaeuser     reports
# 494   WYNN                     Wynn Resorts     reports
# 495    XEL                      Xcel Energy     reports
# 500   ZION             Zions Bancorporation     reports
#
#                 GICS Sector                    GICS Sub-Industry  \
# 7          Consumer Staples                Agricultural Products
# 8    Information Technology                 Application Software
# 16              Industrials                             Airlines
# 18              Real Estate                         Office REITs
# 23   Communication Services         Interactive Media & Services
# ..                      ...                                  ...
# 481             Industrials  Environmental & Facilities Services
# 489             Real Estate                    Specialized REITs
# 494  Consumer Discretionary                     Casinos & Gaming
# 495               Utilities                      Multi-Utilities
# 500              Financials                       Regional Banks
#
#          Headquarters Location Date first added      CIK Founded  \
# 7            Chicago, Illinois       1981-07-29     7084    1902
# 8         San Jose, California       1997-05-05   796343    1982
# 16          SeaTac, Washington       2016-05-13   766421    1985
# 18        Pasadena, California       2017-03-20  1035443    1994
# 23   Mountain View, California       2014-04-03  1652044    1998
# ..                         ...              ...      ...     ...
# 481             Houston, Texas              NaN   823768    1968
# 489        Seattle, Washington              NaN   106535    1900
# 494           Paradise, Nevada       2008-11-14  1174922    2002
# 495     Minneapolis, Minnesota       1957-03-04    72903    1909
# 500       Salt Lake City, Utah       2001-06-22   109380    1873
#
#                                              Wiki Link  \
# 7          https://en.wikipedia.org/wiki/ADM_(company)
# 8             https://en.wikipedia.org/wiki/Adobe_Inc.
# 16      https://en.wikipedia.org/wiki/Alaska_Air_Group
# 18   https://en.wikipedia.org/wiki/Alexandria_Real_...
# 23                                                None
# ..                                                 ...
# 481  https://en.wikipedia.org/wiki/Waste_Management...
# 489         https://en.wikipedia.org/wiki/Weyerhaeuser
# 494         https://en.wikipedia.org/wiki/Wynn_Resorts
# 495          https://en.wikipedia.org/wiki/Xcel_Energy
# 500  https://en.wikipedia.org/wiki/Zions_Bancorpora...
#
#                    Official Website Twitter URL Twitter Handle
# 7                    http://adm.com        None           None
# 8                  http://adobe.com        None           None
# 16             http://alaskaair.com        None           None
# 18             https://www.are.com/        None           None
# 23                             None        None           None
# ..                              ...         ...            ...
# 481              https://www.wm.com        None           None
# 489   https://www.weyerhaeuser.com/        None           None
# 494          http://wynnresorts.com        None           None
# 495      https://www.xcelenergy.com        None           None
# 500  http://zionsbancorporation.com        None           None
#
# [165 rows x 13 columns]

# %% [markdown]
# **Save Twitter dataframe as a CSV!**

# %%
df_twitter.to_csv("sp_500_twitter.csv")

# %% [markdown]
# #### Manual Corrections and Additions
#
# Manually go through each row of the `sp_500_twitter.csv` to correct any erroneous Twitter URL or Twitter handle cells, and to fill empty official website, Twitter URL, and Twitter handle cells. Save the new CSV as `sp_500_twitter_manual.csv`

# %% [markdown]
# #### Getting Subsidiary Twitter Handles from Official Website
#
# What should we do about S&P 500 companies that are parent companies with quite a few subsidiaries / divisions / brands?
#
# We decided to create a new row for each subsidiary listed on the homepage of the parent company's official website. We'll skip subsidiaries that aren't listed that way for now — it'll help us rule out companies that aren't public-facing using a company-decided variable.
#
# 1. Get the soup for the company website
# 2. Search for all `a` tags with an `href` that contains the string `twitter`.
# 3. Clean up each Twitter URL and its corresponding handle.
# 5. Put each (Twitter URL, Twitter handle) tuple into a set for the company.

# %% [markdown]
# Example on Yum! Brands page (which has the Twitter URLs of four subsidiaries (Habit Burger, KFC, Pizza Hut, Taco Bell) listed as on its homepage).

# %%
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

# Create a new requests session that allows 0 retries 
session = requests.Session()
retry = Retry(total=0)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)

# User-Agent header is required to successfully request some sites
HEADERS = {"User-Agent": "Mozilla/5.0 (X11; CrOS x86_64 12871.102.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.141 Safari/537.36"}

yum = "https://www.yum.com"
response = session.get(yum, headers=HEADERS, timeout=10)
print(response.status_code)

yum_soup = BeautifulSoup(response.text)

twitter_link_tags = yum_soup.select("a[href*=twitter]")

twitter_url_handle_tuples = set()
for twitter_link_tag in twitter_link_tags:
    twitter_url = twitter_link_tag['href']
    twitter_url_no_params = twitter_link_tag['href'].split("?")[0]
    twitter_handle = twitter_url_no_params.split("/")[-1]
    twitter_url_end = twitter_url_no_params.split(".com/")[-1]
    twitter_handle = twitter_url_end.split("/")[0]
    twitter_url_handle_tuples.add((twitter_url_no_params, twitter_handle))

print(twitter_url_handle_tuples)
# Out:
# 200
# {('https://twitter.com/habitburger', 'habitburger'), ('https://twitter.com/tacobell', 'tacobell'), ('https://twitter.com/kfc', 'kfc'), ('https://twitter.com/yumbrands', 'yumbrands'), ('https://twitter.com/pizzahut', 'pizzahut')}

# %% [markdown]
# Make this a function!

# %%
# Map each company's symbol to a set of its and its subsidiaries' (Twitter URL, Twitter handle) tuples
symbol_to_twitters_map = {}

# %%
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

# Create a new requests session that allows 0 retries 
session = requests.Session()
retry = Retry(total=0)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)

# User-Agent header is required to successfully request some sites
HEADERS = {"User-Agent": "Mozilla/5.0 (X11; CrOS x86_64 12871.102.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.141 Safari/537.36"}

def get_twitters_from_website(symbol: str, website: str) -> str:
    """
    Returns a set of all unique (Twitter URL, Twitter handle) tuples scraped from company website,
    with no repeated Twitter handles.
    Also updates symbol to Twitter URLs map.
    """
    if not website:
        # print("No website")
        return None
        
    try:
        response = session.get(website, headers=HEADERS, timeout=10)
    except:
        # print("Request failed")
        return None
    
    # print("Scraping", website)
    company_soup = BeautifulSoup(response.text)
    
    twitter_link_tags = company_soup.select("a[href*=twitter]")

    twitter_handles = set()
    twitter_url_handle_tuples = set()
    for twitter_link_tag in twitter_link_tags:
        if twitter_link_tag['href']:
            twitter_url = twitter_link_tag['href']
            twitter_url_no_params = twitter_link_tag['href'].split("?")[0]
            twitter_url_end = twitter_url_no_params.split(".com/")[-1]
            twitter_handle = twitter_url_end.split("/")[0]
            if twitter_handle not in twitter_handles and twitter_handle != "intent":
                # We don't want Twitter handles that say "intent" -> that's usually something else
                twitter_url_handle_tuples.add((twitter_url_no_params, twitter_handle))
                twitter_handles.add(twitter_handle)
    
    symbol_to_twitters_map[symbol] = twitter_url_handle_tuples
    return(twitter_url_handle_tuples)
        
# Try this on Yum
# yum = "https://www.yum.com"
# print(get_twitters_from_website("YUM", yum))
# print()
# print(symbol_to_twitters_map)

# %% [markdown]
# Read in our manually updated CSV with company website links and Twitter URLs.
#
# Add a Subsidiary column, set to False for all rows since we only have parent companies for now.

# %%
df_manual = pd.read_csv('sp_500_twitter_manual.csv')
df_manual["Subsidiary"]=False
df_manual
# Out:
#      Unnamed: 0 Symbol              Security SEC filings  \
# 0             0    MMM                    3M     reports
# 1             1    AOS           A. O. Smith     reports
# 2             2    ABT                Abbott     reports
# 3             3   ABBV                AbbVie     reports
# 4             4   ABMD               Abiomed     reports
# ..          ...    ...                   ...         ...
# 497         497    YUM           Yum! Brands     reports
# 498         498   ZBRA    Zebra Technologies     reports
# 499         499    ZBH         Zimmer Biomet     reports
# 500         500   ZION  Zions Bancorporation     reports
# 501         501    ZTS                Zoetis     reports
#
#                 GICS Sector                   GICS Sub-Industry  \
# 0               Industrials            Industrial Conglomerates
# 1               Industrials                   Building Products
# 2               Health Care               Health Care Equipment
# 3               Health Care                     Pharmaceuticals
# 4               Health Care               Health Care Equipment
# ..                      ...                                 ...
# 497  Consumer Discretionary                         Restaurants
# 498  Information Technology  Electronic Equipment & Instruments
# 499             Health Care               Health Care Equipment
# 500              Financials                      Regional Banks
# 501             Health Care                     Pharmaceuticals
#
#        Headquarters Location Date first added      CIK      Founded  \
# 0      Saint Paul, Minnesota           8/9/76    66740         1902
# 1       Milwaukee, Wisconsin          7/26/17    91142         1916
# 2    North Chicago, Illinois          3/31/64     1800         1888
# 3    North Chicago, Illinois         12/31/12  1551152  2013 (1888)
# 4     Danvers, Massachusetts          5/31/18   815094         1981
# ..                       ...              ...      ...          ...
# 497     Louisville, Kentucky          10/6/97  1041061         1997
# 498   Lincolnshire, Illinois         12/23/19   877212         1969
# 499          Warsaw, Indiana           8/7/01  1136869         1927
# 500     Salt Lake City, Utah          6/22/01   109380         1873
# 501   Parsippany, New Jersey          6/21/13  1555280         1952
#
#                                              Wiki Link  \
# 0                     https://en.wikipedia.org/wiki/3M
# 1            https://en.wikipedia.org/wiki/A._O._Smith
# 2    https://en.wikipedia.org/wiki/Abbott_Laboratories
# 3                 https://en.wikipedia.org/wiki/AbbVie
# 4                https://en.wikipedia.org/wiki/Abiomed
# ..                                                 ...
# 497          https://en.wikipedia.org/wiki/Yum!_Brands
# 498   https://en.wikipedia.org/wiki/Zebra_Technologies
# 499        https://en.wikipedia.org/wiki/Zimmer_Biomet
# 500  https://en.wikipedia.org/wiki/Zions_Bancorpora...
# 501               https://en.wikipedia.org/wiki/Zoetis
#
#                    Official Website                             Twitter URL  \
# 0               https://www.3m.com/                  https://twitter.com/3M
# 1                http://aosmith.com     https://twitter.com/aosmithhotwater
# 2             http://www.abbott.com          https://twitter.com/AbbottNews
# 3                 http://abbvie.com              https://twitter.com/abbvie
# 4                http://abiomed.com             https://twitter.com/abiomed
# ..                              ...                                     ...
# 497             https://www.yum.com           https://twitter.com/yumbrands
# 498            http://www.zebra.com  http://www.twitter.com/zebratechnology
# 499         http://zimmerbiomet.com        https://twitter.com/zimmerbiomet
# 500  http://zionsbancorporation.com                                     NaN
# 501         https://www.zoetis.com/              https://twitter.com/zoetis
#
#       Twitter Handle  Subsidiary
# 0                 3M       False
# 1    aosmithhotwater       False
# 2         AbbottNews       False
# 3             abbvie       False
# 4            abiomed       False
# ..               ...         ...
# 497        yumbrands       False
# 498  zebratechnology       False
# 499     zimmerbiomet       False
# 500              NaN       False
# 501           zoetis       False
#
# [502 rows x 15 columns]

# %%
# For each row of dataframe, find all Twitter URLs on company official website
# Save in dictionary mapping from company Symbol to set of (Twitter URL, Twitter handle) tuples found on that company's official website
for row in df_manual.itertuples():
    get_twitters_from_website(row.Symbol, row._12) # _12 corresponds to the dataframe's Official Website column
    # print(row.Symbol)
    
# symbol_to_twitters_map
# Out:
# /Users/michellelum/anaconda3/envs/econtext/lib/python3.8/site-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(

# %% [markdown]
# Now it's time to add a new row for each subsidiary's Twitter account to our dataframe!
# Let's make a copy of our dataframe.

# %%
import warnings
warnings.filterwarnings('ignore') # ignore warnings about append

df_manual_subsidiaries = df_manual.copy(deep=True)

for symbol in symbol_to_twitters_map:
    if symbol == "TWTR":
        # Twitter has a bunch of Twitter URLs on its website that aren't subsidiaries -> skip Twitter
        continue
        
    twitter_tuples = symbol_to_twitters_map[symbol]
    num_twitters_scraped = len(twitter_tuples)
    
    # If a single Twitter account was scraped, that's probably just the parent company's Twitter account,
    # which is already in our dataframe, so we don't want to add a new row for that.
    if num_twitters_scraped > 1:
        # Get index of the parent company's row by finding the first row that matches the company Symbol
        parent_company_row_index = df_manual.loc[df_manual["Symbol"] == symbol].index[0]
        
        # Copy that old parent company row to a new subsidiary row
        parent_company_row = df_manual.loc[parent_company_row_index]
        subsidiary_row = parent_company_row.copy()
        
        # Iterate thru the (Twitter URL, Twitter Handle) tuples for this parent company
        for twitter_url, twitter_handle in twitter_tuples:
            if twitter_url != parent_company_row["Twitter URL"] and twitter_handle.lower() != parent_company_row["Twitter Handle"].lower():
                # It's a subsidiary Twitter URL, not the parent Twitter URL!
                # Update the Twitter URL, Twitter Handle, and Subsidiary columns for the new row
                subsidiary_row["Twitter URL"] = twitter_url
                subsidiary_row["Twitter Handle"] = twitter_handle
                subsidiary_row["Subsidiary"] = True
                        
                # Add subsidiary as new row in df
                df_manual_subsidiaries = df_manual_subsidiaries.append(subsidiary_row)

# %%
# Sort dataframe alphabetically, primarily by company Security, and secondarily by Subsidiary column value
# The lambda function ensures that the sort is case-insensitive
# So that parent companies and their subsidiaries are in consecutive rows
df_manual_subsidiaries["Subsidiary"] = df_manual_subsidiaries["Subsidiary"].map({True: 'True', False: 'False'}) # convert Subsidiary column to strings to do the sorting
df_manual_subsidiaries = df_manual_subsidiaries.sort_values(["Security", "Subsidiary"], key=lambda col: col.str.lower())
df_manual_subsidiaries["Subsidiary"] = df_manual_subsidiaries["Subsidiary"].map({'True': True, 'False': False}) # convert Subsidiary column back to bools

# Save as CSV
df_manual_subsidiaries.to_csv("sp_500_twitter_subsidiaries.csv")

# %%
# Subtract 1 because 1 row is the column headings
print("Number of rows in original df: ", len(df_manual) - 1)
print("Number of rows in new df: ", len(df_manual_subsidiaries) - 1)
# Out:
# Number of rows in original df:  501
# Number of rows in new df:  558

# %% [markdown]
# Looks like we found 57 new Twitter accounts! Does this mean 57 potential subsidiaries?
#
# We may want to manually check to ensure that these aren't people (ex: CEOs) or unrelated Twitter accounts

# %%
df_subsidiaries_actually_manual = pd.read_csv('sp_500_twitter_subsidiaries_manual.csv')
print("Number of rows in manually corrected df: ", len(df_subsidiaries_actually_manual) - 1)
# Out:
# Number of rows in manually corrected df:  527

# %% [markdown]
# From our manual corrections, it looks like we actually found just 26 new subsidiaries with Twitter accounts. Still not bad!

# %% [markdown]
# #### Drop Rows with Duplicate Twitter Handles
#
# To avoid replicating the same tweets in our dataset!

# %%
# Read in our manually updated CSV with subsidiary Twitters. Make a copy of this CSV!
df_with_duplicates = pd.read_csv('sp_500_twitter_subsidiaries_manual.csv')
df_no_duplicates = df_with_duplicates.copy(deep=True)

# %%
# Drop duplicates (rows that have the same Twitter Handle values) except for the first occurrence,
# and don't drop any rows that have a null value for the Twitter Handle column.
df_no_duplicates = df_with_duplicates[(~df_with_duplicates['Twitter Handle'].duplicated()) | df_with_duplicates['Twitter Handle'].isna()]

# df_no_duplicates = df_no_duplicates.drop_duplicates(subset='Twitter Handle')

df_no_duplicates
# Out:
#      Unnamed: 0.1  Unnamed: 0 Symbol              Security SEC filings  \
# 0               0           0    MMM                    3M     reports
# 1               1           1    AOS           A. O. Smith     reports
# 2               2           2    ABT                Abbott     reports
# 3               3           3   ABBV                AbbVie     reports
# 4               4           4   ABMD               Abiomed     reports
# ..            ...         ...    ...                   ...         ...
# 528           497         497    YUM           Yum! Brands     reports
# 529           498         498   ZBRA    Zebra Technologies     reports
# 530           499         499    ZBH         Zimmer Biomet     reports
# 531           500         500   ZION  Zions Bancorporation     reports
# 532           501         501    ZTS                Zoetis     reports
#
#                 GICS Sector                   GICS Sub-Industry  \
# 0               Industrials            Industrial Conglomerates
# 1               Industrials                   Building Products
# 2               Health Care               Health Care Equipment
# 3               Health Care                     Pharmaceuticals
# 4               Health Care               Health Care Equipment
# ..                      ...                                 ...
# 528  Consumer Discretionary                         Restaurants
# 529  Information Technology  Electronic Equipment & Instruments
# 530             Health Care               Health Care Equipment
# 531              Financials                      Regional Banks
# 532             Health Care                     Pharmaceuticals
#
#        Headquarters Location Date first added      CIK      Founded  \
# 0      Saint Paul, Minnesota           8/9/76    66740         1902
# 1       Milwaukee, Wisconsin          7/26/17    91142         1916
# 2    North Chicago, Illinois          3/31/64     1800         1888
# 3    North Chicago, Illinois         12/31/12  1551152  2013 (1888)
# 4     Danvers, Massachusetts          5/31/18   815094         1981
# ..                       ...              ...      ...          ...
# 528     Louisville, Kentucky          10/6/97  1041061         1997
# 529   Lincolnshire, Illinois         12/23/19   877212         1969
# 530          Warsaw, Indiana           8/7/01  1136869         1927
# 531     Salt Lake City, Utah          6/22/01   109380         1873
# 532   Parsippany, New Jersey          6/21/13  1555280         1952
#
#                                              Wiki Link  \
# 0                     https://en.wikipedia.org/wiki/3M
# 1            https://en.wikipedia.org/wiki/A._O._Smith
# 2    https://en.wikipedia.org/wiki/Abbott_Laboratories
# 3                 https://en.wikipedia.org/wiki/AbbVie
# 4                https://en.wikipedia.org/wiki/Abiomed
# ..                                                 ...
# 528          https://en.wikipedia.org/wiki/Yum!_Brands
# 529   https://en.wikipedia.org/wiki/Zebra_Technologies
# 530        https://en.wikipedia.org/wiki/Zimmer_Biomet
# 531  https://en.wikipedia.org/wiki/Zions_Bancorpora...
# 532               https://en.wikipedia.org/wiki/Zoetis
#
#                    Official Website                             Twitter URL  \
# 0               https://www.3m.com/                  https://twitter.com/3M
# 1                http://aosmith.com     https://twitter.com/aosmithhotwater
# 2             http://www.abbott.com          https://twitter.com/AbbottNews
# 3                 http://abbvie.com              https://twitter.com/abbvie
# 4                http://abiomed.com             https://twitter.com/abiomed
# ..                              ...                                     ...
# 528             https://www.yum.com                 https://twitter.com/kfc
# 529            http://www.zebra.com  http://www.twitter.com/zebratechnology
# 530         http://zimmerbiomet.com        https://twitter.com/zimmerbiomet
# 531  http://zionsbancorporation.com                                     NaN
# 532         https://www.zoetis.com/              https://twitter.com/zoetis
#
#       Twitter Handle  Subsidiary
# 0                 3M       False
# 1    aosmithhotwater       False
# 2         AbbottNews       False
# 3             abbvie       False
# 4            abiomed       False
# ..               ...         ...
# 528              kfc        True
# 529  zebratechnology       False
# 530     zimmerbiomet       False
# 531              NaN       False
# 532           zoetis       False
#
# [532 rows x 16 columns]

# %%
# Save as CSV
df_no_duplicates.to_csv("sp_500_twitter_subsidiaries_manual_no_duplicates.csv")

# %%
# Subtract 1 because 1 row is the column headings
print("Number of rows in original df: ", len(df_with_duplicates) - 1)
print("Number of rows in new df: ", len(df_no_duplicates) - 1)
# Out:
# Number of rows in original df:  532
# Number of rows in new df:  531

# %% [markdown]
# It looks like we only dropped 1 row with duplicate Twitter Handles! That was Google, since it has Class A and Class B stocks that correspond to the same Twitter handle.

# %% [markdown]
# #### Getting Subsidiary Twitter Handles from Twitter Profile Mentions
#
# We decided to create a new row for each subsidiary listed on an S&P 500 company's Twitter profile. We excluded Twitter accounts that are for customer service / care (e.g. ask, help, or support Twitter accounts), Twitter accounts that are for specific teams within the company (e.g. engineering), Twitter accounts for countries outside the U.S., and Twitter accounts mentioned that aren't actually subsidiaries (e.g. organizations that the company sponsors but does not own).
#
# 1. Manually grab subsidiaries from the `mentions` column of `data/sp_500_twitter_profile_info.csv`. Map each original company Twitter handle from `data/sp_500_twitter_profile_info.csv` to a list of Twitter handles of the Twitter accounts mentioned in the original company's Twitter profile.

# %%
df_no_duplicates = pd.read_csv('sp_500_twitter_subsidiaries_manual_no_duplicates.csv')

# %%
# Map each original company Twitter handle to a list of its and its mentioned subsidiaries' Twitter handles
handle_to_subsidiary_mentions_map = {'ATVI_AB': ['activision', 'blizzard_ent', 'king_games'],
                                     'AlignTechInc': ['Invisalign', 'exocad', 'iTeroScanner'],
                                     'amazon': ['AmazonNews'],
                                     'BioRadFlowAbs': ['BioRadCellBio'],
                                     'BookingHoldings': ['bookingcom', 'kayak', 'priceline', 'opentable', 'agoda'],
                                     'Campbells': ['CampbellSoupCo'],
                                     'CharterNewsroom': ['SpectrumBiz'],
                                     'ChubbNA': ['Chubb'],
                                     'Cisco': ['HeyCisco'],
                                     'edisonintl': ['SCE', 'Edison_Energy'],
                                     'ExpediaGroup': ['expedia', 'travelocity', 'orbitz', 'hotelsdotcom', 'hotwire', 'vrbo', 'expediamedia'],
                                     'FBHS_News': ['Moen', 'ThermaTru', 'FiberonDecking', 'LarsonDoors', 'MasterLockUS'],
                                     'Intuit': ['TurboTax', 'CreditKarma', 'QuickBooks', 'Mailchimp'],
                                     'roberthalf': ['Protiviti'],
                                     'NewsfromRCgroup': ['RoyalCaribbean', 'CelebrityCruise', 'Silversea', 'TUICruises', 'hlcruises'],
                                     'ServiceNow': ['ServiceNowNews']}

# %% [markdown]
# Now it's time to add a new row for each mentioned subsidiary's Twitter account to our dataframe! Let's make a copy of our dataframe.

# %%
import warnings
warnings.filterwarnings('ignore') # ignore warnings about append

df_subsidiaries_manual_mentioned = df_no_duplicates.copy(deep=True)

mentioned_subsidiaries_count = 0
for handle in handle_to_subsidiary_mentions_map:  
    twitter_handles_mentioned = handle_to_subsidiary_mentions_map[handle]

    # Get index of the parent company's row by finding the first row that matches the company Twitter Handle
    parent_company_row_index = df_no_duplicates.loc[df_no_duplicates["Twitter Handle"].str.lower() == handle.lower()].index[0]

    # Copy that old parent company row to a new subsidiary row
    parent_company_row = df_no_duplicates.loc[parent_company_row_index]
    subsidiary_row = parent_company_row.copy()

    # Iterate thru the Twitter Handles mentioned in this parent company's Twitter profile
    for twitter_handle in twitter_handles_mentioned:
        mentioned_subsidiaries_count += 1
        # Update the Twitter URL, Twitter Handle, and Subsidiary columns for the new row
        subsidiary_row["Twitter URL"] = "https://twitter.com" + twitter_handle
        subsidiary_row["Twitter Handle"] = twitter_handle
        subsidiary_row["Subsidiary"] = True

        # Add subsidiary as new row in df
        df_subsidiaries_manual_mentioned = df_subsidiaries_manual_mentioned.append(subsidiary_row)

print("Number of mentioned subsidiaries:", mentioned_subsidiaries_count)
# Out:
# Number of mentioned subsidiaries: 42

# %%
# Sort dataframe alphabetically, primarily by company Security, and secondarily by Subsidiary column value
# The lambda function ensures that the sort is case-insensitive
# So that parent companies and their subsidiaries are in consecutive rows
df_subsidiaries_manual_mentioned["Subsidiary"] = df_subsidiaries_manual_mentioned["Subsidiary"].map({True: 'True', False: 'False'}) # convert Subsidiary column to strings to do the sorting
df_subsidiaries_manual_mentioned = df_subsidiaries_manual_mentioned.sort_values(["Security", "Subsidiary"], key=lambda col: col.str.lower())
df_subsidiaries_manual_mentioned["Subsidiary"] = df_subsidiaries_manual_mentioned["Subsidiary"].map({'True': True, 'False': False}) # convert Subsidiary column back to bools

# %%
# Subtract 1 because 1 row is the column headings
print("Number of rows in original df: ", len(df_no_duplicates) - 1)
print("Number of rows in new df: ", len(df_subsidiaries_manual_mentioned) - 1)
# Out:
# Number of rows in original df:  531
# Number of rows in new df:  573

# %% [markdown]
# Looks like we found 43 new Twitter accounts from mentions in parent company Twitter profiles!

# %% [markdown]
# Let's drop any rows with duplicate Twitter handles, in case there are any.

# %%
# Drop duplicates (rows that have the same Twitter Handle values) except for the first occurrence,
# and don't drop any rows that have a null value for the Twitter Handle column.
df_subsidiaries_manual_mentioned = df_subsidiaries_manual_mentioned[(~df_subsidiaries_manual_mentioned['Twitter Handle'].duplicated()) | df_subsidiaries_manual_mentioned['Twitter Handle'].isna()]

print("Number of rows in de-duplicated df: ", len(df_subsidiaries_manual_mentioned) - 1)
# Out:
# Number of rows in de-duplicated df:  573

# %%
# Save as CSV
df_subsidiaries_manual_mentioned.to_csv("sp_500_twitter_subsidiaries_manual_mentioned.csv")

# %% [markdown]
# #### Getting Twitter Handles from Mergr

# %% [markdown]
# Using a CSV of the first 250 U.S. public companies, sorted by revenue.

# %%
# Read CSV of Mergr companies
df_mergr = pd.read_csv('mergr_11-21-22_by_revenue.csv')
print(len(df_mergr))
# Out:
# 250

# %% [markdown]
# Remove the Mergr df rows for companies already in our S&P 500 CSV. Note that this may not catch all duplicate companies, since their names may be listed slightly differently on the S&P 500 CSV and the Mergr CSV.

# %%
df_sp_500 = pd.read_csv('sp_500_twitter_subsidiaries_manual_mentioned.csv')
sp_500_company_names = df_sp_500['Security']

# %%
df_mergr = df_mergr[~df_mergr['Name'].isin(sp_500_company_names)]
print(len(df_mergr))
# Out:
# 131

# %% [markdown]
# Looks like, based on direct name matching, 131 of the 250 Mergr companies are not already in the S&P 500 CSV.

# %% [markdown]
# Add Twitter URLs to the dataframe.

# %%
# Get Twitter URLs from Mergr company websites.
df_mergr_twitter = df_mergr.copy(deep=True)
df_mergr_twitter['Twitter URL'] = df_mergr_twitter.apply(lambda row: get_twitter_from_website(row['Url'], mergr=True), axis=1)
df_mergr_twitter
# Out:
# www.apple.com
# Scraping https://www.apple.com
# Request succeeded but Twitter not found
# www.corporate.exxonmobil.com
# Request failed
# www.abc.xyz
# Scraping https://www.abc.xyz
# Request succeeded but Twitter not found
# www.unitedhealthgroup.com
# Scraping https://www.unitedhealthgroup.com
# www.costco.com
# Scraping https://www.costco.com
# Request succeeded but Twitter not found
# www.walgreensbootsalliance.com
# Scraping https://www.walgreensbootsalliance.com
# www.ford.com
# Scraping https://www.ford.com
# www.homedepot.com
# Scraping https://www.homedepot.com
# www.centene.com
# Scraping https://www.centene.com
# www.gm.com
# Scraping https://www.gm.com
# Request succeeded but Twitter not found
# www.marathonpetroleum.com
# Scraping https://www.marathonpetroleum.com
# Request succeeded but Twitter not found
# www.facebook.com
# Scraping https://www.facebook.com
# Request succeeded but Twitter not found
# www.delltechnologies.com
# Scraping https://www.delltechnologies.com
# www.ups.com
# Scraping https://www.ups.com
# Request succeeded but Twitter not found
# www.chevron.com
# Scraping https://www.chevron.com
# www.targetcorp.com
# Request failed
# www.citigroup.com
# Scraping https://www.citigroup.com
# Request succeeded but Twitter not found
# www.energytransfer.com
# Scraping https://www.energytransfer.com
# Request succeeded but Twitter not found
# www.thewaltdisneycompany.com
# Scraping https://www.thewaltdisneycompany.com
# www.valero.com
# Scraping https://www.valero.com
# www.hp.com
# Scraping https://www.hp.com
# www.bunge.com
# Scraping https://www.bunge.com
# Request succeeded but Twitter not found
# www.stonex.com
# Scraping https://www.stonex.com
# www.aig.com
# Scraping https://www.aig.com
# www.caterpillar.com
# Scraping https://www.caterpillar.com
# www.cisco.com
# Scraping https://www.cisco.com
# www.merck.com
# Scraping https://www.merck.com
# www.bms.com
# Scraping https://www.bms.com
# www.goldmansachs.com
# Scraping https://www.goldmansachs.com
# Request succeeded but Twitter not found
# nikeinc.com
# Scraping https://nikeinc.com
# Request succeeded but Twitter not found
# www.deere.com
# Scraping https://www.deere.com
# www.tysonfoods.com
# Scraping https://www.tysonfoods.com
# www.abbott.com
# Scraping https://www.abbott.com
# www.progressive.com
# Scraping https://www.progressive.com
# www.oracle.com
# Scraping https://www.oracle.com
# Request succeeded but Twitter not found
# www.tjx.com
# Scraping https://www.tjx.com
# Request succeeded but Twitter not found
# www.enterpriseproducts.com
# Scraping https://www.enterpriseproducts.com
# Request succeeded but Twitter not found
# www.coca-colacompany.com
# Scraping https://www.coca-colacompany.com
# Request succeeded but Twitter not found
# www.dow.com
# Scraping https://www.dow.com
# www.arrow.com
# Scraping https://www.arrow.com
# www.honeywell.com
# Scraping https://www.honeywell.com
# www.chsinc.com
# Scraping https://www.chsinc.com
# www.travelers.com
# Scraping https://www.travelers.com
# www.tesla.com
# Scraping https://www.tesla.com
# Request succeeded but Twitter not found
# www.delta.com
# Scraping https://www.delta.com
# Request succeeded but Twitter not found
# www.danaher.com
# Scraping https://www.danaher.com
# Request succeeded but Twitter not found
# www.jabil.com
# Scraping https://www.jabil.com
# www.lilly.com
# Scraping https://www.lilly.com
# Request succeeded but Twitter not found
# www.hpe.com
# Scraping https://www.hpe.com
# www.cbre.com
# Scraping https://www.cbre.com
# Request succeeded but Twitter not found
# www.micron.com
# Scraping https://www.micron.com
# www.broadcom.com
# Scraping https://www.broadcom.com
# Request succeeded but Twitter not found
# www.nrg.com
# Scraping https://www.nrg.com
# Request succeeded but Twitter not found
# www.nvidia.com
# Scraping https://www.nvidia.com
# www.unfi.com
# Scraping https://www.unfi.com
# Request succeeded but Twitter not found
# www.macysinc.com
# Scraping https://www.macysinc.com
# www.paramount.com
# Scraping https://www.paramount.com
# www.pfgc.com
# Scraping https://www.pfgc.com
# Request succeeded but Twitter not found
# www.synnexcorp.com
# Scraping https://www.synnexcorp.com
# Request succeeded but Twitter not found
# www.united.com
# Scraping https://www.united.com
# Request succeeded but Twitter not found
# www.riteaid.com
# Scraping https://www.riteaid.com
# www.plainsallamerican.com
# Scraping https://www.plainsallamerican.com
# Request succeeded but Twitter not found
# www.usbank.com
# Scraping https://www.usbank.com
# www.usfoods.com
# Scraping https://www.usfoods.com
# www.lithiainvestorrelations.com
# Scraping https://www.lithiainvestorrelations.com
# www.whirlpoolcorp.com
# Scraping https://www.whirlpoolcorp.com
# www.aflac.com
# Scraping https://www.aflac.com
# www.usa.visa.com
# Scraping https://www.usa.visa.com
# Request succeeded but Twitter not found
# www.aersale.com
# Scraping https://www.aersale.com
# www.manpowergroup.com
# Scraping https://www.manpowergroup.com
# www.penskeautomotive.com
# Scraping https://www.penskeautomotive.com
# www.autonation.com
# Scraping https://www.autonation.com
# www.southerncompany.com
# Scraping https://www.southerncompany.com
# www.wfscorp.com
# Scraping https://www.wfscorp.com
# Request succeeded but Twitter not found
# www.thehartford.com
# Scraping https://www.thehartford.com
# www.mmc.com
# Scraping https://www.mmc.com
# www.lumen.com
# Scraping https://www.lumen.com
# www.up.com
# Scraping https://www.up.com
# Request succeeded but Twitter not found
# www.Kohls.com
# Scraping https://www.Kohls.com
# www.jll.com
# Scraping https://www.jll.com
# www.lear.com
# Scraping https://www.lear.com
# www.pnc.com
# Scraping https://www.pnc.com
# www.mastercard.com
# Scraping https://www.mastercard.com
# Request succeeded but Twitter not found
# www.genpt.com
# Scraping https://www.genpt.com
# www.paccar.com
# Scraping https://www.paccar.com
# Request succeeded but Twitter not found
# www.kyndryl.com
# Scraping https://www.kyndryl.com
# www.pgecorp.com
# Scraping https://www.pgecorp.com
# Request succeeded but Twitter not found
# www.hfsinclair.com
# Scraping https://www.hfsinclair.com
# Request succeeded but Twitter not found
# www.emerson.com
# Scraping https://www.emerson.com
# www.landosbiopharma.com
# Scraping https://www.landosbiopharma.com
# www.dish.com
# Scraping https://www.dish.com
# www.oxy.com
# Scraping https://www.oxy.com
# www.tenethealth.com
# Scraping https://www.tenethealth.com
# Request succeeded but Twitter not found
# www.avnet.com
# Scraping https://www.avnet.com
# www.lfg.com
# Scraping https://www.lfg.com
# Request succeeded but Twitter not found
# www.carrier.com
# Scraping https://www.carrier.com
# www.aa.com
# Scraping https://www.aa.com
# www.stryker.com
# Scraping https://www.stryker.com
# Request succeeded but Twitter not found
# www.aep.com
# Scraping https://www.aep.com
# www.bjs.com
# Scraping https://www.bjs.com
# www.expeditors.com
# Scraping https://www.expeditors.com
# www.xpo.com
# Scraping https://www.xpo.com
# www.chrobinson.com
# Scraping https://www.chrobinson.com
# www.adobe.com
# Scraping https://www.adobe.com
# Request succeeded but Twitter not found
# www.rocketcompanies.com
# Scraping https://www.rocketcompanies.com
# www.synchrony.com
# Scraping https://www.synchrony.com
# www.fnf.com
# Scraping https://www.fnf.com
# Request succeeded but Twitter not found
# www.dteenergy.com
# Scraping https://www.dteenergy.com
# www.nordstrom.com
# Scraping https://www.nordstrom.com
# Request succeeded but Twitter not found
# www.principal.com
# Scraping https://www.principal.com
# Request succeeded but Twitter not found
# www.rgare.com
# Scraping https://www.rgare.com
# www.itw.com
# Scraping https://www.itw.com
# Request succeeded but Twitter not found
# www.elcompanies.com
# Scraping https://www.elcompanies.com
# www.kelloggcompany.com
# Scraping https://www.kelloggcompany.com
# www.qurateretail.com
# Scraping https://www.qurateretail.com
# Request succeeded but Twitter not found
# www.wayfair.com
# Scraping https://www.wayfair.com
# Request succeeded but Twitter not found
# www.jacobs.com
# Scraping https://www.jacobs.com
# www.corning.com
# Scraping https://www.corning.com
# www.fisglobal.com
# Scraping https://www.fisglobal.com
# www.marriott.com
# Scraping https://www.marriott.com
# www.berryglobal.com
# Request failed
# www.ppg.com
# Scraping https://www.ppg.com
# www.ball.com
# Scraping https://www.ball.com
# www.gapinc.com
# Scraping https://www.gapinc.com
# www.loews.com
# Scraping https://www.loews.com
# Request succeeded but Twitter not found
# www.aecom.com
# Scraping https://www.aecom.com
# www.lkqcorp.com
# Scraping https://www.lkqcorp.com
# www.markel.com
# Scraping https://www.markel.com
# www.foxcorporation.com
# Scraping https://www.foxcorporation.com
# Request succeeded but Twitter not found
# www.carvana.com
# Scraping https://www.carvana.com
# www.otis.com
# Scraping https://www.otis.com
#                  Name                          Sector  \
# 2               Apple             Technology Hardware
# 5               Exxon             Oil/Gas Exploration
# 6              Google  Internet Software and Services
# 7        UnitedHealth             Healthcare Services
# 12   Costco Wholesale                          Retail
# ..                ...                             ...
# 242               LKQ                      Automotive
# 243            Markel                       Insurance
# 244               Fox                           Media
# 245           Carvana                      E-Commerce
# 247              OTIS                       Machinery
#
#                                            Address           City  \
# 2                                  1 Infinite Loop      Cupertino
# 5                       5959 Las Colinas Boulevard         Irving
# 6                        1600 Amphitheatre Parkway  Mountain View
# 7    UnitedHealth Group Center 9900 Bren Road East     Minnetonka
# 12                                     999 Lake Dr       Issaquah
# ..                                             ...            ...
# 242            500 West Madison Street, Suite 2800        Chicago
# 243                        4521 Highwoods Parkway      Glen Allen
# 244                    1211 Avenue of the Americas       New York
# 245                   1930 West Rio Salado Parkway          Tempe
# 247                                1 Carrier Place     Farmington
#
#     State or Province    Zip        Country           Phone  \
# 2          California  95014  United States  (408) 996-1010
# 5               Texas  75039  United States  (972) 940-6000
# 6          California  94043  United States  (650) 253-0000
# 7           Minnesota  55343  United States  (952) 936-1300
# 12         Washington  98027  United States  (425) 313-8100
# ..                ...    ...            ...             ...
# 242          Illinois  60661  United States  (312) 621-1950
# 243          Virginia  23060  United States  (804) 747-0136
# 244          New York  10036  United States  (212) 852-7000
# 245           Arizona  85281  United States  (480) 719-8809
# 247       Connecticut   6032  United States  (800) 233-6847
#
#                               Url Revenue ($mlns)  Employees Ownership Status  \
# 2                   www.apple.com         365,817     150000           Public
# 5    www.corporate.exxonmobil.com         276,692      63000           Public
# 6                     www.abc.xyz         257,637     139995           Public
# 7       www.unitedhealthgroup.com         255,639     330000           Public
# 12                 www.costco.com         166,761     156000           Public
# ..                            ...             ...        ...              ...
# 242               www.lkqcorp.com          13,089      46000           Public
# 243                www.markel.com          12,910      20300           Public
# 244        www.foxcorporation.com          12,909       9000           Public
# 245               www.carvana.com          12,814      21000           Public
# 247                  www.otis.com          12,756      69000           Public
#
#     Investors/Acquirers  Buy M&A Count - Total  \
# 2                   NaN                  108.0
# 5                   NaN                    8.0
# 6                   NaN                  221.0
# 7                   NaN                   16.0
# 12                  NaN                    3.0
# ..                  ...                    ...
# 242                 NaN                   44.0
# 243   Alliance Holdings                   13.0
# 244                 NaN                    4.0
# 245                 NaN                    3.0
# 247                 NaN                    5.0
#
#      Avg. Buy Count Per Year (Last 5 Yrs)  Sell M&A Count - Total  \
# 2                                     3.8                     2.0
# 5                                     NaN                     6.0
# 6                                     4.0                     6.0
# 7                                     0.6                     2.0
# 12                                    0.4                     NaN
# ..                                    ...                     ...
# 242                                   0.6                     3.0
# 243                                   1.0                     NaN
# 244                                   0.8                     NaN
# 245                                   0.4                     NaN
# 247                                   0.2                     NaN
#
#      Avg. Sell Count Per Year (Last 5 Yrs)  \
# 2                                      NaN
# 5                                      0.4
# 6                                      0.2
# 7                                      NaN
# 12                                     NaN
# ..                                     ...
# 242                                    0.2
# 243                                    NaN
# 244                                    NaN
# 245                                    NaN
# 247                                    NaN
#
#                              Twitter URL
# 2                                   None
# 5                                   None
# 6                                   None
# 7    https://twitter.com/UnitedHealthGrp
# 12                                  None
# ..                                   ...
# 242          https://twitter.com/LKQCorp
# 243      https://twitter.com/MarkelStyle
# 244                                 None
# 245          https://twitter.com/carvana
# 247   https://twitter.com/OtisElevatorCo
#
# [131 rows x 18 columns]

# %% [markdown]
# Use the Twitter URL to Twitter handle map to add Twitter handles to the dataframe.

# %%
df_mergr_twitter['Twitter Handle'] = df_mergr_twitter.apply(lambda row: get_handle_from_twitter_url(row), axis=1)
df_mergr_twitter
# Out:
#                  Name                          Sector  \
# 2               Apple             Technology Hardware
# 5               Exxon             Oil/Gas Exploration
# 6              Google  Internet Software and Services
# 7        UnitedHealth             Healthcare Services
# 12   Costco Wholesale                          Retail
# ..                ...                             ...
# 242               LKQ                      Automotive
# 243            Markel                       Insurance
# 244               Fox                           Media
# 245           Carvana                      E-Commerce
# 247              OTIS                       Machinery
#
#                                            Address           City  \
# 2                                  1 Infinite Loop      Cupertino
# 5                       5959 Las Colinas Boulevard         Irving
# 6                        1600 Amphitheatre Parkway  Mountain View
# 7    UnitedHealth Group Center 9900 Bren Road East     Minnetonka
# 12                                     999 Lake Dr       Issaquah
# ..                                             ...            ...
# 242            500 West Madison Street, Suite 2800        Chicago
# 243                        4521 Highwoods Parkway      Glen Allen
# 244                    1211 Avenue of the Americas       New York
# 245                   1930 West Rio Salado Parkway          Tempe
# 247                                1 Carrier Place     Farmington
#
#     State or Province    Zip        Country           Phone  \
# 2          California  95014  United States  (408) 996-1010
# 5               Texas  75039  United States  (972) 940-6000
# 6          California  94043  United States  (650) 253-0000
# 7           Minnesota  55343  United States  (952) 936-1300
# 12         Washington  98027  United States  (425) 313-8100
# ..                ...    ...            ...             ...
# 242          Illinois  60661  United States  (312) 621-1950
# 243          Virginia  23060  United States  (804) 747-0136
# 244          New York  10036  United States  (212) 852-7000
# 245           Arizona  85281  United States  (480) 719-8809
# 247       Connecticut   6032  United States  (800) 233-6847
#
#                               Url Revenue ($mlns)  Employees Ownership Status  \
# 2                   www.apple.com         365,817     150000           Public
# 5    www.corporate.exxonmobil.com         276,692      63000           Public
# 6                     www.abc.xyz         257,637     139995           Public
# 7       www.unitedhealthgroup.com         255,639     330000           Public
# 12                 www.costco.com         166,761     156000           Public
# ..                            ...             ...        ...              ...
# 242               www.lkqcorp.com          13,089      46000           Public
# 243                www.markel.com          12,910      20300           Public
# 244        www.foxcorporation.com          12,909       9000           Public
# 245               www.carvana.com          12,814      21000           Public
# 247                  www.otis.com          12,756      69000           Public
#
#     Investors/Acquirers  Buy M&A Count - Total  \
# 2                   NaN                  108.0
# 5                   NaN                    8.0
# 6                   NaN                  221.0
# 7                   NaN                   16.0
# 12                  NaN                    3.0
# ..                  ...                    ...
# 242                 NaN                   44.0
# 243   Alliance Holdings                   13.0
# 244                 NaN                    4.0
# 245                 NaN                    3.0
# 247                 NaN                    5.0
#
#      Avg. Buy Count Per Year (Last 5 Yrs)  Sell M&A Count - Total  \
# 2                                     3.8                     2.0
# 5                                     NaN                     6.0
# 6                                     4.0                     6.0
# 7                                     0.6                     2.0
# 12                                    0.4                     NaN
# ..                                    ...                     ...
# 242                                   0.6                     3.0
# 243                                   1.0                     NaN
# 244                                   0.8                     NaN
# 245                                   0.4                     NaN
# 247                                   0.2                     NaN
#
#      Avg. Sell Count Per Year (Last 5 Yrs)  \
# 2                                      NaN
# 5                                      0.4
# 6                                      0.2
# 7                                      NaN
# 12                                     NaN
# ..                                     ...
# 242                                    0.2
# 243                                    NaN
# 244                                    NaN
# 245                                    NaN
# 247                                    NaN
#
#                              Twitter URL   Twitter Handle
# 2                                   None             None
# 5                                   None             None
# 6                                   None             None
# 7    https://twitter.com/UnitedHealthGrp  UnitedHealthGrp
# 12                                  None             None
# ..                                   ...              ...
# 242          https://twitter.com/LKQCorp          LKQCorp
# 243      https://twitter.com/MarkelStyle      MarkelStyle
# 244                                 None             None
# 245          https://twitter.com/carvana          carvana
# 247   https://twitter.com/OtisElevatorCo   OtisElevatorCo
#
# [131 rows x 19 columns]

# %% [markdown]
# Remove the Mergr df rows for Twitter handles already in our S&P 500 CSV. Do this in a case-insensitive way.

# %%
sp_500_twitter_handles = df_sp_500['Twitter Handle'].dropna()  # Drop nulls

# %%
df_mergr_twitter = df_mergr_twitter[~df_mergr_twitter['Twitter Handle'].str.lower().isin([sp_500_handle.lower() for sp_500_handle in sp_500_twitter_handles])]
print(len(df_mergr_twitter))
# Out:
# 85

# %% [markdown]
# Looks like, based on direct Twitter Handle matching, 85 of the 250 Mergr companies are either 1) not already in the S&P 500 CSV, or 2) we weren't able to scrape their Twitter handles.

# %%
len(df_mergr_twitter[df_mergr_twitter["Twitter URL"].isnull()])
# Out:
# 50

# %% [markdown]
# Looks like we have 50 companies for which we weren't able to extract Twitter URLs. Let's see what those companies are.

# %%
df_mergr_twitter[df_mergr_twitter["Twitter Handle"].isnull()]
# Out:
#                              Name                          Sector  \
# 2                           Apple             Technology Hardware
# 5                           Exxon             Oil/Gas Exploration
# 6                          Google  Internet Software and Services
# 12               Costco Wholesale                          Retail
# 21                             GM                      Automotive
# 23                       Marathon   Energy Services and Equipment
# 24                       Facebook  Internet Software and Services
# 27                            UPS                  Transportation
# 31                         Target                          Retail
# 41                           Citi              Financial Services
# 44                Energy Transfer   Energy Services and Equipment
# 52                          Bunge                     Agriculture
# 70        The Goldman Sachs Group              Financial Services
# 71                           Nike                Apparel/Textiles
# 77                         Oracle                        Software
# 78                            TJX                          Retail
# 79   Enterprise Products Partners             Oil/Gas Exploration
# 80                      Coca-Cola                       Beverages
# 94                          Tesla                      Automotive
# 95                          Delta                        Airlines
# 97                        Danaher                     Diversified
# 101                         Lilly                    Life Science
# 107                          CBRE                     Real Estate
# 109                      Broadcom                  Semiconductors
# 111                           NRG                       Utilities
# 113                          UNFI                    Distribution
# 119                           PFG                    Distribution
# 121                     TD SYNNEX               Business Services
# 122                        United                        Airlines
# 128           Plains All American   Energy Services and Equipment
# 138                          Visa              Financial Services
# 150           World Fuel Services   Energy Services and Equipment
# 156                 Union Pacific                  Transportation
# 163                    MasterCard              Financial Services
# 165                        PACCAR                      Automotive
# 169                          PG&E                       Utilities
# 170                   HF Sinclair             Oil/Gas Exploration
# 181                  Tenet Health             Healthcare Services
# 184       Lincoln Financial Group                       Insurance
# 188                       Stryker                Medical Products
# 201                         Adobe                        Software
# 208   Fidelity National Financial                       Insurance
# 213                     Nordstrom                          Retail
# 214                     Principal                       Insurance
# 219                           ITW                   Manufacturing
# 222                 Qurate Retail                      E-Commerce
# 224                       Wayfair                      E-Commerce
# 231                         Berry                        Plastics
# 235                         Loews                     Diversified
# 244                           Fox                           Media
#
#                                       Address           City  \
# 2                             1 Infinite Loop      Cupertino
# 5                  5959 Las Colinas Boulevard         Irving
# 6                   1600 Amphitheatre Parkway  Mountain View
# 12                                999 Lake Dr       Issaquah
# 21                     300 Renaissance Center        Detroit
# 23                      539 South Main Street        Findlay
# 24                           1601 Willow Road     Menlo Park
# 27                    55 Glenlake Parkway, NE        Atlanta
# 31                         1000 Nicollet Mall    Minneapolis
# 41                       388 Greenwich Street       New York
# 44          8111 Westchester Drive, Suite 600         Dallas
# 52              1391 Timberlake Manor Parkway      St. Louis
# 70                            200 West Street       New York
# 71                         One Bowerman Drive      Beaverton
# 77                            2300 Oracle Way         Austin
# 78                        770 Cochituate Road     Framingham
# 79          1100 Louisiana Street, 10th Floor        Houston
# 80                        One Coca-Cola Plaza        Atlanta
# 94                       3500 Deer Creek Road      Palo Alto
# 95                      Post Office Box 20706        Atlanta
# 97    2200 Pennsylvania Avenue, NW Suite 800W     Washington
# 101                    Lilly Corporate Center   Indianapolis
# 107          2100 McKinney Avenue, Suite 1250         Dallas
# 109                    1320 Ridder Park Drive       San Jose
# 111                      910 Louisiana Street        Houston
# 113                        313 Iron Horse Way     Providence
# 119                  12500 West Creek Parkway       Richmond
# 121                         44201 Nobel Drive        Fremont
# 122                    233 South Wacker Drive        Chicago
# 128               333 Clay Street, Suite 1600        Houston
# 138                               PO Box 8999  San Francisco
# 150     9800 Northwest 41st Street, Suite 400          Miami
# 156                       1400 Douglas Street          Omaha
# 163                      2000 Purchase Street       Purchase
# 165                       777-106th Avenue NE       Bellevue
# 169            77 Beale Street, PO Box 770000  San Francisco
# 170            2828 North Harwood, Suite 1300         Dallas
# 181                      14201 Dallas Parkway         Dallas
# 184  150 North Radnor Chester Road Suite A305          Radno
# 188                    2825 Airview Boulevard      Kalamazoo
# 201                           345 Park Avenue       San Jose
# 208                      601 Riverside Avenue   Jacksonville
# 213                         1617 Sixth Avenue        Seattle
# 214                           711 High Street     Des Moines
# 219                         155 Harlem Avenue       Glenview
# 222                       12300 Liberty Blvd.      Englewood
# 224                 4 Copley Place, 7th Floor         Boston
# 231                         101 Oakley Street     Evansville
# 235                        667 Madison Avenue       New York
# 244               1211 Avenue of the Americas       New York
#
#         State or Province    Zip        Country           Phone  \
# 2              California  95014  United States  (408) 996-1010
# 5                   Texas  75039  United States  (972) 940-6000
# 6              California  94043  United States  (650) 253-0000
# 12             Washington  98027  United States  (425) 313-8100
# 21               Michigan  48265  United States  (313) 667-1500
# 23                   Ohio  45840  United States  (419) 422-2121
# 24             California  94025  United States  (650) 543-4800
# 27                Georgia  30328  United States  (404) 828-6000
# 31              Minnesota  55403  United States  (612) 304-6073
# 41               New York  10013  United States  (212) 559-1000
# 44                  Texas  75225  United States  (214) 981-0700
# 52               Missouri  63017  United States  (314) 292-2000
# 70               New York  10282  United States  (212) 902-1000
# 71                 Oregon  97005  United States  (503) 671-6453
# 77                  Texas  78741  United States  (737) 867-1000
# 78          Massachusetts   1701  United States  (508) 390-1000
# 79                  Texas  77002  United States  (713) 381-6500
# 80                Georgia  30313  United States  (404) 676-2121
# 94             California  94304  United States  (650) 681-5000
# 95                Georgia  30320  United States  (404) 715-2600
# 97   District of Columbia  20037  United States  (202) 828-0850
# 101               Indiana  46285  United States  (317) 276-2000
# 107                 Texas  75201  United States  (214) 979-6100
# 109            California  95131  United States   +408 433 8000
# 111            New Jersey  77002  United States  (713) 537-3000
# 113          Rhode Island   2908  United States  (401) 528-8634
# 119              Virginia  23238  United States  (804) 484-7700
# 121            California  94538  United States  (510) 656-3333
# 122              Illinois  60606  United States  (872) 825-4000
# 128                 Texas  77002  United States  (713) 646-4100
# 138            California  94128  United States  (650) 432-3200
# 150               Florida  33178  United States  (305) 428-8000
# 156              Nebraska  68179  United States  (402) 544-5000
# 163              New York  10577  United States  (914) 249-2000
# 165            Washington  98004  United States  (425) 468-7400
# 169            California  94177  United States  (415) 973-1000
# 170                 Texas  75201  United States  (214) 871-3555
# 181                 Texas  75254  United States  (469) 893-2200
# 184          Pennsylvania  19087  United States  (484) 583-1400
# 188              Michigan  49002  United States  (269) 385-2600
# 201            California  95110  United States  (408) 536-6000
# 208               Florida  32204  United States  (904) 854-8100
# 213            Washington  98101  United States  (206) 628-2111
# 214                 Idaho  50392  United States  (515) 247-5111
# 219              Illinois  60025  United States  (847) 724-7500
# 222              Colorado  80112  United States  (720) 875-5300
# 224         Massachusetts   2116  United States  (617) 532-6100
# 231               Indiana  47710  United States  (812) 424-2904
# 235              New York  10065  United States  (212) 521-2000
# 244              New York  10036  United States  (212) 852-7000
#
#                               Url Revenue ($mlns)  Employees Ownership Status  \
# 2                   www.apple.com         365,817     150000           Public
# 5    www.corporate.exxonmobil.com         276,692      63000           Public
# 6                     www.abc.xyz         257,637     139995           Public
# 12                 www.costco.com         166,761     156000           Public
# 21                     www.gm.com         122,485     155000           Public
# 23      www.marathonpetroleum.com         119,983      17700           Public
# 24               www.facebook.com         117,929      77805           Public
# 27                    www.ups.com          97,287     273510           Public
# 31             www.targetcorp.com          93,561     409000           Public
# 41              www.citigroup.com          71,887     231000           Public
# 44         www.energytransfer.com          67,417      12558           Public
# 52                  www.bunge.com          59,152      22000           Public
# 70           www.goldmansachs.com          44,560      40500           Public
# 71                    nikeinc.com          44,538      73300           Public
# 77                 www.oracle.com          42,440     135000           Public
# 78                    www.tjx.com          41,717     320000           Public
# 79     www.enterpriseproducts.com          40,807          0           Public
# 80       www.coca-colacompany.com          38,660      80300           Public
# 94                  www.tesla.com          31,536      70757           Public
# 95                  www.delta.com          29,899      83000           Public
# 97                www.danaher.com          29,453      78000           Public
# 101                 www.lilly.com          28,318      35000           Public
# 107                  www.cbre.com          27,746     105000           Public
# 109              www.broadcom.com          27,450      20000           Public
# 111                   www.nrg.com          26,989       6635           Public
# 113                  www.unfi.com          26,514      28300           Public
# 119                  www.pfgc.com          25,086      20000           Public
# 121            www.synnexcorp.com          24,676      22000           Public
# 122                www.united.com          24,634      87000           Public
# 128     www.plainsallamerican.com          23,290       4400           Public
# 138              www.usa.visa.com          21,846      20500           Public
# 150               www.wfscorp.com          20,358       4300           Public
# 156                    www.up.com          19,533      29755           Public
# 163            www.mastercard.com          18,884      24000           Public
# 165                www.paccar.com          18,729      26000           Public
# 169               www.pgecorp.com          18,469      24000           Public
# 170            www.hfsinclair.com          18,389       4208           Public
# 181           www.tenethealth.com          17,640      85800           Public
# 184                   www.lfg.com          17,556      10848           Public
# 188               www.stryker.com          17,108      46000           Public
# 201                 www.adobe.com          15,785      22516           Public
# 208                   www.fnf.com          15,054      28290           Public
# 213             www.nordstrom.com          14,789      72000           Public
# 214             www.principal.com          14,742      17400           Public
# 219                   www.itw.com          14,455      45000           Public
# 222          www.qurateretail.com          14,177      26508           Public
# 224               www.wayfair.com          14,145      16200           Public
# 231           www.berryglobal.com          13,850      47000           Public
# 235                 www.loews.com          13,742      10340           Public
# 244        www.foxcorporation.com          12,909       9000           Public
#
#                                    Investors/Acquirers  Buy M&A Count - Total  \
# 2                                                  NaN                  108.0
# 5                                                  NaN                    8.0
# 6                                                  NaN                  221.0
# 12                                                 NaN                    3.0
# 21                                                 NaN                    4.0
# 23                                                 NaN                    2.0
# 24                                                 NaN                   83.0
# 27                                                 NaN                   19.0
# 31                                                 NaN                    9.0
# 41                                                 NaN                   16.0
# 44                                                 NaN                    9.0
# 52                                                 NaN                   10.0
# 70                                                 NaN                    7.0
# 71                                                 NaN                   11.0
# 77                                                 NaN                  131.0
# 78                                                 NaN                    5.0
# 79                                                 NaN                   19.0
# 80                                                 NaN                   18.0
# 94                                                 NaN                    6.0
# 95                                                 NaN                    2.0
# 97                                                 NaN                   41.0
# 101                                                NaN                   28.0
# 107                                                NaN                   45.0
# 109                                                NaN                   15.0
# 111                                                NaN                   15.0
# 113                                                NaN                    8.0
# 119                                                NaN                    6.0
# 121                           Apollo Global Management                   15.0
# 122                                                NaN                    3.0
# 128  Kayne Anderson Capital Advisors LP|First Reser...                    7.0
# 138                                                NaN                   14.0
# 150                                                NaN                   16.0
# 156                                                NaN                    5.0
# 163                                                NaN                   26.0
# 165                                                NaN                    2.0
# 169                                                NaN                    NaN
# 170                                                NaN                    4.0
# 181                                                NaN                    6.0
# 184                                                NaN                    3.0
# 188                                                NaN                   43.0
# 201                                                NaN                   53.0
# 208                                                NaN                   29.0
# 213                                                NaN                    7.0
# 214                                                NaN                    7.0
# 219                                                NaN                   48.0
# 222                                                NaN                    1.0
# 224                                                NaN                    3.0
# 231                                                NaN                   14.0
# 235                                                NaN                    1.0
# 244                                                NaN                    4.0
#
#      Avg. Buy Count Per Year (Last 5 Yrs)  Sell M&A Count - Total  \
# 2                                     3.8                     2.0
# 5                                     NaN                     6.0
# 6                                     4.0                     6.0
# 12                                    0.4                     NaN
# 21                                    NaN                     6.0
# 23                                    0.2                     2.0
# 24                                    3.2                     NaN
# 27                                    0.4                     4.0
# 31                                    0.2                     5.0
# 41                                    NaN                    18.0
# 44                                    0.6                     1.0
# 52                                    NaN                     4.0
# 70                                    0.4                     4.0
# 71                                    1.0                     5.0
# 77                                    2.0                     1.0
# 78                                    0.2                     1.0
# 79                                    0.4                     5.0
# 80                                    0.4                     8.0
# 94                                    0.4                     NaN
# 95                                    NaN                     1.0
# 97                                    0.8                     9.0
# 101                                   1.8                     9.0
# 107                                   1.6                     1.0
# 109                                   0.6                     8.0
# 111                                   0.2                     6.0
# 113                                   0.2                     NaN
# 119                                   0.6                     1.0
# 121                                   0.4                     NaN
# 122                                   NaN                     1.0
# 128                                   0.2                     2.0
# 138                                   1.6                     NaN
# 150                                   0.4                     1.0
# 156                                   0.6                     1.0
# 163                                   2.6                     NaN
# 165                                   NaN                     NaN
# 169                                   NaN                     NaN
# 170                                   0.6                     2.0
# 181                                   0.2                    10.0
# 184                                   0.2                     1.0
# 188                                   2.2                     5.0
# 201                                   1.6                     NaN
# 208                                   1.0                     8.0
# 213                                   0.4                     5.0
# 214                                   0.4                     NaN
# 219                                   0.2                    13.0
# 222                                   NaN                     NaN
# 224                                   NaN                     1.0
# 231                                   0.4                     2.0
# 235                                   NaN                     1.0
# 244                                   0.8                     NaN
#
#      Avg. Sell Count Per Year (Last 5 Yrs) Twitter URL Twitter Handle
# 2                                      NaN        None           None
# 5                                      0.4        None           None
# 6                                      0.2        None           None
# 12                                     NaN        None           None
# 21                                     0.2        None           None
# 23                                     0.4        None           None
# 24                                     NaN        None           None
# 27                                     0.4        None           None
# 31                                     NaN        None           None
# 41                                     0.2        None           None
# 44                                     NaN        None           None
# 52                                     0.2        None           None
# 70                                     0.4        None           None
# 71                                     0.2        None           None
# 77                                     NaN        None           None
# 78                                     NaN        None           None
# 79                                     0.2        None           None
# 80                                     0.6        None           None
# 94                                     NaN        None           None
# 95                                     NaN        None           None
# 97                                     0.2        None           None
# 101                                    0.2        None           None
# 107                                    0.2        None           None
# 109                                    0.6        None           None
# 111                                    0.4        None           None
# 113                                    NaN        None           None
# 119                                    NaN        None           None
# 121                                    NaN        None           None
# 122                                    NaN        None           None
# 128                                    0.4        None           None
# 138                                    NaN        None           None
# 150                                    0.2        None           None
# 156                                    NaN        None           None
# 163                                    NaN        None           None
# 165                                    NaN        None           None
# 169                                    NaN        None           None
# 170                                    NaN        None           None
# 181                                    0.4        None           None
# 184                                    NaN        None           None
# 188                                    0.6        None           None
# 201                                    NaN        None           None
# 208                                    0.6        None           None
# 213                                    NaN        None           None
# 214                                    NaN        None           None
# 219                                    0.6        None           None
# 222                                    NaN        None           None
# 224                                    0.2        None           None
# 231                                    0.4        None           None
# 235                                    0.2        None           None
# 244                                    NaN        None           None

# %% [markdown]
# Save Twitter dataframe as a CSV!

# %%
df_mergr_twitter.to_csv("mergr_twitter.csv")

# %% [markdown]
# #### Mergr Manual Corrections and Additions
#
# Manually go through each row of the `mergr_twitter.csv` to correct any erroneous Twitter URL or Twitter handle cells, and to fill empty Twitter URL and Twitter handle cells. Save the new CSV as `mergr_twitter_manual.csv`

# %%
# Read CSV of Mergr companies with Twitter handles
df_mergr_twitter_manual = pd.read_csv('mergr_twitter_manual.csv')
print(len(df_mergr_twitter_manual))
# Out:
# 85

# %% [markdown]
# Remove the Mergr df rows for Twitter handles already in our S&P 500 CSV. Do this in a case-insensitive way.

# %%
df_sp_500 = pd.read_csv('sp_500_twitter_subsidiaries_manual_mentioned.csv')
sp_500_twitter_handles = df_sp_500['Twitter Handle'].dropna()  # Drop nulls

# %%
df_mergr_twitter_dedup = df_mergr_twitter_manual[~df_mergr_twitter_manual['Twitter Handle'].str.lower().isin([sp_500_handle.lower() for sp_500_handle in sp_500_twitter_handles])]
print(len(df_mergr_twitter_dedup))
# Out:
# 53

# %% [markdown]
# Looks like, based on direct Twitter Handle matching, 53 of the 250 Mergr companies are not already in the S&P 500 CSV.

# %% [markdown]
# Save dataframe with deduplicated Twitter handles as a CSV!

# %%
df_mergr_twitter_dedup.to_csv("mergr_twitter_manual_deduplicated_from_sp_500.csv")

# %% [markdown]
# #### Getting Mergr Subsidiary Twitter Handles from Official Website

# %% [markdown]
# What should we do about Mergr companies that are parent companies with quite a few subsidiaries / divisions / brands?
#
# We decided to create a new row for each subsidiary listed on the homepage of the parent company's official website. We'll skip subsidiaries that aren't listed that way for now — it'll help us rule out companies that aren't public-facing using a company-decided variable.
#
# 1. Get the soup for the company website
# 2. Search for all `a` tags with an `href` that contains the string `twitter`.
# 3. Clean up each Twitter URL and its corresponding handle.
# 4. Put each (Twitter URL, Twitter handle) tuple into a set for the company.

# %%
# Map each company's name to a set of its and its subsidiaries' (Twitter URL, Twitter handle) tuples
name_to_twitters_map = {}

from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

# Create a new requests session that allows 0 retries 
session = requests.Session()
retry = Retry(total=0)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)

# User-Agent header is required to successfully request some sites
HEADERS = {"User-Agent": "Mozilla/5.0 (X11; CrOS x86_64 12871.102.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.141 Safari/537.36"}

def get_twitters_from_website_mergr(name: str, website: str) -> str:
    """
    Returns a set of all unique (Twitter URL, Twitter handle) tuples scraped from company website,
    with no repeated Twitter handles.
    Also updates name to Twitter URLs map.
    """
    if not website:
        # print("No website")
        return None
    
    website = 'https://' + website
        
    try:
        response = session.get(website, headers=HEADERS, timeout=10)
    except:
        # print("Request failed")
        return None
    
    # print("Scraping", website)
    company_soup = BeautifulSoup(response.text)
    
    twitter_link_tags = company_soup.select("a[href*=twitter]")

    twitter_handles = set()
    twitter_url_handle_tuples = set()
    for twitter_link_tag in twitter_link_tags:
        if twitter_link_tag['href']:
            twitter_url = twitter_link_tag['href']
            twitter_url_no_params = twitter_link_tag['href'].split("?")[0]
            twitter_url_end = twitter_url_no_params.split(".com/")[-1]
            twitter_handle = twitter_url_end.split("/")[0]
            if twitter_handle not in twitter_handles and twitter_handle != "intent":
                # We don't want Twitter handles that say "intent" -> that's usually something else
                twitter_url_handle_tuples.add((twitter_url_no_params, twitter_handle))
                twitter_handles.add(twitter_handle)
    
    name_to_twitters_map[name] = twitter_url_handle_tuples
    return(twitter_url_handle_tuples)

# %% [markdown]
# Read in our manually updated CSV with company website links and Twitter URLs.
#
# Add a Subsidiary column, set to False for all rows since we only have parent companies for now.

# %%
df_mergr_manual = pd.read_csv('mergr_twitter_manual_deduplicated_from_sp_500.csv')
df_mergr_manual["Subsidiary"]=False
df_mergr_manual
# Out:
#     Unnamed: 0.1  Unnamed: 0                          Name  \
# 0              7          24                      Facebook
# 1              8          26                          Dell
# 2             12          44               Energy Transfer
# 3             13          52                         Bunge
# 4             14          59                        StoneX
# 5             19          73                         Tyson
# 6             21          78                           TJX
# 7             22          79  Enterprise Products Partners
# 8             23          80                     Coca-Cola
# 9             24          87             Arrow Electronics
# 10            28          98                         Jabil
# 11            32         111                           NRG
# 12            33         113                          UNFI
# 13            34         116                        Macy's
# 14            35         119                           PFG
# 15            36         121                     TD SYNNEX
# 16            38         123                      Rite Aid
# 17            39         128           Plains All American
# 18            40         132                      US Foods
# 19            41         134                 Lithia Motors
# 20            43         142                       AerSale
# 21            44         144                 ManpowerGroup
# 22            45         146                        Penske
# 23            46         148                    AutoNation
# 24            47         150           World Fuel Services
# 25            49         158                       Kohl's
# 26            50         159                           JLL
# 27            51         161                          Lear
# 28            54         165                        PACCAR
# 29            55         166                       Kyndryl
# 30            56         169                          PG&E
# 31            57         170                   HF Sinclair
# 32            58         175                        Landos
# 33            60         181                  Tenet Health
# 34            61         182                         Avnet
# 35            63         188                       Stryker
# 36            64         192                          BJ's
# 37            65         196                           XPO
# 38            66         197       C.H. Robinson Worldwide
# 39            68         203              Rocket Companies
# 40            69         208   Fidelity National Financial
# 41            70         213                     Nordstrom
# 42            72         217                           RGA
# 43            73         219                           ITW
# 44            75         222                 Qurate Retail
# 45            76         224                       Wayfair
# 46            78         231                         Berry
# 47            79         234                           GAP
# 48            80         235                         Loews
# 49            81         240                         AECOM
# 50            82         243                        Markel
# 51            83         244                           Fox
# 52            84         245                       Carvana
#
#                             Sector  \
# 0   Internet Software and Services
# 1              Technology Hardware
# 2    Energy Services and Equipment
# 3                      Agriculture
# 4                Business Services
# 5                             Food
# 6                           Retail
# 7              Oil/Gas Exploration
# 8                        Beverages
# 9                     Distribution
# 10                   Manufacturing
# 11                       Utilities
# 12                    Distribution
# 13                          Retail
# 14                    Distribution
# 15               Business Services
# 16                          Retail
# 17   Energy Services and Equipment
# 18                    Distribution
# 19                      Automotive
# 20                       Aerospace
# 21                        Staffing
# 22                          Retail
# 23                      Automotive
# 24   Energy Services and Equipment
# 25                          Retail
# 26                     Real Estate
# 27                      Automotive
# 28                      Automotive
# 29          Information Technology
# 30                       Utilities
# 31             Oil/Gas Exploration
# 32                    Life Science
# 33             Healthcare Services
# 34                    Distribution
# 35                Medical Products
# 36                          Retail
# 37                  Transportation
# 38                  Transportation
# 39               Business Services
# 40                       Insurance
# 41                          Retail
# 42                       Insurance
# 43                   Manufacturing
# 44                      E-Commerce
# 45                      E-Commerce
# 46                        Plastics
# 47                Apparel/Textiles
# 48                     Diversified
# 49               Business Services
# 50                       Insurance
# 51                           Media
# 52                      E-Commerce
#
#                                              Address              City  \
# 0                                   1601 Willow Road        Menlo Park
# 1                                         1 Dell Way        Round Rock
# 2                  8111 Westchester Drive, Suite 600            Dallas
# 3                      1391 Timberlake Manor Parkway         St. Louis
# 4                     155 East 44th Street Suite 900          New York
# 5                          2200 W. Don Tyson Parkway        Springdale
# 6                                770 Cochituate Road        Framingham
# 7                  1100 Louisiana Street, 10th Floor           Houston
# 8                                One Coca-Cola Plaza           Atlanta
# 9                           9201 East Dry Creek Road        Centennial
# 10  10560 Drive Martin Luther King, Jr. Street North    St. Petersburg
# 11                              910 Louisiana Street           Houston
# 12                                313 Iron Horse Way        Providence
# 13                              151 West 34th Street          New York
# 14                          12500 West Creek Parkway          Richmond
# 15                                 44201 Nobel Drive           Fremont
# 16                                    30 Hunter Lane         Camp Hill
# 17                       333 Clay Street, Suite 1600           Houston
# 18                 9399 West Higgins Road, Suite 500          Rosemont
# 19                         150 North Bartlett Street           Medford
# 20                     121 Alhambra Plaza Suite 1110      Coral Gables
# 21                                100 Manpower Place         Milwaukee
# 22                               2555 Telegraph Road  Bloomfield Hills
# 23                 200 SW 1st Avenue Fort Lauderdale   Fort Lauderdale
# 24             9800 Northwest 41st Street, Suite 400             Miami
# 25                        N56 W17000 Ridgewood Drive   Menomonee Falls
# 26                           200 East Randolph Drive           Chicago
# 27                              21557 Telegraph Road        Southfield
# 28                               777-106th Avenue NE          Bellevue
# 29                  One Vanderbilt Avenue 15th Floor          New York
# 30                    77 Beale Street, PO Box 770000     San Francisco
# 31                    2828 North Harwood, Suite 1300            Dallas
# 32                       1800 Kraft Drive, Suite 216        Blacksburg
# 33                              14201 Dallas Parkway            Dallas
# 34                            2211 South 47th Street           Phoenix
# 35                            2825 Airview Boulevard         Kalamazoo
# 36                                 25 Research Drive       Westborough
# 37                        Five Greenwich Office Park         Greenwich
# 38                               14701 Charlson Road      Eden Prairie
# 39                              1050 Woodward Avenue           Detroit
# 40                              601 Riverside Avenue      Jacksonville
# 41                                 1617 Sixth Avenue           Seattle
# 42                         16600 Swingley Ridge Road      Chesterfield
# 43                                 155 Harlem Avenue          Glenview
# 44                               12300 Liberty Blvd.         Englewood
# 45                         4 Copley Place, 7th Floor            Boston
# 46                                 101 Oakley Street        Evansville
# 47                                   2 Folsom Street     San Francisco
# 48                                667 Madison Avenue          New York
# 49                  300 South Grand Avenue 9th Floor       Los Angeles
# 50                           4521 Highwoods Parkway         Glen Allen
# 51                       1211 Avenue of the Americas          New York
# 52                      1930 West Rio Salado Parkway             Tempe
#
#    State or Province    Zip        Country           Phone  ... Employees  \
# 0         California  94025  United States  (650) 543-4800  ...     77805
# 1              Texas  78682  United States  (800) 289-3355  ...    133000
# 2              Texas  75225  United States  (214) 981-0700  ...     12558
# 3           Missouri  63017  United States  (314) 292-2000  ...     22000
# 4           New York  10017  United States  (212) 485-3500  ...      2946
# 5           Arkansas  72762  United States  (479) 290-4000  ...    139000
# 6      Massachusetts   1701  United States  (508) 390-1000  ...    320000
# 7              Texas  77002  United States  (713) 381-6500  ...         0
# 8            Georgia  30313  United States  (404) 676-2121  ...     80300
# 9           Colorado  80112  United States  (303) 824-4000  ...     20700
# 10           Florida  33716  United States  (727) 577-9749  ...    260000
# 11        New Jersey  77002  United States  (713) 537-3000  ...      6635
# 12      Rhode Island   2908  United States  (401) 528-8634  ...     28300
# 13          New York  10001  United States  (212) 494-1602  ...    123000
# 14          Virginia  23238  United States  (804) 484-7700  ...     20000
# 15        California  94538  United States  (510) 656-3333  ...     22000
# 16      Pennsylvania  17011  United States  (717) 761-2633  ...     50000
# 17             Texas  77002  United States  (713) 646-4100  ...      4400
# 18          Illinois  60018  United States  (847) 720-8000  ...     26000
# 19            Oregon  97501  United States  (541) 776-6401  ...     21150
# 20           Florida  33134  United States  (305) 764-3232  ...       470
# 21         Wisconsin  53212  United States  (414) 961-1000  ...     30000
# 22          Michigan  48302  United States  (248) 648-2500  ...     23000
# 23           Florida  33301  United States  (954) 769-6000  ...     21600
# 24           Florida  33178  United States  (305) 428-8000  ...      4300
# 25         Wisconsin  53051  United States  (262) 703-7000  ...     99000
# 26          Illinois  60601  United States  (312) 782-5800  ...     98200
# 27          Michigan  48033  United States  (248) 447-1500  ...    160100
# 28        Washington  98004  United States  (425) 468-7400  ...     26000
# 29          New York  10017  United States  (212) 896-2098  ...     90000
# 30        California  94177  United States  (415) 973-1000  ...     24000
# 31             Texas  75201  United States  (214) 871-3555  ...      4208
# 32          Virginia  24060  United States  (540) 218-2232  ...        46
# 33             Texas  75254  United States  (469) 893-2200  ...     85800
# 34           Arizona  85034  United States  (480) 643-2000  ...     14600
# 35          Michigan  49002  United States  (269) 385-2600  ...     46000
# 36     Massachusetts   1581  United States  (774) 512-7400  ...     34000
# 37       Connecticut   6831  United States  (855) 976-6951  ...    108000
# 38         Minnesota  55347  United States  (952) 937-8500  ...     14997
# 39          Michigan  48226  United States  (313) 373-7990  ...     26000
# 40           Florida  32204  United States  (904) 854-8100  ...     28290
# 41        Washington  98101  United States  (206) 628-2111  ...     72000
# 42          Missouri  63017  United States  (636) 736-7000  ...      3600
# 43          Illinois  60025  United States  (847) 724-7500  ...     45000
# 44          Colorado  80112  United States  (720) 875-5300  ...     26508
# 45     Massachusetts   2116  United States  (617) 532-6100  ...     16200
# 46           Indiana  47710  United States  (812) 424-2904  ...     47000
# 47        California  94105  United States  (415) 427-0100  ...    117000
# 48          New York  10065  United States  (212) 521-2000  ...     10340
# 49        California  90071  United States  (213) 593-8100  ...     54000
# 50          Virginia  23060  United States  (804) 747-0136  ...     20300
# 51          New York  10036  United States  (212) 852-7000  ...      9000
# 52           Arizona  85281  United States  (480) 719-8809  ...     21000
#
#    Ownership Status                                Investors/Acquirers  \
# 0            Public                                                NaN
# 1            Public                                                NaN
# 2            Public                                                NaN
# 3            Public                                                NaN
# 4            Public                                                NaN
# 5            Public                                                NaN
# 6            Public                                                NaN
# 7            Public                                                NaN
# 8            Public                                                NaN
# 9            Public                                                NaN
# 10           Public                                                NaN
# 11           Public                                                NaN
# 12           Public                                                NaN
# 13           Public                                                NaN
# 14           Public                                                NaN
# 15           Public                           Apollo Global Management
# 16           Public                                                NaN
# 17           Public  Kayne Anderson Capital Advisors LP|First Reser...
# 18           Public                                     KKR & Co. L.P.
# 19           Public                                                NaN
# 20           Public                                                NaN
# 21           Public                                                NaN
# 22           Public                                                NaN
# 23           Public                                                NaN
# 24           Public                                                NaN
# 25           Public                                                NaN
# 26           Public                                                NaN
# 27           Public                                                NaN
# 28           Public                                                NaN
# 29           Public                                                NaN
# 30           Public                                                NaN
# 31           Public                                                NaN
# 32           Public                                                NaN
# 33           Public                                                NaN
# 34           Public                                                NaN
# 35           Public                                                NaN
# 36           Public                                                NaN
# 37           Public                                                NaN
# 38           Public                                                NaN
# 39           Public                                                NaN
# 40           Public                                                NaN
# 41           Public                                                NaN
# 42           Public                                                NaN
# 43           Public                                                NaN
# 44           Public                                                NaN
# 45           Public                                                NaN
# 46           Public                                                NaN
# 47           Public                                                NaN
# 48           Public                                                NaN
# 49           Public                                                NaN
# 50           Public                                  Alliance Holdings
# 51           Public                                                NaN
# 52           Public                                                NaN
#
#    Buy M&A Count - Total Avg. Buy Count Per Year (Last 5 Yrs)  \
# 0                   83.0                                  3.2
# 1                   29.0                                  NaN
# 2                    9.0                                  0.6
# 3                   10.0                                  NaN
# 4                   17.0                                  2.4
# 5                   13.0                                  0.6
# 6                    5.0                                  0.2
# 7                   19.0                                  0.4
# 8                   18.0                                  0.4
# 9                   34.0                                  0.2
# 10                   7.0                                  0.2
# 11                  15.0                                  0.2
# 12                   8.0                                  0.2
# 13                   4.0                                  0.2
# 14                   6.0                                  0.6
# 15                  15.0                                  0.4
# 16                  12.0                                  0.4
# 17                   7.0                                  0.2
# 18                  23.0                                  0.4
# 19                  20.0                                  1.6
# 20                   2.0                                  0.4
# 21                  14.0                                  0.2
# 22                  23.0                                  0.8
# 23                  13.0                                  0.2
# 24                  16.0                                  0.4
# 25                   NaN                                  NaN
# 26                  29.0                                  1.8
# 27                  21.0                                  1.0
# 28                   2.0                                  NaN
# 29                   NaN                                  NaN
# 30                   NaN                                  NaN
# 31                   4.0                                  0.6
# 32                   NaN                                  NaN
# 33                   6.0                                  0.2
# 34                  78.0                                  0.4
# 35                  43.0                                  2.2
# 36                   NaN                                  NaN
# 37                  17.0                                  0.2
# 38                  24.0                                  0.8
# 39                   1.0                                  0.2
# 40                  29.0                                  1.0
# 41                   7.0                                  0.4
# 42                   4.0                                  0.2
# 43                  48.0                                  0.2
# 44                   1.0                                  NaN
# 45                   3.0                                  NaN
# 46                  14.0                                  0.4
# 47                   7.0                                  0.6
# 48                   1.0                                  NaN
# 49                  12.0                                  0.2
# 50                  13.0                                  1.0
# 51                   4.0                                  0.8
# 52                   3.0                                  0.4
#
#     Sell M&A Count - Total  Avg. Sell Count Per Year (Last 5 Yrs)  \
# 0                      NaN                                    NaN
# 1                      7.0                                    0.2
# 2                      1.0                                    NaN
# 3                      4.0                                    0.2
# 4                      NaN                                    NaN
# 5                      6.0                                    0.6
# 6                      1.0                                    NaN
# 7                      5.0                                    0.2
# 8                      8.0                                    0.6
# 9                      1.0                                    NaN
# 10                     NaN                                    NaN
# 11                     6.0                                    0.4
# 12                     NaN                                    NaN
# 13                     2.0                                    NaN
# 14                     1.0                                    NaN
# 15                     NaN                                    NaN
# 16                     1.0                                    NaN
# 17                     2.0                                    0.4
# 18                     NaN                                    NaN
# 19                     NaN                                    NaN
# 20                     NaN                                    NaN
# 21                     NaN                                    NaN
# 22                     NaN                                    NaN
# 23                     1.0                                    NaN
# 24                     1.0                                    0.2
# 25                     NaN                                    NaN
# 26                     NaN                                    NaN
# 27                     1.0                                    NaN
# 28                     NaN                                    NaN
# 29                     NaN                                    NaN
# 30                     NaN                                    NaN
# 31                     2.0                                    NaN
# 32                     NaN                                    NaN
# 33                    10.0                                    0.4
# 34                     6.0                                    0.2
# 35                     5.0                                    0.6
# 36                     NaN                                    NaN
# 37                     2.0                                    0.2
# 38                     1.0                                    NaN
# 39                     NaN                                    NaN
# 40                     8.0                                    0.6
# 41                     5.0                                    NaN
# 42                     1.0                                    0.2
# 43                    13.0                                    0.6
# 44                     NaN                                    NaN
# 45                     1.0                                    0.2
# 46                     2.0                                    0.4
# 47                     4.0                                    0.6
# 48                     1.0                                    0.2
# 49                     5.0                                    0.8
# 50                     NaN                                    NaN
# 51                     NaN                                    NaN
# 52                     NaN                                    NaN
#
#                                 Twitter URL   Twitter Handle Subsidiary
# 0              https://twitter.com/facebook         facebook      False
# 1              https://twitter.com/delltech         delltech      False
# 2        https://twitter.com/EnergyTransfer   EnergyTransfer      False
# 3                 https://twitter.com/bunge            bunge      False
# 4       https://twitter.com/StoneX_Official  StoneX_Official      False
# 5            https://twitter.com/TysonFoods       TysonFoods      False
# 6                https://twitter.com/tjmaxx           tjmaxx      False
# 7                                       NaN              NaN      False
# 8              https://twitter.com/CocaCola         CocaCola      False
# 9         https://twitter.com/Arrow_dot_com    Arrow_dot_com      False
# 10                https://twitter.com/Jabil            Jabil      False
# 11              https://twitter.com/picknrg          picknrg      False
# 12                 https://twitter.com/UNFI             UNFI      False
# 13            https://twitter.com/macysnews        macysnews      False
# 14                                      NaN              NaN      False
# 15               https://twitter.com/SYNNEX           SYNNEX      False
# 16           http://www.twitter.com/RiteAid          RiteAid      False
# 17                                      NaN              NaN      False
# 18              https://twitter.com/usfoods          usfoods      False
# 19     https://www.twitter.com/lithiamotors     lithiamotors      False
# 20              https://twitter.com/aersale          aersale      False
# 21        https://twitter.com/ManpowerGroup    ManpowerGroup      False
# 22           https://twitter.com/penskecars       penskecars      False
# 23           https://twitter.com/AutoNation       AutoNation      False
# 24           https://twitter.com/world_fuel       world_fuel      False
# 25                https://twitter.com/kohls            kohls      False
# 26                  https://twitter.com/JLL              JLL      False
# 27      https://twitter.com/LearCorporation  LearCorporation      False
# 28                                      NaN              NaN      False
# 29              https://twitter.com/kyndryl          kyndryl      False
# 30               https://twitter.com/pge4me           pge4me      False
# 31                                      NaN              NaN      False
# 32            https://twitter.com/landosbio        landosbio      False
# 33          https://twitter.com/tenethealth      tenethealth      False
# 34                https://twitter.com/avnet            avnet      False
# 35          https://twitter.com/strykercomm      strykercomm      False
# 36         https://twitter.com/BJsWholesale     BJsWholesale      False
# 37         https://twitter.com/XPOLogistics     XPOLogistics      False
# 38          https://twitter.com/CHRobinson       CHRobinson       False
# 39  https://www.twitter.com/rocketpressroom  rocketpressroom      False
# 40           https://twitter.com/FidelityNF       FidelityNF      False
# 41            https://twitter.com/nordstrom        nordstrom      False
# 42               https://twitter.com/RGA_RE           RGA_RE      False
# 43                                      NaN              NaN      False
# 44      https://twitter.com/qurateretailgrp  qurateretailgrp      False
# 45              https://twitter.com/Wayfair          Wayfair      False
# 46       https://twitter.com/berryglobalinc   berryglobalinc      False
# 47               https://twitter.com/GapInc           GapInc      False
# 48                                      NaN              NaN      False
# 49                https://twitter.com/AECOM            AECOM      False
# 50          https://twitter.com/MarkelStyle      MarkelStyle      False
# 51                                      NaN              NaN      False
# 52              https://twitter.com/carvana          carvana      False
#
# [53 rows x 22 columns]

# %%
# For each row of dataframe, find all Twitter URLs on company official website
# Save in dictionary mapping from company Name to set of (Twitter URL, Twitter handle) tuples found on that company's official website
for row in df_mergr_manual.itertuples():
    get_twitters_from_website_mergr(row.Name, row.Url)
    print(row.Name)
    
name_to_twitters_map
# Out:
# Facebook
# Dell
# Energy Transfer
# Bunge
# StoneX
# Tyson
# TJX
# Enterprise Products Partners
# Coca-Cola
# Arrow Electronics
# Jabil
# NRG
# UNFI
# Macy's
# PFG
# TD SYNNEX
# Rite Aid
# Plains All American
# US Foods
# Lithia Motors
# AerSale
# ManpowerGroup
# Penske
# AutoNation
# World Fuel Services
# Kohl's
# JLL
# Lear
# PACCAR
# Kyndryl
# PG&E
# HF Sinclair
# Landos
# Tenet Health
# Avnet
# Stryker
# BJ's
# XPO
# C.H. Robinson Worldwide
# Rocket Companies
# Fidelity National Financial
# Nordstrom
# RGA
# ITW
# Qurate Retail
# Wayfair
# Berry
# GAP
# Loews
# AECOM
# Markel
# Fox
# Carvana
# {'Facebook': set(),
#  'Dell': {('//twitter.com/delltech', 'delltech')},
#  'Energy Transfer': set(),
#  'Bunge': set(),
#  'StoneX': {('https://twitter.com/StoneX_Official', 'StoneX_Official')},
#  'Tyson': {('https://twitter.com/TysonFoods/', 'TysonFoods')},
#  'TJX': set(),
#  'Enterprise Products Partners': set(),
#  'Coca-Cola': set(),
#  'Arrow Electronics': {('https://twitter.com/Arrow_dot_com', 'Arrow_dot_com')},
#  'Jabil': {('https://twitter.com/Jabil', 'Jabil')},
#  'NRG': set(),
#  'UNFI': {('https://twitter.com/#!/UNFI', '#!')},
#  "Macy's": {('https://twitter.com/macysnews', 'macysnews')},
#  'PFG': set(),
#  'TD SYNNEX': set(),
#  'Rite Aid': {('http://www.twitter.com/RiteAid', 'RiteAid')},
#  'Plains All American': set(),
#  'US Foods': {('https://twitter.com/usfoods', 'usfoods')},
#  'Lithia Motors': {('https://www.twitter.com/lithiamotors', 'lithiamotors')},
#  'AerSale': {('https://twitter.com/aersale', 'aersale')},
#  'ManpowerGroup': {('https://twitter.com/ManpowerGroup', 'ManpowerGroup')},
#  'Penske': {('https://twitter.com/penskecars', 'penskecars')},
#  'AutoNation': {('https://twitter.com/AutoNation', 'AutoNation')},
#  'World Fuel Services': set(),
#  "Kohl's ": {('https://twitter.com/kohls', 'kohls')},
#  'JLL': {('https://twitter.com/JLL', 'JLL')},
#  'Lear': {('https://twitter.com/LearCorporation', 'LearCorporation')},
#  'PACCAR': set(),
#  'Kyndryl': {('https://twitter.com/kyndryl', 'kyndryl')},
#  'PG&E': set(),
#  'HF Sinclair': set(),
#  'Landos': {('https://twitter.com/LandosBio/status/1455513477838254083',
#    'LandosBio'),
#   ('https://twitter.com/SciReports', 'SciReports'),
#   ('https://twitter.com/US_FDA', 'US_FDA'),
#   ('https://twitter.com/demycolton', 'demycolton'),
#   ('https://twitter.com/landosbio', 'landosbio'),
#   ('https://twitter.com/search', 'search')},
#  'Tenet Health': set(),
#  'Avnet': set(),
#  'Stryker': set(),
#  "BJ's": {('https://twitter.com/BJsWholesale', 'BJsWholesale')},
#  'XPO': {('https://twitter.com/XPOLogistics', 'XPOLogistics')},
#  'C.H. Robinson Worldwide': {('https://twitter.com/CHRobinson ',
#    'CHRobinson ')},
#  'Rocket Companies': {('https://www.twitter.com/rocketcompanies',
#    'rocketcompanies'),
#   ('https://www.twitter.com/rocketpressroom', 'rocketpressroom')},
#  'Fidelity National Financial': set(),
#  'Nordstrom': set(),
#  'RGA': {('https://twitter.com/RGA_RE', 'RGA_RE')},
#  'ITW': set(),
#  'Qurate Retail': set(),
#  'Wayfair': set(),
#  'GAP': {('https://twitter.com/GapInc', 'GapInc')},
#  'Loews': set(),
#  'AECOM': {('https://twitter.com/AECOM', 'AECOM'),
#   ('https://twitter.com/AECOMCareers', 'AECOMCareers'),
#   ('https://twitter.com/hashtag/COP27', 'hashtag')},
#  'Markel': {('https://twitter.com/MarkelStyle', 'MarkelStyle')},
#  'Fox': set(),
#  'Carvana': {('https://twitter.com/carvana', 'carvana')}}

# %% [markdown]
# Now it's time to add a new row for each subsidiary's Twitter account to our dataframe! Let's make a copy of our dataframe.

# %%
import warnings
warnings.filterwarnings('ignore') # ignore warnings about append

df_mergr_subsidiaries = df_mergr_manual.copy(deep=True)

for name in name_to_twitters_map:
    twitter_tuples = name_to_twitters_map[name]
    num_twitters_scraped = len(twitter_tuples)
    
    # If a single Twitter account was scraped, that's probably just the parent company's Twitter account,
    # which is already in our dataframe, so we don't want to add a new row for that.
    if num_twitters_scraped > 1:
        # Get index of the parent company's row by finding the first row that matches the company Name
        parent_company_row_index = df_mergr_manual.loc[df_mergr_manual["Name"] == name].index[0]
        
        # Copy that old parent company row to a new subsidiary row
        parent_company_row = df_mergr_manual.loc[parent_company_row_index]
        subsidiary_row = parent_company_row.copy()
        
        # Iterate thru the (Twitter URL, Twitter Handle) tuples for this parent company
        for twitter_url, twitter_handle in twitter_tuples:
            if twitter_url != parent_company_row["Twitter URL"] and twitter_handle.lower() != parent_company_row["Twitter Handle"].lower():
                # It's a subsidiary Twitter URL, not the parent Twitter URL!
                # Update the Twitter URL, Twitter Handle, and Subsidiary columns for the new row
                subsidiary_row["Twitter URL"] = twitter_url
                subsidiary_row["Twitter Handle"] = twitter_handle
                subsidiary_row["Subsidiary"] = True
                        
                # Add subsidiary as new row in df
                df_mergr_subsidiaries = df_mergr_subsidiaries.append(subsidiary_row)

# %%
# Sort dataframe alphabetically, primarily by company Security, and secondarily by Subsidiary column value
# The lambda function ensures that the sort is case-insensitive
# So that parent companies and their subsidiaries are in consecutive rows
df_mergr_subsidiaries["Subsidiary"] = df_mergr_subsidiaries["Subsidiary"].map({True: 'True', False: 'False'}) # convert Subsidiary column to strings to do the sorting
df_mergr_subsidiaries = df_mergr_subsidiaries.sort_values(["Name", "Subsidiary"], key=lambda col: col.str.lower())
df_mergr_subsidiaries["Subsidiary"] = df_mergr_subsidiaries["Subsidiary"].map({'True': True, 'False': False}) # convert Subsidiary column back to bools

# Save as CSV
df_mergr_subsidiaries.to_csv("mergr_twitter_subsidiaries.csv")

# %%
# Subtract 1 because 1 row is the column headings
print("Number of rows in original df: ", len(df_mergr_manual) - 1)
print("Number of rows in new df: ", len(df_mergr_subsidiaries) - 1)
# Out:
# Number of rows in original df:  52
# Number of rows in new df:  59

# %% [markdown]
# Looks like we found 7 new Twitter accounts! Does this mean 7 potential subsidiaries?

# %% [markdown]
# We may want to manually check to ensure that these aren't career-specific Twitter accounts or unrelated Twitter accounts

# %%
df_mergr_subsidiaries_manual = pd.read_csv('mergr_twitter_subsidiaries_manual.csv')
print("Number of rows in manually corrected df: ", len(df_mergr_subsidiaries_manual) - 1)
# Out:
# Number of rows in manually corrected df:  53

# %% [markdown]
# From our manual corrections, it looks like we actually found just 1 new subsidiary with a Twitter account.

# %%
# Drop duplicates (rows that have the same Twitter Handle values) except for the first occurrence,
# and don't drop any rows that have a null value for the Twitter Handle column.
df_mergr_subsidiaries_manual_no_dups = df_mergr_subsidiaries_manual[(~df_mergr_subsidiaries_manual['Twitter Handle'].duplicated()) | df_mergr_subsidiaries_manual['Twitter Handle'].isna()]

# %%
# Subtract 1 because 1 row is the column headings
print("Number of rows in original df: ", len(df_mergr_subsidiaries_manual) - 1)
print("Number of rows in new df: ", len(df_mergr_subsidiaries_manual_no_dups) - 1)
# Out:
# Number of rows in original df:  53
# Number of rows in new df:  53

# %% [markdown]
# It looks like we didn't have any rows with duplicate Twitter Handles to begin with!
