# %%
import pandas as pd
import pickle
import os

# %%
DATA_FOLDER = "data/tweets/ten_years"

# %% [markdown]
# We want to find the hashtags used by at least 10 distinct companies.
#
# First we load the list of all hashtags in the dataset. This is distinct usages, so there are no repeats.

# %%
with open('hashtag_clustering/all_hashtags.pkl', 'rb') as f:
    all_hashtags = pickle.load(f)
    
print(len(all_hashtags))
# Out:
# 129439

# %% [markdown]
# Create a dictionary mapping each hashtag to an integer representing the number of companies that used that hashtag.
#
# $\text{hashtag} \rightarrow \text{number of compaies that used it}$

# %%
# Function to get hashtags within a companie's df

def get_unique_hashtags(df):
    hashtags_set = set([])
    
    hashtags_series = df[df["hashtags"].notnull()]["hashtags"]

    for tags in hashtags_series:
        cleaned_tags_list = tags.replace("{", "").replace("}", "").replace("'", "").split(", ")
        cleaned_tags_list = [tag.lower() for tag in cleaned_tags_list]
        
        for tag in cleaned_tags_list:
            hashtags_set.add(tag)

    return hashtags_set

# %%
hashtag_company_usage_counts = {tag.lower(): 0 for tag in all_hashtags}

for comp_csv in os.listdir(DATA_FOLDER):
        print(f"Updating hashtags {comp_csv}")
        df = pd.read_csv(f"{DATA_FOLDER}/{comp_csv}", lineterminator='\n')
        df_hashtags = get_unique_hashtags(df)
        
        for tag in df_hashtags:
            hashtag_company_usage_counts[tag] += 1
# Out:
# Updating hashtags pncbank_tweets.csv
# Updating hashtags teradyneinc_tweets.csv
# Updating hashtags bakerhughesco_tweets.csv
# Updating hashtags ceridian_tweets.csv
# Updating hashtags aiginsurance_tweets.csv
# Updating hashtags expediamedia_tweets.csv
# Updating hashtags costargroup_tweets.csv
# Updating hashtags cboe_tweets.csv
# Updating hashtags skyworksinc_tweets.csv
# Updating hashtags bathbodyworks_tweets.csv
# Updating hashtags raytheontech_tweets.csv
# Updating hashtags kelloggcompany_tweets.csv
# Updating hashtags truistnews_tweets.csv
# Updating hashtags royalcaribbean_tweets.csv
# Updating hashtags eastmanchemco_tweets.csv
# Updating hashtags dominos_tweets.csv
# Updating hashtags edwardslifesci_tweets.csv
# Updating hashtags labcorp_tweets.csv
# Updating hashtags allegionplc_tweets.csv
# Updating hashtags kraftheinzco_tweets.csv
# Updating hashtags evergypower_tweets.csv
# Updating hashtags fbhs_news_tweets.csv
# Updating hashtags ups_tweets.csv
# Updating hashtags fti_us_tweets.csv
# Updating hashtags guycarpenter_tweets.csv
# Updating hashtags synchrony_tweets.csv
# Updating hashtags steris_tweets.csv
# Updating hashtags netflix_tweets.csv
# Updating hashtags downewsroom_tweets.csv
# Updating hashtags agilent_tweets.csv
# Updating hashtags exocad_tweets.csv
# Updating hashtags bookingcom_tweets.csv
# Updating hashtags tinder_tweets.csv
# Updating hashtags vlasicstork_tweets.csv
# Updating hashtags chrobinson_tweets.csv
# Updating hashtags google_tweets.csv
# Updating hashtags intuitivesurg_tweets.csv
# Updating hashtags lamresearch_tweets.csv
# Updating hashtags extraspace_tweets.csv
# Updating hashtags keysight_tweets.csv
# Updating hashtags heycisco_tweets.csv
# Updating hashtags mhkgreenworks_tweets.csv
# Updating hashtags lyondellbasell_tweets.csv
# Updating hashtags fiserv_tweets.csv
# Updating hashtags admupdates_tweets.csv
# Updating hashtags twitter_tweets.csv
# Updating hashtags verizonfios_tweets.csv
# Updating hashtags centerpoint_tweets.csv
# Updating hashtags hiltonnewsroom_tweets.csv
# Updating hashtags stanleyblkdeckr_tweets.csv
# Updating hashtags intlpaperco_tweets.csv
# Updating hashtags gallagherglobal_tweets.csv
# Updating hashtags agoda_tweets.csv
# Updating hashtags catalentpharma_tweets.csv
# Updating hashtags pplcorp_tweets.csv
# Updating hashtags larsondoors_tweets.csv
# Updating hashtags priceline_tweets.csv
# Updating hashtags ironmountain_tweets.csv
# Updating hashtags altrianews_tweets.csv
# Updating hashtags factset_tweets.csv
# Updating hashtags bioradcellbio_tweets.csv
# Updating hashtags visa_tweets.csv
# Updating hashtags take2interactiv_tweets.csv
# Updating hashtags corninglifesci_tweets.csv
# Updating hashtags genuinepartsco_tweets.csv
# Updating hashtags cruisenorwegian_tweets.csv
# Updating hashtags kayak_tweets.csv
# Updating hashtags exelon_tweets.csv
# Updating hashtags healthy_choice_tweets.csv
# Updating hashtags conocophillips_tweets.csv
# Updating hashtags wynnlasvegas_tweets.csv
# Updating hashtags newell_brands_tweets.csv
# Updating hashtags bookingholdings_tweets.csv
# Updating hashtags moderna_tx_tweets.csv
# Updating hashtags weareoxy_tweets.csv
# Updating hashtags realreddiwip_tweets.csv
# Updating hashtags ametekinc_tweets.csv
# Updating hashtags nortonlifelock_tweets.csv
# Updating hashtags tmobile_tweets.csv
# Updating hashtags leidosinc_tweets.csv
# Updating hashtags drhorton_tweets.csv
# Updating hashtags masterlockus_tweets.csv
# Updating hashtags ice_markets_tweets.csv
# Updating hashtags martinmarietta_tweets.csv
# Updating hashtags marshmclennan_tweets.csv
# Updating hashtags habitburger_tweets.csv
# Updating hashtags att_tweets.csv
# Updating hashtags criverlabs_tweets.csv
# Updating hashtags turbotax_tweets.csv
# Updating hashtags enphase_tweets.csv
# Updating hashtags nielsen_tweets.csv
# Updating hashtags valeroenergy_tweets.csv
# Updating hashtags charternewsroom_tweets.csv
# Updating hashtags wastemanagement_tweets.csv
# Updating hashtags regencycenters_tweets.csv
# Updating hashtags thermofisher_tweets.csv
# Updating hashtags zebratechnology_tweets.csv
# Updating hashtags publicstorage_tweets.csv
# Updating hashtags packagingcorp_tweets.csv
# Updating hashtags usbank_tweets.csv
# Updating hashtags iqvia_global_tweets.csv
# Updating hashtags garmin_tweets.csv
# Updating hashtags unitedhealthgrp_tweets.csv
# Updating hashtags verisign_tweets.csv
# Updating hashtags bnymellon_tweets.csv
# Updating hashtags carmax_tweets.csv
# Updating hashtags ross_stores_tweets.csv
# Updating hashtags aristanetworks_tweets.csv
# Updating hashtags broadcom_tweets.csv
# Updating hashtags avalonbay_tweets.csv
# Updating hashtags synopsys_tweets.csv
# Updating hashtags spglobal_tweets.csv
# Updating hashtags travelocity_tweets.csv
# Updating hashtags vertexpharma_tweets.csv
# Updating hashtags homedepot_tweets.csv
# Updating hashtags mastercard_tweets.csv
# Updating hashtags askamex_tweets.csv
# Updating hashtags nscorp_tweets.csv
# Updating hashtags xylem_tweets.csv
# Updating hashtags moen_tweets.csv
# Updating hashtags mailchimp_tweets.csv
# Updating hashtags howmetaerospace_tweets.csv
# Updating hashtags whirlpoolcorp_tweets.csv
# Updating hashtags nordson_corp_tweets.csv
# Updating hashtags dccomics_tweets.csv
# Updating hashtags conagrabrands_tweets.csv
# Updating hashtags dexcom_tweets.csv
# Updating hashtags monolithicpower_tweets.csv
# Updating hashtags cbre_tweets.csv
# Updating hashtags southwestair_tweets.csv
# Updating hashtags humana_tweets.csv
# Updating hashtags kroger_tweets.csv
# Updating hashtags cisco_tweets.csv
# Updating hashtags citizensbank_tweets.csv
# Updating hashtags mcdonalds_tweets.csv
# Updating hashtags mosaiccompany_tweets.csv
# Updating hashtags viatrisinc_tweets.csv
# Updating hashtags shopsimon_tweets.csv
# Updating hashtags vulcan_concrete_tweets.csv
# Updating hashtags target_tweets.csv
# Updating hashtags paramountco_tweets.csv
# Updating hashtags crowncastle_tweets.csv
# Updating hashtags amphenol_tweets.csv
# Updating hashtags regeneron_tweets.csv
# Updating hashtags welltower_tweets.csv
# Updating hashtags fisglobal_tweets.csv
# Updating hashtags northerntrust_tweets.csv
# Updating hashtags merck_tweets.csv
# Updating hashtags expedia_tweets.csv
# Updating hashtags averydennison_tweets.csv
# Updating hashtags ameriprise_tweets.csv
# Updating hashtags onsemi_tweets.csv
# Updating hashtags pxdtweets_tweets.csv
# Updating hashtags akamai_tweets.csv
# Updating hashtags paychex_tweets.csv
# Updating hashtags kccorp_tweets.csv
# Updating hashtags chipotletweets_tweets.csv
# Updating hashtags costco_tweets.csv
# Updating hashtags keurigpepper_tweets.csv
# Updating hashtags principal_tweets.csv
# Updating hashtags broadridge_tweets.csv
# Updating hashtags healthcare_abc_tweets.csv
# Updating hashtags wabteccorp_tweets.csv
# Updating hashtags blizzard_ent_tweets.csv
# Updating hashtags marathonoil_tweets.csv
# Updating hashtags chevron_tweets.csv
# Updating hashtags txinstruments_tweets.csv
# Updating hashtags equifax_tweets.csv
# Updating hashtags cigna_tweets.csv
# Updating hashtags autodesk_tweets.csv
# Updating hashtags thehartford_tweets.csv
# Updating hashtags qualcomm_tweets.csv
# Updating hashtags americantowerus_tweets.csv
# Updating hashtags meta_tweets.csv
# Updating hashtags dukerealty_tweets.csv
# Updating hashtags ultabeauty_tweets.csv
# Updating hashtags atmosenergy_tweets.csv
# Updating hashtags okcupid_tweets.csv
# Updating hashtags esteelauder_tweets.csv
# Updating hashtags csx_tweets.csv
# Updating hashtags abbvie_tweets.csv
# Updating hashtags equinix_tweets.csv
# Updating hashtags dupont_news_tweets.csv
# Updating hashtags solaredgepv_tweets.csv
# Updating hashtags cvshealth_tweets.csv
# Updating hashtags lowes_tweets.csv
# Updating hashtags idexcorp_tweets.csv
# Updating hashtags aligntechinc_tweets.csv
# Updating hashtags b_binsurance_tweets.csv
# Updating hashtags teleflex_tweets.csv
# Updating hashtags mgmresortsintl_tweets.csv
# Updating hashtags fleetcor_tweets.csv
# Updating hashtags mandt_bank_tweets.csv
# Updating hashtags sbasite_tweets.csv
# Updating hashtags incyte_tweets.csv
# Updating hashtags resmed_tweets.csv
# Updating hashtags waterscorp_tweets.csv
# Updating hashtags ventasreit_tweets.csv
# Updating hashtags federalrealty_tweets.csv
# Updating hashtags epamsystems_tweets.csv
# Updating hashtags aon_plc_tweets.csv
# Updating hashtags campbellsoupco_tweets.csv
# Updating hashtags charlesschwab_tweets.csv
# Updating hashtags amwater_tweets.csv
# Updating hashtags klacorp_tweets.csv
# Updating hashtags raymondjames_tweets.csv
# Updating hashtags alaskaair_tweets.csv
# Updating hashtags hesscorporation_tweets.csv
# Updating hashtags ea_tweets.csv
# Updating hashtags firstenergycorp_tweets.csv
# Updating hashtags alliantenergy_tweets.csv
# Updating hashtags intel_tweets.csv
# Updating hashtags paypal_tweets.csv
# Updating hashtags cfindustries_tweets.csv
# Updating hashtags invitationhomes_tweets.csv
# Updating hashtags lennar_tweets.csv
# Updating hashtags lambweston_tweets.csv
# Updating hashtags expediagroup_tweets.csv
# Updating hashtags cintascorp_tweets.csv
# Updating hashtags molsoncoors_tweets.csv
# Updating hashtags dominionenergy_tweets.csv
# Updating hashtags gartner_inc_tweets.csv
# Updating hashtags atvi_ab_tweets.csv
# Updating hashtags morganstanley_tweets.csv
# Updating hashtags wtwcorporate_tweets.csv
# Updating hashtags nasdaq_tweets.csv
# Updating hashtags monsterenergy_tweets.csv
# Updating hashtags dukesmeats_tweets.csv
# Updating hashtags amd_tweets.csv
# Updating hashtags otiselevatorco_tweets.csv
# Updating hashtags americanair_tweets.csv
# Updating hashtags oracle_tweets.csv
# Updating hashtags netapp_tweets.csv
# Updating hashtags wecenergygroup_tweets.csv
# Updating hashtags realtyincome_tweets.csv
# Updating hashtags hormelfoods_tweets.csv
# Updating hashtags globelife_tweets.csv
# Updating hashtags celanese_tweets.csv
# Updating hashtags apa_corp_tweets.csv
# Updating hashtags oliverwyman_tweets.csv
# Updating hashtags activision_tweets.csv
# Updating hashtags nexteraenergy_tweets.csv
# Updating hashtags f5_tweets.csv
# Updating hashtags thermatru_tweets.csv
# Updating hashtags celebritycruise_tweets.csv
# Updating hashtags tesla_tweets.csv
# Updating hashtags udrmarketing_tweets.csv
# Updating hashtags amgen_tweets.csv
# Updating hashtags dukeenergy_tweets.csv
# Updating hashtags theaescorp_tweets.csv
# Updating hashtags capitalone_tweets.csv
# Updating hashtags ansys_tweets.csv
# Updating hashtags adobe_tweets.csv
# Updating hashtags mccormickcorp_tweets.csv
# Updating hashtags firstrepublic_tweets.csv
# Updating hashtags cp_news_tweets.csv
# Updating hashtags cognizant_tweets.csv
# Updating hashtags globalpayinc_tweets.csv
# Updating hashtags slimjim_tweets.csv
# Updating hashtags oneok_tweets.csv
# Updating hashtags ford_tweets.csv
# Updating hashtags wrberkleycorp_tweets.csv
# Updating hashtags ballcorphq_tweets.csv
# Updating hashtags salesforce_tweets.csv
# Updating hashtags tuicruises_tweets.csv
# Updating hashtags comericabank_tweets.csv
# Updating hashtags essexapartments_tweets.csv
# Updating hashtags corninggorilla_tweets.csv
# Updating hashtags hersheycompany_tweets.csv
# Updating hashtags abbottnews_tweets.csv
# Updating hashtags cbrands_tweets.csv
# Updating hashtags smuckers_tweets.csv
# Updating hashtags textron_tweets.csv
# Updating hashtags huntington_bank_tweets.csv
# Updating hashtags trane_tech_tweets.csv
# Updating hashtags intuit_tweets.csv
# Updating hashtags corningopcomm_tweets.csv
# Updating hashtags poolcorp_tweets.csv
# Updating hashtags waltdisneyco_tweets.csv
# Updating hashtags pfizer_tweets.csv
# Updating hashtags iteroscanner_tweets.csv
# Updating hashtags progressive_tweets.csv
# Updating hashtags mettlertoledo_tweets.csv
# Updating hashtags pultehomes_tweets.csv
# Updating hashtags hpe_tweets.csv
# Updating hashtags jh_fintech_tweets.csv
# Updating hashtags irproducts_tweets.csv
# Updating hashtags microchiptech_tweets.csv
# Updating hashtags chase_tweets.csv
# Updating hashtags kinder_morgan_tweets.csv
# Updating hashtags teledynedalsa_tweets.csv
# Updating hashtags bioradflowabs_tweets.csv
# Updating hashtags bankofamerica_tweets.csv
# Updating hashtags dentsplysirona_tweets.csv
# Updating hashtags grainger_tweets.csv
# Updating hashtags warnerbrostv_tweets.csv
# Updating hashtags opentable_tweets.csv
# Updating hashtags marriottbonvoy_tweets.csv
# Updating hashtags marshglobal_tweets.csv
# Updating hashtags united_tweets.csv
# Updating hashtags generalmills_tweets.csv
# Updating hashtags sherwinwilliams_tweets.csv
# Updating hashtags cardinalhealth_tweets.csv
# Updating hashtags moodysinvsvc_tweets.csv
# Updating hashtags applied4tech_tweets.csv
# Updating hashtags paccarfinancial_tweets.csv
# Updating hashtags sealed_air_tweets.csv
# Updating hashtags airproducts_tweets.csv
# Updating hashtags brownforman_tweets.csv
# Updating hashtags idexx_tweets.csv
# Updating hashtags gileadsciences_tweets.csv
# Updating hashtags aosmithhotwater_tweets.csv
# Updating hashtags apple_tweets.csv
# Updating hashtags hcahealthcare_tweets.csv
# Updating hashtags nisourceinc_tweets.csv
# Updating hashtags nxp_tweets.csv
# Updating hashtags mckesson_tweets.csv
# Updating hashtags northropgrumman_tweets.csv
# Updating hashtags prologis_tweets.csv
# Updating hashtags fortivecorp_tweets.csv
# Updating hashtags servicenow_tweets.csv
# Updating hashtags cdwcorp_tweets.csv
# Updating hashtags dollargeneral_tweets.csv
# Updating hashtags kimcorealty_tweets.csv
# Updating hashtags spectrumbiz_tweets.csv
# Updating hashtags advanceauto_tweets.csv
# Updating hashtags regionsbank_tweets.csv
# Updating hashtags ebay_tweets.csv
# Updating hashtags nvidia_tweets.csv
# Updating hashtags verisk_tweets.csv
# Updating hashtags wbd_tweets.csv
# Updating hashtags gardein_tweets.csv
# Updating hashtags qorvoinc_tweets.csv
# Updating hashtags ecolab_tweets.csv
# Updating hashtags hp_tweets.csv
# Updating hashtags generaldynamics_tweets.csv
# Updating hashtags boeing_tweets.csv
# Updating hashtags kelloggsus_tweets.csv
# Updating hashtags tylertech_tweets.csv
# Updating hashtags jnjnews_tweets.csv
# Updating hashtags wellsfargo_tweets.csv
# Updating hashtags hologic_tweets.csv
# Updating hashtags nrgenergy_tweets.csv
# Updating hashtags dxctechnology_tweets.csv
# Updating hashtags newmontcorp_tweets.csv
# Updating hashtags westpharma_tweets.csv
# Updating hashtags walmart_tweets.csv
# Updating hashtags emerson_news_tweets.csv
# Updating hashtags nike_tweets.csv
# Updating hashtags chubb_tweets.csv
# Updating hashtags omnicom_tweets.csv
# Updating hashtags autozone_tweets.csv
# Updating hashtags microntech_tweets.csv
# Updating hashtags danahercorp_tweets.csv
# Updating hashtags exxonmobil_tweets.csv
# Updating hashtags uhs_inc_tweets.csv
# Updating hashtags entergy_tweets.csv
# Updating hashtags prudential_tweets.csv
# Updating hashtags wba_global_tweets.csv
# Updating hashtags mdlz_tweets.csv
# Updating hashtags edison_energy_tweets.csv
# Updating hashtags bioradlifesci_tweets.csv
# Updating hashtags zoetis_tweets.csv
# Updating hashtags henryschein_tweets.csv
# Updating hashtags comcast_tweets.csv
# Updating hashtags servicenownews_tweets.csv
# Updating hashtags gm_tweets.csv
# Updating hashtags cloroxco_tweets.csv
# Updating hashtags pentair_tweets.csv
# Updating hashtags quanta_services_tweets.csv
# Updating hashtags southerncompany_tweets.csv
# Updating hashtags bostonsci_tweets.csv
# Updating hashtags biotechne_tweets.csv
# Updating hashtags marathonpetroco_tweets.csv
# Updating hashtags interpublicipg_tweets.csv
# Updating hashtags microsoft_tweets.csv
# Updating hashtags psegdelivers_tweets.csv
# Updating hashtags ptc_tweets.csv
# Updating hashtags sempra_tweets.csv
# Updating hashtags questdx_tweets.csv
# Updating hashtags cocacolaco_tweets.csv
# Updating hashtags digitalrealty_tweets.csv
# Updating hashtags travelers_tweets.csv
# Updating hashtags camdenliving_tweets.csv
# Updating hashtags campbells_tweets.csv
# Updating hashtags iff_tweets.csv
# Updating hashtags silversea_tweets.csv
# Updating hashtags devonenergy_tweets.csv
# Updating hashtags cadence_tweets.csv
# Updating hashtags abiomed_tweets.csv
# Updating hashtags newsfromrcgroup_tweets.csv
# Updating hashtags coterraenergy_tweets.csv
# Updating hashtags aflac_tweets.csv
# Updating hashtags wearehii_tweets.csv
# Updating hashtags eversourcema_tweets.csv
# Updating hashtags elevancehealth_tweets.csv
# Updating hashtags halliburton_tweets.csv
# Updating hashtags pizzahut_tweets.csv
# Updating hashtags goldmansachs_tweets.csv
# Updating hashtags bestbuy_tweets.csv
# Updating hashtags 3m_tweets.csv
# Updating hashtags proctergamble_tweets.csv
# Updating hashtags edisonintl_tweets.csv
# Updating hashtags delta_tweets.csv
# Updating hashtags insidepmi_tweets.csv
# Updating hashtags medtronic_tweets.csv
# Updating hashtags zimmerbiomet_tweets.csv
# Updating hashtags amazonnews_tweets.csv
# Updating hashtags mercer_tweets.csv
# Updating hashtags hotwire_tweets.csv
# Updating hashtags hinge_tweets.csv
# Updating hashtags xcelenergy_tweets.csv
# Updating hashtags unionpacific_tweets.csv
# Updating hashtags snapon_tools_tweets.csv
# Updating hashtags amcorpackaging_tweets.csv
# Updating hashtags statestreet_tweets.csv
# Updating hashtags nucorcorp_tweets.csv
# Updating hashtags bdandco_tweets.csv
# Updating hashtags fifththird_tweets.csv
# Updating hashtags citi_tweets.csv
# Updating hashtags perkinelmer_tweets.csv
# Updating hashtags carnivalplc_tweets.csv
# Updating hashtags lkqcorp_tweets.csv
# Updating hashtags protiviti_tweets.csv
# Updating hashtags albemarlecorp_tweets.csv
# Updating hashtags msci_inc_tweets.csv
# Updating hashtags centene_tweets.csv
# Updating hashtags biogen_tweets.csv
# Updating hashtags conedison_tweets.csv
# Updating hashtags expd_official_tweets.csv
# Updating hashtags dovercorp_tweets.csv
# Updating hashtags keybank_tweets.csv
# Updating hashtags rokautomation_tweets.csv
# Updating hashtags constellationeg_tweets.csv
# Updating hashtags fastenalcompany_tweets.csv
# Updating hashtags livenation_tweets.csv
# Updating hashtags fmccorp_tweets.csv
# Updating hashtags boomchickapop_tweets.csv
# Updating hashtags jbhunt360_tweets.csv
# Updating hashtags amazon_tweets.csv
# Updating hashtags pepsico_tweets.csv
# Updating hashtags vfcorp_tweets.csv
# Updating hashtags dish_tweets.csv
# Updating hashtags oreillyauto_tweets.csv
# Updating hashtags tacobell_tweets.csv
# Updating hashtags aepnews_tweets.csv
# Updating hashtags johnsoncontrols_tweets.csv
# Updating hashtags etsy_tweets.csv
# Updating hashtags honeywell_tweets.csv
# Updating hashtags sce_tweets.csv
# Updating hashtags republicservice_tweets.csv
# Updating hashtags eatoncorp_tweets.csv
# Updating hashtags caesarsent_tweets.csv
# Updating hashtags quickbooks_tweets.csv
# Updating hashtags lockheedmartin_tweets.csv
# Updating hashtags carrier_tweets.csv
# Updating hashtags weyerhaeuser_tweets.csv
# Updating hashtags troweprice_tweets.csv
# Updating hashtags westerndigital_tweets.csv
# Updating hashtags everest_re_tweets.csv
# Updating hashtags borgwarner_tweets.csv
# Updating hashtags assurant_tweets.csv
# Updating hashtags getspectrum_tweets.csv
# Updating hashtags darden_tweets.csv
# Updating hashtags williamsupdates_tweets.csv
# Updating hashtags yumbrands_tweets.csv
# Updating hashtags maacommunities_tweets.csv
# Updating hashtags king_games_tweets.csv
# Updating hashtags allstate_tweets.csv
# Updating hashtags fiberondecking_tweets.csv
# Updating hashtags plentyoffish_tweets.csv
# Updating hashtags creditkarma_tweets.csv
# Updating hashtags hasbro_tweets.csv
# Updating hashtags johndeere_tweets.csv
# Updating hashtags brinknewsnow_tweets.csv
# Updating hashtags match_tweets.csv
# Updating hashtags hlcruises_tweets.csv
# Updating hashtags molinahealth_tweets.csv
# Updating hashtags amerencorp_tweets.csv
# Updating hashtags lincolnfingroup_tweets.csv
# Updating hashtags ibm_tweets.csv
# Updating hashtags seagate_tweets.csv
# Updating hashtags aptiv_tweets.csv
# Updating hashtags dte_energy_tweets.csv
# Updating hashtags junipernetworks_tweets.csv
# Updating hashtags motosolutions_tweets.csv
# Updating hashtags corning_tweets.csv
# Updating hashtags marketaxess_tweets.csv
# Updating hashtags vrbo_tweets.csv
# Updating hashtags lillypad_tweets.csv
# Updating hashtags stryker_st_tweets.csv
# Updating hashtags westrock_tweets.csv
# Updating hashtags paycom_tweets.csv
# Updating hashtags orbitz_tweets.csv
# Updating hashtags ralphlauren_tweets.csv
# Updating hashtags invescous_tweets.csv
# Updating hashtags bmsnews_tweets.csv
# Updating hashtags chubbna_tweets.csv
# Updating hashtags blackrock_tweets.csv
# Updating hashtags sysco_tweets.csv
# Updating hashtags parkerhannifin_tweets.csv
# Updating hashtags baxter_intl_tweets.csv
# Updating hashtags ourtimedating_tweets.csv
# Updating hashtags tractorsupply_tweets.csv
# Updating hashtags equityres_tweets.csv
# Updating hashtags metlife_tweets.csv
# Updating hashtags ppg_tweets.csv
# Updating hashtags illumina_tweets.csv
# Updating hashtags lumentechco_tweets.csv
# Updating hashtags fm_fcx_tweets.csv
# Updating hashtags roberthalf_tweets.csv
# Updating hashtags hotelsdotcom_tweets.csv
# Updating hashtags teconnectivity_tweets.csv
# Updating hashtags jacobsconnects_tweets.csv
# Updating hashtags unitedrentals_tweets.csv
# Updating hashtags adp_tweets.csv
# Updating hashtags corteva_tweets.csv
# Updating hashtags kfc_tweets.csv
# Updating hashtags invisalign_tweets.csv
# Updating hashtags fedex_tweets.csv
# Updating hashtags jpmorgan_tweets.csv
# Updating hashtags generalelectric_tweets.csv
# Updating hashtags cmegroup_tweets.csv
# Updating hashtags davita_tweets.csv
# Updating hashtags accenture_us_tweets.csv
# Updating hashtags discover_tweets.csv
# Updating hashtags generac_tweets.csv
# Updating hashtags dollartree_tweets.csv
# Updating hashtags fortinet_tweets.csv
# Updating hashtags trimblecorpnews_tweets.csv
# Updating hashtags caterpillarinc_tweets.csv
# Updating hashtags verizon_tweets.csv
# Updating hashtags l3harristech_tweets.csv
# Updating hashtags phillips66co_tweets.csv
# Updating hashtags lindeplc_tweets.csv
# Updating hashtags adi_news_tweets.csv

# %%
frequent_hashtags = dict(filter(lambda pair: pair[1] >= 10, # check that the value is >= 10
            hashtag_company_usage_counts.items()))

frequent_hashtags
# Out:
# {'100bestcc': 53,
#  '100bestcos': 25,
#  '100cei': 11,
#  '100companiescare': 17,
#  '100forhealthyfamilies': 14,
#  '10yearchallenge': 12,
#  '19thamendment': 12,
#  '2021spglobalyearbook': 10,
#  '3d': 49,
#  '3dprinted': 11,
#  '3dprinter': 10,
#  '3dprinting': 61,
#  '401k': 18,
#  '40under40': 25,
#  '4g': 13,
#  '4ir': 17,
#  '4thofjuly': 140,
#  '50companiescare': 12,
#  '5g': 86,
#  '5k': 11,
#  '811day': 26,
#  '911day': 17,
#  'aacr19': 12,
#  'aapi': 79,
#  'aapiheritagemonth': 105,
#  'aapihm': 47,
#  'abudhabi': 12,
#  'aca': 12,
#  'access': 12,
#  'accessibility': 25,
#  'accounting': 22,
#  'acquisition': 46,
#  'acquisitions': 22,
#  'active': 14,
#  'actonclimate': 25,
#  'ad': 163,
#  'ada': 11,
#  'ada30': 15,
#  'adalovelaceday': 15,
#  'adas': 21,
#  'additivemanufacturing': 16,
#  'administrativeprofessionalsday': 20,
#  'adminprofessionalsday': 13,
#  'adobesummit': 11,
#  'adoption': 15,
#  'adventure': 17,
#  'advertising': 24,
#  'advice': 20,
#  'advisors': 11,
#  'advmfgexpo': 11,
#  'advocacy': 15,
#  'aerospace': 47,
#  'aeroweek': 12,
#  'affordable': 13,
#  'affordablehousing': 16,
#  'africa': 35,
#  'ag': 16,
#  'agday': 14,
#  'agile': 47,
#  'agility': 14,
#  'aging': 18,
#  'agricultural': 11,
#  'agriculture': 58,
#  'agtech': 17,
#  'ai': 206,
#  'aids': 13,
#  'aircraft': 23,
#  'airforce': 18,
#  'airline': 10,
#  'airlines': 19,
#  'airpollution': 13,
#  'airport': 13,
#  'airports': 14,
#  'airquality': 20,
#  'al': 10,
#  'alabama': 14,
#  'alaska': 16,
#  'alexa': 14,
#  'algorithms': 13,
#  'allergies': 11,
#  'allies': 11,
#  'allin': 14,
#  'allstargame': 14,
#  'ally': 19,
#  'allyship': 18,
#  'als': 19,
#  'alsicebucketchallenge': 10,
#  'aluminum': 10,
#  'alzheimer': 18,
#  'alzheimers': 26,
#  'ama': 12,
#  'amazing': 14,
#  'amazon': 21,
#  'america': 41,
#  'american': 17,
#  'americanheartmonth': 34,
#  'americans': 13,
#  'americarecyclesday': 51,
#  'americasbestemployers': 12,
#  'americasmostjust': 51,
#  'aml': 15,
#  'amr': 13,
#  'amsterdam': 25,
#  'analysis': 17,
#  'analytics': 101,
#  'android': 20,
#  'angeltree': 12,
#  'animals': 10,
#  'anniversary': 21,
#  'announcement': 10,
#  'annualreport': 27,
#  'antibioticresistance': 11,
#  'antibiotics': 12,
#  'antibodies': 11,
#  'antibody': 14,
#  'anxiety': 13,
#  'apac': 31,
#  'apahm': 63,
#  'api': 27,
#  'apis': 19,
#  'apollo': 11,
#  'apollo11': 27,
#  'apollo50': 11,
#  'apollo50th': 32,
#  'app': 39,
#  'apple': 28,
#  'applepay': 10,
#  'application': 13,
#  'applications': 23,
#  'apply': 11,
#  'applynow': 10,
#  'apprenticeship': 13,
#  'apprenticeships': 11,
#  'apps': 22,
#  'aprilfools': 32,
#  'aprilfoolsday': 24,
#  'ar': 76,
#  'arborday': 49,
#  'architecture': 40,
#  'areyouin': 39,
#  'argentina': 18,
#  'arizona': 32,
#  'arkansas': 14,
#  'armedforcesday': 31,
#  'armisticeday': 11,
#  'army': 21,
#  'art': 50,
#  'artemis': 10,
#  'artificialintelligence': 107,
#  'arts': 12,
#  'asco18': 11,
#  'asco19': 12,
#  'asco20': 12,
#  'asco21': 11,
#  'asco22': 12,
#  'asean': 11,
#  'ash20': 13,
#  'ash21': 10,
#  'asia': 42,
#  'asianpacificamericanheritagemonth': 17,
#  'asiapacific': 17,
#  'aspenideas': 11,
#  'assetmanagement': 31,
#  'assetmanagers': 11,
#  'asthma': 10,
#  'atl': 32,
#  'atlanta': 68,
#  'audit': 10,
#  'augmentedreality': 52,
#  'austin': 37,
#  'australia': 68,
#  'authentication': 14,
#  'autism': 32,
#  'autismawareness': 10,
#  'autismawarenessmonth': 13,
#  'auto': 41,
#  'automakers': 10,
#  'automated': 16,
#  'automation': 118,
#  'automotive': 78,
#  'automotiveindustry': 15,
#  'autonomous': 43,
#  'autonomouscars': 10,
#  'autonomousdriving': 20,
#  'autonomousvehicle': 19,
#  'autonomousvehicles': 42,
#  'autonomy': 16,
#  'autumn': 23,
#  'av': 16,
#  'avgeek': 15,
#  'aviation': 44,
#  'aviationday': 12,
#  'avs': 10,
#  'award': 57,
#  'awards': 53,
#  'awareness': 19,
#  'awesome': 19,
#  'awnewyork': 13,
#  'aws': 43,
#  'awssummit': 10,
#  'azure': 28,
#  'b2b': 32,
#  'babyboomers': 20,
#  'bachelornation': 10,
#  'backtoschool': 134,
#  'backtothefuture': 13,
#  'bahamas': 10,
#  'balanceforbetter': 111,
#  'baltimore': 30,
#  'bandwidth': 12,
#  'bangalore': 11,
#  'bank': 20,
#  'banking': 45,
#  'banks': 32,
#  'barcconsumer': 13,
#  'barcelona': 19,
#  'baseball': 29,
#  'basketball': 15,
#  'bastilleday': 11,
#  'batteries': 23,
#  'battery': 39,
#  'batterystorage': 16,
#  'bayarea': 24,
#  'bbq': 23,
#  'bcam': 21,
#  'beach': 16,
#  'beatairpollution': 14,
#  'beatplasticpollution': 10,
#  'beattheheat': 15,
#  'beauty': 20,
#  'beboldforchange': 32,
#  'becybersmart': 60,
#  'beer': 24,
#  'bees': 20,
#  'beforeandafter': 10,
#  'behindthescenes': 50,
#  'beijing': 13,
#  'belgium': 12,
#  'belonging': 15,
#  'benefit': 10,
#  'benefits': 41,
#  'bengaluru': 10,
#  'beready': 13,
#  'berecycled': 17,
#  'berlin': 18,
#  'bermuda': 10,
#  'best': 10,
#  'bestforvets': 14,
#  'bestforworkers': 10,
#  'bestofthebest': 10,
#  'bestplacesit': 14,
#  'bestplacestowork': 30,
#  'bestplacetowork': 63,
#  'bestpractices': 20,
#  'bestworkplaces': 40,
#  'bethechange': 17,
#  'betheforce': 12,
#  'bettertogether': 53,
#  'beverage': 21,
#  'bhgawards': 10,
#  'bhm': 70,
#  'bigawards': 13,
#  'bigdata': 126,
#  'biggame': 33,
#  'bigtech': 10,
#  'bike': 12,
#  'bikems': 13,
#  'biketoworkday': 25,
#  'bio2018': 12,
#  'bio2019': 15,
#  'biodiversity': 38,
#  'biofuels': 10,
#  'biogas': 11,
#  'biologics': 15,
#  'biology': 17,
#  'biomarker': 14,
#  'biomarkers': 16,
#  'biomedical': 15,
#  'biometric': 18,
#  'biometrics': 20,
#  'biopharma': 38,
#  'biopharmaceutical': 11,
#  'bioprocessing': 11,
#  'biosimilar': 12,
#  'biosimilars': 16,
#  'biotech': 49,
#  'biotechnology': 20,
#  'bipoc': 11,
#  'birmingham': 11,
#  'birthday': 23,
#  'bisummit': 12,
#  'bitcoin': 30,
#  'biz': 13,
#  'blackbusinessmonth': 14,
#  'blackexcellence': 15,
#  'blackfriday': 123,
#  'blackhistory': 17,
#  'blackhistorymonth': 306,
#  'blacklivesmatter': 30,
#  'blackouttuesday': 24,
#  'blessed': 10,
#  'blm': 12,
#  'blockchain': 91,
#  'blog': 70,
#  'bloodcancer': 15,
#  'bloodcancerawarenessmonth': 12,
#  'bloomberg': 11,
#  'bloombergequality': 16,
#  'bloomberggei': 64,
#  'bluetooth': 19,
#  'bnefsummit': 12,
#  'bnpl': 10,
#  'board': 10,
#  'boarddiversity': 11,
#  'boardofdirectors': 20,
#  'boeing': 10,
#  'bonds': 16,
#  'bookloversday': 20,
#  'books': 19,
#  'boomers': 13,
#  'boston': 69,
#  'bostonmarathon': 16,
#  'bpms150': 11,
#  'bptw': 15,
#  'brain': 15,
#  'brand': 42,
#  'branding': 25,
#  'brands': 23,
#  'brazil': 50,
#  'breakfast': 25,
#  'breaking': 37,
#  'breakingnews': 17,
#  'breakingthebias': 10,
#  'breakthebias': 180,
#  'breastcancer': 64,
#  'breastcancerawareness': 56,
#  'breastcancerawarenessmonth': 77,
#  'brexit': 37,
#  'bringyourchildtoworkday': 11,
#  'broadband': 25,
#  'brokers': 11,
#  'brooklyn': 20,
#  'brunch': 15,
#  'brussels': 10,
#  'bts': 36,
#  'budget': 25,
#  'buffalo': 13,
#  'buildbackbetter': 15,
#  'building': 16,
#  'buildings': 10,
#  'burnout': 15,
#  'business': 148,
#  'businesscontinuity': 22,
#  'businesses': 18,
#  'businessgrowth': 10,
#  'businessintelligence': 12,
#  'ca': 21,
#  'cad': 10,
#  'cagny': 11,
#  'california': 76,
#  'californiawildfires': 10,
#  'call811': 27,
#  'callbeforeyoudig': 17,
#  'camera': 13,
#  'campfire': 15,
#  'camping': 11,
#  'canada': 69,
#  'canadaday': 26,
#  'canadian': 10,
#  'cancer': 72,
#  'cancercare': 13,
#  'cancerresearch': 24,
#  'cancers': 11,
#  'cannabis': 10,
#  'canneslions': 14,
#  'capital': 14,
#  'capitalmarkets': 19,
#  'car': 30,
#  'carbon': 61,
#  'carboncapture': 20,
#  'carbonemissions': 25,
#  'carbonfootprint': 38,
#  'carbonfree': 11,
#  'carbonneutral': 32,
#  'carbonneutrality': 22,
#  'carbonreduction': 13,
#  'cardiovascular': 16,
#  'career': 163,
#  'careeradvice': 30,
#  'careerdevelopment': 32,
#  'careerfair': 36,
#  'careeropportunities': 13,
#  'careers': 134,
#  'careersinenergyweek': 17,
#  'caregivers': 20,
#  'caresact': 13,
#  'cargo': 11,
#  'caribbean': 17,
#  'cars': 22,
#  'casestudy': 24,
#  'cash': 13,
#  'cat': 12,
#  'catalystforchange': 23,
#  'cats': 11,
#  'ccs': 10,
#  'cdc': 12,
#  'cdo': 16,
#  'cdpalist': 27,
#  'cdpsupplychain': 27,
#  'cei2016': 11,
#  'cei2017': 19,
#  'cei2018': 32,
#  'cei2019': 46,
#  'cei2020': 52,
#  'cei2021': 95,
#  'cei2022': 104,
#  'celebrate': 30,
#  'celebratediversitymonth': 17,
#  'celebration': 14,
#  'cell': 10,
#  'celltherapy': 20,
#  'ceo': 105,
#  'ceoaction': 61,
#  'ceos': 16,
#  'ceraweek': 27,
#  'certification': 12,
#  'cervicalcancer': 10,
#  'ces': 36,
#  'ces2016': 17,
#  'ces2017': 25,
#  'ces2018': 27,
#  'ces2019': 35,
#  'ces2020': 46,
#  'ces2021': 28,
#  'ces2022': 34,
#  'cfo': 37,
#  'cfos': 11,
#  'challenge': 11,
#  'challenges': 11,
#  'change': 24,
#  'changemakers': 15,
#  'changemanagement': 17,
#  'changetheworld': 39,
#  'charity': 50,
#  'charityday': 11,
#  'charleston': 10,
#  'charlotte': 33,
#  'chatbots': 12,
#  'cheddarlive': 27,
#  'cheers': 16,
#  'chemical': 22,
#  'chemicals': 17,
#  'chemistry': 33,
#  'chicago': 99,
#  'chicken': 10,
#  'children': 20,
#  'chile': 22,
#  'china': 78,
#  'chinese': 11,
#  'chinesenewyear': 46,
#  'chip': 15,
#  'chipsact': 15,
#  'chocolate': 15,
#  'choosetochallenge': 154,
#  'christmas': 66,
#  'christmaseve': 18,
#  'chro': 30,
#  'cincinnati': 17,
#  'cincodemayo': 60,
#  'cio': 85,
#  'cio100': 30,
#  'cios': 17,
#  'circular': 10,
#  'circulareconomy': 50,
#  'circularity': 13,
#  'ciso': 36,
#  'cisos': 12,
#  'cities': 16,
#  'civic50': 16,
#  'claims': 15,
#  'cle': 10,
#  'clean': 27,
#  'cleanair': 14,
#  'cleanenergy': 93,
#  'cleanenergyfuture': 11,
#  'cleanenergyweek': 15,
#  'cleaning': 15,
#  'cleanpower': 11,
#  'cleantech': 24,
#  'cleanwater': 21,
#  'cleveland': 24,
#  'client': 18,
#  'climate': 96,
#  'climateaction': 92,
#  'climateactionnow': 10,
#  'climatechange': 164,
#  'climatecrisis': 28,
#  'climaterisk': 16,
#  'climatesolutions': 11,
#  'climateweek': 48,
#  'climateweeknyc': 61,
#  'clinical': 19,
#  'clinicalresearch': 15,
#  'clinicaltrial': 18,
#  'clinicaltrials': 29,
#  'clinicaltrialsday': 13,
#  'closethecaregap': 13,
#  'closethegendergap': 21,
#  'closingbell': 16,
#  'cloud': 120,
#  'cloudcomputing': 44,
#  'cloudnative': 15,
#  'cloudnativecon': 10,
#  'cloudsecurity': 17,
#  'clt': 11,
#  'cmo': 30,
#  'cmos': 11,
#  'cnbcatwork': 10,
#  'cnbcevolve': 10,
#  'cng': 12,
#  'co': 11,
#  'co2': 39,
#  'coal': 22,
#  'cocktail': 10,
#  'cocktails': 10,
#  'code': 14,
#  'coding': 27,
#  'coffee': 37,
#  'cold': 10,
#  'coldchain': 14,
#  'collaborate': 13,
#  'collaboration': 95,
#  'college': 40,
#  'collegefootball': 12,
#  'collisionconf': 10,
#  'colombia': 20,
#  'color': 14,
#  'colorado': 36,
#  'colorectalcancer': 18,
#  'colorectalcancerawarenessmonth': 12,
#  'columbus': 18,
#  'comingoutday': 10,
#  'comingsoon': 23,
#  'commerce': 19,
#  'commercial': 26,
#  'commercialrealestate': 14,
#  'commitment': 13,
#  'committed2clean': 15,
#  'commodities': 12,
#  'communication': 36,
#  'communications': 45,
#  'communities': 61,
#  'community': 159,
#  'communityengagement': 11,
#  'communitypartners': 11,
#  'communityservice': 10,
#  'communitysolar': 10,
#  'communitysupport': 10,
#  'companyculture': 32,
#  'compensation': 12,
#  'competition': 18,
#  'compliance': 68,
#  'computers': 11,
#  'computerscience': 20,
#  'computervision': 12,
#  'computing': 23,
#  'concrete': 12,
#  'conference': 41,
#  'confidence': 10,
#  'congrats': 32,
#  'congratulations': 45,
#  'congress': 13,
#  'connect': 16,
#  'connect2earth': 10,
#  'connected': 26,
#  'connectedcar': 16,
#  'connectedcars': 11,
#  'connecteddevices': 11,
#  'connecticut': 14,
#  'connectivity': 44,
#  'conservation': 55,
#  'construction': 88,
#  'consulting': 11,
#  'consumer': 32,
#  'consumers': 26,
#  'contactless': 12,
#  'container': 12,
#  'containers': 13,
#  'content': 13,
#  'contentmarketing': 12,
#  'contest': 51,
#  'contractors': 15,
#  'control': 14,
#  'cooking': 15,
#  'cool': 10,
#  'cop21': 14,
#  'cop26': 80,
#  'cop27': 26,
#  'copper': 13,
#  'corevalues': 10,
#  'coronavirus': 163,
#  'corpgov': 33,
#  'corporate': 18,
#  'corporatechallenge': 10,
#  'corporatecitizenship': 19,
#  'corporateculture': 12,
#  'corporategovernance': 11,
#  'corporateresponsibility': 47,
#  'corporatesocialresponsibility': 19,
#  'cosmetics': 11,
#  'costarica': 13,
#  'costume': 10,
#  'countdown': 12,
#  'countdowntomars': 19,
#  'covid': 151,
#  'covid19': 319,
#  'covid19vaccine': 19,
#  'covid_19': 37,
#  'covidvaccine': 17,
#  'covidー19': 18,
#  'cpg': 18,
#  'cpr': 13,
#  'craft': 11,
#  'craftbeer': 13,
#  'cre': 30,
#  'creative': 24,
#  'creativity': 23,
#  'creatorsrespond': 13,
#  'creatorswanted': 18,
#  'credit': 21,
#  'crisis': 11,
#  'crispr': 15,
#  'crm': 13,
#  'crude': 11,
#  'crudeoil': 13,
#  'crypto': 38,
#  'cryptocurrencies': 17,
#  'cryptocurrency': 48,
#  'csedweek': 12,
#  'cso': 10,
#  'csr': 175,
#  'csuite': 24,
#  'ct': 13,
#  'ctd2021': 10,
#  'cte': 10,
#  'cto': 31,
#  'culture': 111,
#  'curiosity': 11,
#  'customer': 30,
#  'customerexperience': 65,
#  'customers': 33,
#  'customerservice': 64,
#  'customerserviceweek': 30,
#  'customersuccess': 12,
#  'cutyourenergycostsday': 13,
#  'cvd': 10,
#  'cx': 58,
#  'cxo': 10,
#  'cxotalk': 13,
#  'cyber': 58,
#  'cyberattack': 36,
#  'cyberattacks': 46,
#  'cyberaware': 34,
#  'cybercrime': 36,
#  'cybercriminals': 18,
#  'cyberinsurance': 13,
#  'cybermonday': 97,
#  'cyberrisk': 23,
#  'cyberrisks': 14,
#  'cybersecurity': 164,
#  'cybersecurityawareness': 16,
#  'cybersecurityawarenessmonth': 73,
#  'cybersecuritymonth': 27,
#  'cyberthreats': 28,
#  'cycling': 12,
#  'dad': 16,
#  'dadjokes': 12,
#  'dads': 12,
#  'dairy': 10,
#  'dallas': 58,
#  'dance': 11,
#  'data': 185,
#  'dataanalysis': 14,
#  'dataanalytics': 51,
#  'database': 11,
#  'databreach': 13,
#  'datacenter': 43,
#  'datacenters': 39,
#  'datadriven': 13,
#  'dataforgood': 10,
#  'datamanagement': 32,
#  'dataprivacy': 37,
#  'dataprivacyday': 40,
#  'dataprotection': 23,
#  'datascience': 61,
#  'datasecurity': 29,
#  'datasharing': 10,
#  'datastorage': 10,
#  'datavisualization': 10,
#  'davos': 30,
#  'davos2020': 12,
#  'davosagenda': 26,
#  'daylightsaving': 12,
#  'daylightsavings': 33,
#  'daylightsavingstime': 15,
#  'daylightsavingtime': 35,
#  'dayofcaring': 30,
#  'dayofservice': 25,
#  'dayofthegirl': 54,
#  'dayofunderstanding': 11,
#  'daytona500': 17,
#  'dbpinclusionindex': 18,
#  'dc': 51,
#  'ddos': 10,
#  'deal': 10,
#  'deals': 13,
#  'deam': 13,
#  'debt': 22,
#  'decarbonization': 42,
#  'decarbonize': 11,
#  'december': 10,
#  'decor': 13,
#  'deeplearning': 32,
#  'defense': 28,
#  'deforestation': 14,
#  'dei': 168,
#  'dei22': 26,
#  'delicious': 11,
#  'delivery': 17,
#  'dementia': 15,
#  'demo': 12,
#  'dental': 11,
#  'denver': 47,
#  'depression': 15,
#  'derivatives': 10,
#  'design': 91,
#  'designers': 12,
#  'designthinking': 20,
#  'dessert': 12,
#  'detroit': 33,
#  'developer': 27,
#  'developers': 26,
#  'development': 54,
#  'devices': 11,
#  'devops': 34,
#  'devsecops': 10,
#  'dfw': 17,
#  'diabetes': 57,
#  'diabetesawarenessmonth': 19,
#  'diagnostic': 15,
#  'diagnostics': 20,
#  'didyouknow': 156,
#  'diesel': 13,
#  'digital': 159,
#  'digitalassets': 12,
#  'digitalbanking': 13,
#  'digitaldisruption': 11,
#  'digitaldivide': 22,
#  'digitaleconomy': 14,
#  'digitalexperience': 12,
#  'digitalhealth': 56,
#  'digitalinnovation': 15,
#  'digitalization': 43,
#  'digitalmarketing': 29,
#  'digitalpayments': 11,
#  'digitalsolutions': 11,
#  'digitaltransformation': 135,
#  'digitaltwin': 20,
#  'digitaltwins': 15,
#  'digitization': 30,
#  'digsafe': 11,
#  'dinner': 10,
#  'disabilities': 24,
#  'disability': 40,
#  'disabilityawarenessmonth': 10,
#  'disabilityinclusion': 74,
#  'disabilitypridemonth': 11,
#  'disasterrecovery': 14,
#  'disasterrelief': 14,
#  'discovery': 15,
#  'disease': 12,
#  'disney': 11,
#  'display': 11,
#  'disruption': 32,
#  'distracteddriving': 13,
#  'distribution': 26,
#  'ditop50': 45,
#  'diverse': 62,
#  'diversity': 259,
#  'diversityandinclusion': 130,
#  'diversityequityinclusion': 13,
#  'diversityinc': 12,
#  'diversitymatters': 24,
#  'diversitymonth': 10,
#  'dividend': 26,
#  'diwali': 59,
#  'diy': 66,
#  'djsi': 71,
#  'dna': 27,
#  'dog': 20,
#  'dogood': 13,
#  'dogs': 26,
#  'dogsoftwitter': 12,
#  'domesticviolence': 10,
#  'donate': 39,
#  'donation': 22,
#  'donations': 17,
#  'dorian': 22,
#  'downstream': 11,
#  'dreambig': 13,
#  'dreamers': 13,
#  'dreamteam': 16,
#  'drilling': 10,
#  'driveelectric': 10,
#  'driver': 10,
#  'driverless': 12,
#  'driverlesscars': 11,
#  'drivers': 10,
#  'drivesafe': 10,
#  'driving': 11,
#  'drone': 48,
#  'drones': 59,
#  'drought': 10,
#  'drug': 10,
#  'drugdevelopment': 14,
#  'drugdiscovery': 18,
#  'dubai': 41,
#  'dublin': 16,
#  'dubnation': 14,
#  'dx': 15,
#  'dyk': 205,
#  'eachforequal': 117,
#  'eagles': 16,
#  'earnings': 111,
#  'earth': 10,
#  'earthday': 382,
#  'earthday2016': 19,
#  'earthday2018': 19,
#  'earthday2019': 27,
#  'earthday2020': 53,
#  'earthday2021': 79,
#  'earthday2022': 69,
#  'earthday50': 18,
#  'earthdayeveryday': 18,
#  'earthhour': 25,
#  'earthmonth': 64,
#  'earthquake': 22,
#  'earthweek': 45,
#  'easter': 39,
#  'ebola': 12,
#  'ebook': 20,
#  'eclipse': 15,
#  'eclipse2017': 25,
#  'ecofriendly': 26,
#  'ecommerce': 69,
#  'econdev': 22,
#  'economic': 37,
#  'economicdevelopment': 12,
#  'economicgrowth': 12,
#  'economics': 20,
#  'economy': 73,
#  'ecosystem': 16,
#  'ecosystems': 11,
#  'edge': 37,
#  'edgecomputing': 34,
#  'edtech': 33,
#  'educate': 10,
#  'education': 162,
#  'educationday': 10,
#  'eeday2019': 11,
#  'eeday2021': 14,
#  'efficiency': 73,
#  'efficient': 19,
#  'egypt': 13,
#  'ehr': 13,
#  'elearning': 16,
#  'election': 18,
#  'election2016': 14,
#  'election2020': 20,
#  'electionday': 39,
#  'electric': 39,
#  'electrical': 13,
#  'electricalsafety': 10,
#  'electriccar': 10,
#  'electriccars': 16,
#  'electricity': 40,
#  'electricvehicle': 51,
#  'electricvehicles': 81,
#  'electrification': 33,
#  'electronic': 11,
#  'electronics': 30,
#  'embedded': 17,
#  'embracingsustainability': 23,
#  'emea': 20,
#  'emergency': 16,
#  'emergingmarkets': 21,
#  'emergingtech': 19,
#  'emissions': 67,
#  'emmy': 11,
#  'emmys': 14,
#  'emobility': 15,
#  'empathy': 16,
#  'employee': 30,
#  'employeeappreciation': 21,
#  'employeeappreciationday': 110,
#  'employeebenefits': 22,
#  'employeeengagement': 58,
#  'employeeexperience': 25,
#  'employees': 45,
#  'employeespotlight': 18,
#  'employeewellness': 11,
#  'employer': 12,
#  'employers': 18,
#  'employment': 25,
#  'empower': 15,
#  'empowerment': 17,
#  'encryption': 12,
#  'endalz': 19,
#  'endcancer': 14,
#  'endhunger': 34,
#  'energy': 171,
#  'energyawarenessmonth': 25,
#  'energychoicescount': 12,
#  'energyefficiency': 80,
#  'energyefficient': 38,
#  'energyindustry': 16,
#  'energymanagement': 14,
#  'energysaving': 12,
#  'energysavings': 19,
#  'energysecurity': 12,
#  'energystar': 26,
#  'energystarawards': 19,
#  'energystarday': 16,
#  'energystarpoy': 10,
#  'energystorage': 31,
#  'energytransition': 39,
#  'energytwitter': 15,
#  'engagement': 34,
#  'engineer': 71,
#  'engineering': 150,
#  'engineeringheroes': 12,
#  'engineeringjobs': 16,
#  'engineers': 91,
#  'engineersweek': 53,
#  'enterprise': 32,
#  'enterprisetech': 17,
#  'entertainment': 30,
#  'entrepreneur': 40,
#  'entrepreneurs': 52,
#  'entrepreneurship': 33,
#  'environment': 144,
#  'environmental': 102,
#  'epa': 11,
#  'equality': 103,
#  'equalityact': 43,
#  'equalityforall': 10,
#  'equalpay': 18,
#  'equalpayday': 38,
#  'equipment': 14,
#  'equitable': 12,
#  'equities': 13,
#  'equity': 117,
#  'erg': 17,
#  'ergonomics': 12,
#  'erp': 11,
#  'esccongress': 10,
#  'esg': 216,
#  'esginvesting': 12,
#  'esgreport': 11,
#  'esports': 27,
#  'essential': 10,
#  'essentialworkers': 20,
#  'etf': 16,
#  'etfs': 17,
#  'ethernet': 19,
#  'ethical': 13,
#  'ethics': 41,
#  'eu': 38,
#  'eugreendeal': 11,
#  'europe': 64,
#  'european': 16,
#  'ev': 86,
#  'evcharging': 22,
#  'event': 30,
#  'eventprofs': 13,
#  'events': 29,
#  'evs': 52,
#  'eweek': 12,
#  'eweek2017': 14,
#  'eweek2018': 19,
#  'eweek2019': 20,
#  'eweek2020': 26,
#  'eweek2021': 17,
#  'eweek2022': 26,
#  'excellence': 17,
#  'excited': 11,
#  'exclusive': 18,
#  'executives': 10,
#  'exercise': 15,
#  'expansion': 12,
#  ...}

# %%
len(frequent_hashtags)
# Out:
# 3311

# %%
sorted(frequent_hashtags.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('earthday', 382),
#  ('internationalwomensday', 343),
#  ('sustainability', 320),
#  ('covid19', 319),
#  ('blackhistorymonth', 306),
#  ('veteransday', 302),
#  ('innovation', 301),
#  ('tbt', 288),
#  ('pridemonth', 285),
#  ('technology', 274),
#  ('hispanicheritagemonth', 271),
#  ('womenshistorymonth', 268),
#  ('diversity', 259),
#  ('icymi', 251),
#  ('leadership', 238),
#  ('pride', 238),
#  ('stem', 238),
#  ('memorialday', 233),
#  ('givingtuesday', 232),
#  ('thanksgiving', 222),
#  ('halloween', 219),
#  ('esg', 216),
#  ('inclusion', 216),
#  ('mlkday', 215),
#  ('valentinesday', 214),
#  ('tech', 212),
#  ('ai', 206),
#  ('iwd2021', 206),
#  ('sustainable', 206),
#  ('dyk', 205),
#  ('juneteenth', 198),
#  ('healthcare', 193),
#  ('podcast', 193),
#  ('data', 185),
#  ('nationalinternday', 183),
#  ('veterans', 183),
#  ('breakthebias', 180),
#  ('csr', 175),
#  ('iwd2022', 172),
#  ('energy', 171),
#  ('dei', 168),
#  ('mothersday', 165),
#  ('climatechange', 164),
#  ('cybersecurity', 164),
#  ('lgbtq', 164),
#  ('ad', 163),
#  ('career', 163),
#  ('coronavirus', 163),
#  ('fathersday', 163),
#  ('education', 162),
#  ('manufacturing', 162),
#  ('thankyou', 162),
#  ('iwd2020', 161),
#  ('community', 159),
#  ('digital', 159),
#  ('laborday', 159),
#  ('happyholidays', 158),
#  ('jobs', 157),
#  ('didyouknow', 156),
#  ('happynewyear', 156),
#  ('choosetochallenge', 154),
#  ('mondaymotivation', 153),
#  ('safety', 152),
#  ('throwbackthursday', 152),
#  ('covid', 151),
#  ('webinar', 151),
#  ('engineering', 150),
#  ('womeninstem', 150),
#  ('health', 149),
#  ('business', 148),
#  ('supplychain', 148),
#  ('environment', 144),
#  ('4thofjuly', 140),
#  ('womenintech', 140),
#  ('iot', 139),
#  ('hiring', 137),
#  ('volunteer', 136),
#  ('digitaltransformation', 135),
#  ('backtoschool', 134),
#  ('careers', 134),
#  ('iwd2019', 132),
#  ('happyhalloween', 131),
#  ('diversityandinclusion', 130),
#  ('stpatricksday', 128),
#  ('worldhealthday', 128),
#  ('machinelearning', 127),
#  ('worldenvironmentday', 127),
#  ('bigdata', 126),
#  ('happythanksgiving', 126),
#  ('blackfriday', 123),
#  ('fourthofjuly', 123),
#  ('womensequalityday', 123),
#  ('holiday', 122),
#  ('independenceday', 122),
#  ('summer', 121),
#  ('cloud', 120),
#  ('automation', 118),
#  ('eachforequal', 117),
#  ('equity', 117),
#  ('pandemic', 116),
#  ('security', 116),
#  ('hr', 115),
#  ('flashbackfriday', 114),
#  ('netzero', 114),
#  ('neverforget', 114),
#  ('renewableenergy', 113),
#  ('sponsored', 113),
#  ('mentalhealth', 112),
#  ('science', 112),
#  ('worldmentalhealthday', 112),
#  ('balanceforbetter', 111),
#  ('culture', 111),
#  ('earnings', 111),
#  ('employeeappreciationday', 110),
#  ('it', 110),
#  ('nyc', 109),
#  ('lunarnewyear', 108),
#  ('artificialintelligence', 107),
#  ('women', 107),
#  ('marketing', 106),
#  ('womeninscience', 106),
#  ('worldwaterday', 106),
#  ('aapiheritagemonth', 105),
#  ('ceo', 105),
#  ('cei2022', 104),
#  ('equality', 103),
#  ('newyear', 103),
#  ('environmental', 102),
#  ('military', 102),
#  ('analytics', 101),
#  ('piday', 101),
#  ('chicago', 99),
#  ('stopasianhate', 99),
#  ('infrastructure', 98),
#  ('cybermonday', 97),
#  ('internship', 97),
#  ('research', 97),
#  ('climate', 96),
#  ('fortune500', 96),
#  ('solar', 96),
#  ('wednesdaywisdom', 96),
#  ('cei2021', 95),
#  ('collaboration', 95),
#  ('givingback', 95),
#  ('innovative', 94),
#  ('news', 94),
#  ('superbowl', 94),
#  ('cleanenergy', 93),
#  ('climateaction', 92),
#  ('partnership', 92),
#  ('texas', 92),
#  ('blockchain', 91),
#  ('design', 91),
#  ('engineers', 91),
#  ('finance', 91),
#  ('vr', 91),
#  ('genderequality', 90),
#  ('giveback', 90),
#  ('construction', 88),
#  ('india', 88),
#  ('water', 88),
#  ('robotics', 87),
#  ('5g', 86),
#  ('ev', 86),
#  ('travel', 86),
#  ('cio', 85),
#  ('iwd', 85),
#  ('worldemojiday', 84),
#  ('interns', 83),
#  ('nationaldogday', 83),
#  ('retail', 83),
#  ('futureofwork', 82),
#  ('nationalvolunteerweek', 82),
#  ('video', 82),
#  ('volunteers', 82),
#  ('electricvehicles', 81),
#  ('veteran', 81),
#  ('cop26', 80),
#  ('energyefficiency', 80),
#  ('happymothersday', 80),
#  ('holidays', 80),
#  ('houston', 80),
#  ('maythe4thbewithyou', 80),
#  ('millennials', 80),
#  ('aapi', 79),
#  ('earthday2021', 79),
#  ('smallbusiness', 79),
#  ('wfh', 79),
#  ('automotive', 78),
#  ('china', 78),
#  ('lgbt', 78),
#  ('newyork', 78),
#  ('safetyfirst', 78),
#  ('breastcancerawarenessmonth', 77),
#  ('happyfathersday', 77),
#  ('liveunited', 77),
#  ('ndeam', 77),
#  ('teamwork', 77),
#  ('ar', 76),
#  ('california', 76),
#  ('just100', 76),
#  ('transportation', 76),
#  ('volunteering', 76),
#  ('future', 75),
#  ('inclusive', 75),
#  ('job', 75),
#  ('disabilityinclusion', 74),
#  ('london', 74),
#  ('thankful', 74),
#  ('wellness', 74),
#  ('cybersecurityawarenessmonth', 73),
#  ('economy', 73),
#  ('efficiency', 73),
#  ('fintech', 73),
#  ('mobile', 73),
#  ('socialmedia', 73),
#  ('cancer', 72),
#  ('mentalhealthawarenessmonth', 72),
#  ('recycling', 72),
#  ('djsi', 71),
#  ('engineer', 71),
#  ('bhm', 70),
#  ('blog', 70),
#  ('fbf', 70),
#  ('iwd2018', 70),
#  ('nationalstemday', 70),
#  ('boston', 69),
#  ('canada', 69),
#  ('earthday2022', 69),
#  ('ecommerce', 69),
#  ('ff', 69),
#  ('fridayfeeling', 69),
#  ('hurricaneharvey', 69),
#  ('mostadmiredcos', 69),
#  ('sxsw', 69),
#  ('virtual', 69),
#  ('atlanta', 68),
#  ('australia', 68),
#  ('compliance', 68),
#  ('sanfrancisco', 68),
#  ('startup', 68),
#  ('emissions', 67),
#  ('christmas', 66),
#  ('diy', 66),
#  ('football', 66),
#  ('software', 66),
#  ('customerexperience', 65),
#  ('startups', 65),
#  ('bloomberggei', 64),
#  ('breastcancer', 64),
#  ('customerservice', 64),
#  ('earthmonth', 64),
#  ('europe', 64),
#  ('food', 64),
#  ('green', 64),
#  ('love', 64),
#  ('networking', 64),
#  ('spring', 64),
#  ('stemeducation', 64),
#  ('usa', 64),
#  ('workforce', 64),
#  ('apahm', 63),
#  ('bestplacetowork', 63),
#  ('florida', 63),
#  ('innovations', 63),
#  ('militaryappreciationmonth', 63),
#  ('mlk', 63),
#  ('nationalpetday', 63),
#  ('realestate', 63),
#  ('singapore', 63),
#  ('thursdaythoughts', 63),
#  ('training', 63),
#  ('diverse', 62),
#  ('nationalcomingoutday', 62),
#  ('power', 62),
#  ('renewable', 62),
#  ('starwarsday', 62),
#  ('uk', 62),
#  ('vaccine', 62),
#  ('3dprinting', 61),
#  ('carbon', 61),
#  ('ceoaction', 61),
#  ('climateweeknyc', 61),
#  ('communities', 61),
#  ('datascience', 61),
#  ('leaders', 61),
#  ('renewables', 61),
#  ('talent', 61),
#  ('us', 61),
#  ('womenleaders', 61),
#  ('workplace', 61),
#  ('becybersmart', 60),
#  ('cincodemayo', 60),
#  ('firstdayofsummer', 60),
#  ('infographic', 60),
#  ('intern', 60),
#  ('investment', 60),
#  ('productivity', 60),
#  ('smallbiz', 60),
#  ('technologies', 60),
#  ('winter', 60),
#  ('diwali', 59),
#  ('drones', 59),
#  ('firstdayoffall', 59),
#  ('growth', 59),
#  ('inthistogether', 59),
#  ('ml', 59),
#  ('sales', 59),
#  ('sandiego', 59),
#  ('students', 59),
#  ('worldcancerday', 59),
#  ('worldfoodday', 59),
#  ('agriculture', 58),
#  ('cx', 58),
#  ('cyber', 58),
#  ('dallas', 58),
#  ('employeeengagement', 58),
#  ('july4th', 58),
#  ('pharma', 58),
#  ('space', 58),
#  ('success', 58),
#  ('award', 57),
#  ('diabetes', 57),
#  ('internships', 57),
#  ('nationalsafetymonth', 57),
#  ('recycle', 57),
#  ('riskmanagement', 57),
#  ('sdgs', 57),
#  ('steam', 57),
#  ('thankfulthursday', 57),
#  ('trends', 57),
#  ('virtualreality', 57),
#  ('breastcancerawareness', 56),
#  ('digitalhealth', 56),
#  ('financial', 56),
#  ('innovate', 56),
#  ('logistics', 56),
#  ('nonprofit', 56),
#  ('resilience', 56),
#  ('strategy', 56),
#  ('wellbeing', 56),
#  ('womeninbusiness', 56),
#  ('conservation', 55),
#  ('happyvalentinesday', 55),
#  ('lifesciences', 55),
#  ('mostadmired', 55),
#  ('ppe', 55),
#  ('dayofthegirl', 54),
#  ('development', 54),
#  ('fall', 54),
#  ('industrial', 54),
#  ('investinourplanet', 54),
#  ('motivationmonday', 54),
#  ('nationalcoffeeday', 54),
#  ('nowhiring', 54),
#  ('nyse', 54),
#  ('strongertogether', 54),
#  ('100bestcc', 53),
#  ('awards', 53),
#  ('bettertogether', 53),
#  ('earthday2020', 53),
#  ('engineersweek', 53),
#  ('family', 53),
#  ('global', 53),
#  ('grateful', 53),
#  ('hurricaneian', 53),
#  ('insurance', 53),
#  ('marchmadness', 53),
#  ('parisagreement', 53),
#  ('pride2021', 53),
#  ('retirement', 53),
#  ('sweepstakes', 53),
#  ('augmentedreality', 52),
#  ('cei2020', 52),
#  ('entrepreneurs', 52),
#  ('evs', 52),
#  ('free', 52),
#  ('hbcu', 52),
#  ('remotework', 52),
#  ('womeninengineering', 52),
#  ('americarecyclesday', 51),
#  ('americasmostjust', 51),
#  ('contest', 51),
#  ('dataanalytics', 51),
#  ('dc', 51),
#  ('electricvehicle', 51),
#  ('socialdistancing', 51),
#  ('throwback', 51),
#  ('art', 50),
#  ('behindthescenes', 50),
#  ('brazil', 50),
#  ('charity', 50),
#  ('circulareconomy', 50),
#  ('genz', 50),
#  ('girlsinstem', 50),
#  ('iiot', 50),
#  ('japan', 50),
#  ('losangeles', 50),
#  ('medical', 50),
#  ('nationalengineersweek', 50),
#  ('oil', 50),
#  ('philanthropy', 50),
#  ('pressforprogress', 50),
#  ('risk', 50),
#  ('socialimpact', 50),
#  ('telehealth', 50),
#  ('vaccines', 50),
#  ('3d', 49),
#  ('arborday', 49),
#  ('biotech', 49),
#  ('holidayseason', 49),
#  ('industry', 49),
#  ('internetofthings', 49),
#  ('lasvegas', 49),
#  ('live', 49),
#  ('mentorship', 49),
#  ('ohio', 49),
#  ('oilandgas', 49),
#  ('ransomware', 49),
#  ('service', 49),
#  ('teacherappreciationweek', 49),
#  ('win', 49),
#  ('worldoceansday', 49),
#  ('climateweek', 48),
#  ('cryptocurrency', 48),
#  ('drone', 48),
#  ('germany', 48),
#  ('hackathon', 48),
#  ('healthcareheroes', 48),
#  ('inflation', 48),
#  ('inspiration', 48),
#  ('leed', 48),
#  ('nationalselfieday', 48),
#  ('nfl', 48),
#  ('privacy', 48),
#  ('seattle', 48),
#  ('transformation', 48),
#  ('workfromhome', 48),
#  ('aapihm', 47),
#  ('aerospace', 47),
#  ('agile', 47),
#  ('corporateresponsibility', 47),
#  ('denver', 47),
#  ('financialservices', 47),
#  ('giveaway', 47),
#  ('hurricane', 47),
#  ('investing', 47),
#  ('mentoring', 47),
#  ('miami', 47),
#  ('naturalgas', 47),
#  ('recruiting', 47),
#  ('smallbusinessweek', 47),
#  ('smartcities', 47),
#  ('vote', 47),
#  ('wearredday', 47),
#  ('womeninleadership', 47),
#  ('work', 47),
#  ('worldseries', 47),
#  ('acquisition', 46),
#  ('cei2019', 46),
#  ('ces2020', 46),
#  ('chinesenewyear', 46),
#  ('cyberattacks', 46),
#  ('givingtuesdaynow', 46),
#  ('harvey', 46),
#  ('hurricaneflorence', 46),
#  ('investors', 46),
#  ('metaverse', 46),
#  ('mexico', 46),
#  ('presidentsday', 46),
#  ('publichealth', 46),
#  ('robots', 46),
#  ('smallbusinesssaturday', 46),
#  ('smarthome', 46),
#  ('banking', 45),
#  ('communications', 45),
#  ('congratulations', 45),
#  ('ditop50', 45),
#  ('earthweek', 45),
#  ('employees', 45),
#  ('golf', 45),
#  ('merrychristmas', 45),
#  ('nationaldoctorsday', 45),
#  ('nationalpuppyday', 45),
#  ('openingday', 45),
#  ('pride2020', 45),
#  ('tgif', 45),
#  ('aviation', 44),
#  ('cloudcomputing', 44),
#  ('connectivity', 44),
#  ('firstdayofspring', 44),
#  ('gaming', 44),
#  ('gas', 44),
#  ('goals', 44),
#  ('gratitude', 44),
#  ('history', 44),
#  ('humanresources', 44),
#  ('hurricanedorian', 44),
#  ('interview', 44),
#  ('newyearsresolution', 44),
#  ('quality', 44),
#  ('starwars', 44),
#  ('stemday', 44),
#  ('worldsmostethicalcompanies', 44),
#  ('worldteachersday', 44),
#  ('autonomous', 43),
#  ('aws', 43),
#  ('datacenter', 43),
#  ('digitalization', 43),
#  ('equalityact', 43),
#  ('gogreen', 43),
#  ('gptwcertified', 43),
#  ('healthtech', 43),
#  ('hurricaneida', 43),
#  ('impact', 43),
#  ('mobility', 43),
#  ('semiconductor', 43),
#  ('solutions', 43),
#  ('staysafe', 43),
#  ('asia', 42),
#  ('autonomousvehicles', 42),
#  ('brand', 42),
#  ('decarbonization', 42),
#  ('funfact', 42),
#  ('groundhogday', 42),
#  ('home', 42),
#  ('hungeractionmonth', 42),
#  ('internationalpodcastday', 42),
#  ('nascar', 42),
#  ('newyearseve', 42),
#  ('packaging', 42),
#  ('paris', 42),
#  ('utilities', 42),
#  ('ux', 42),
#  ('weekend', 42),
#  ('whitepaper', 42),
#  ('worldkindnessday', 42),
#  ('america', 41),
#  ('auto', 41),
#  ('benefits', 41),
#  ('conference', 41),
#  ('dubai', 41),
#  ('ethics', 41),
#  ('fcmostinnovative', 41),
#  ('funfactfriday', 41),
#  ('habitatforhumanity', 41),
#  ('hybrid', 41),
#  ('learning', 41),
#  ('nationalvolunteermonth', 41),
#  ('nativeamericanheritagemonth', 41),
#  ('opensource', 41),
#  ('orlando', 41),
#  ('oscars', 41),
#  ('puertorico', 41),
#  ('solarenergy', 41),
#  ('solarpower', 41),
#  ('sports', 41),
#  ('supplychains', 41),
#  ('tips', 41),
#  ('ukraine', 41),
#  ('womensday', 41),
#  ('architecture', 40),
#  ('bestworkplaces', 40),
#  ('college', 40),
#  ('dataprivacyday', 40),
#  ('disability', 40),
#  ('electricity', 40),
#  ('entrepreneur', 40),
#  ('france', 40),
#  ('globalgoals', 40),
#  ('governance', 40),
#  ('greatplacetowork', 40),
#  ('management', 40),
#  ('nationalnursesday', 40),
#  ('redcross', 40),
#  ('sponsor', 40),
#  ('storage', 40),
#  ('trade', 40),
#  ('whm', 40),
#  ('app', 39),
#  ('areyouin', 39),
#  ('battery', 39),
#  ('changetheworld', 39),
#  ('co2', 39),
#  ('datacenters', 39),
#  ('donate', 39),
#  ('easter', 39),
#  ('electionday', 39),
#  ('electric', 39),
#  ('energytransition', 39),
#  ('instagram', 39),
#  ('manufacturers', 39),
#  ('manufacturingday', 39),
#  ('medtech', 39),
#  ('nationaldonutday', 39),
#  ('partner', 39),
#  ('scholarship', 39),
#  ('sciencebasedtargets', 39),
#  ('tax', 39),
#  ('tiptuesday', 39),
#  ('worldcup', 39),
#  ('biodiversity', 38),
#  ('biopharma', 38),
#  ('carbonfootprint', 38),
#  ('crypto', 38),
#  ('energyefficient', 38),
#  ('equalpayday', 38),
#  ('eu', 38),
#  ('friday', 38),
#  ('ghg', 38),
#  ('heartmonth', 38),
#  ('hurricanemichael', 38),
#  ('nonprofits', 38),
#  ('onthisday', 38),
#  ('performance', 38),
#  ('philadelphia', 38),
#  ('resolutions', 38),
#  ('retailers', 38),
#  ('scholarships', 38),
#  ('smallbusinesses', 38),
#  ('smartcity', 38),
#  ('teachers', 38),
#  ('transparency', 38),
#  ('vegas', 38),
#  ('austin', 37),
#  ('breaking', 37),
#  ('brexit', 37),
#  ('cfo', 37),
#  ('coffee', 37),
#  ('covid_19', 37),
#  ('dataprivacy', 37),
#  ('economic', 37),
#  ('edge', 37),
#  ('facebook', 37),
#  ('healthy', 37),
#  ('internet', 37),
#  ('nextgen', 37),
#  ('operations', 37),
#  ('socialmediaday', 37),
#  ('vacation', 37),
#  ('wildfires', 37),
#  ('winning', 37),
#  ('bts', 36),
#  ('careerfair', 36),
#  ('ces', 36),
#  ('ciso', 36),
#  ('colorado', 36),
#  ('communication', 36),
#  ('cyberattack', 36),
#  ('cybercrime', 36),
#  ('goredforwomen', 36),
#  ('happybirthday', 36),
#  ('investor', 36),
#  ('medicine', 36),
#  ('mentalhealthawareness', 36),
#  ('mfg', 36),
#  ('nasa', 36),
#  ('nashville', 36),
#  ('network', 36),
#  ('newjersey', 36),
#  ('nye', 36),
#  ('pharmaceutical', 36),
#  ('pressrelease', 36),
#  ('pride2022', 36),
#  ('reinvent', 36),
#  ('sensors', 36),
#  ('stayhome', 36),
#  ('techtuesday', 36),
#  ('telemedicine', 36),
#  ('worklifebalance', 36),
#  ('yearofthetiger', 36),
#  ('africa', 35),
#  ('ces2019', 35),
#  ('daylightsavingtime', 35),
#  ('genderparity', 35),
#  ('giving', 35),
#  ('industry40', 35),
#  ('ireland', 35),
#  ('iwd2017', 35),
#  ('loveislove', 35),
#  ('nj', 35),
#  ('olympics', 35),
#  ('savings', 35),
#  ('school', 35),
#  ('scientists', 35),
#  ('shipping', 35),
#  ('smart', 35),
#  ('tuesdaythoughts', 35),
#  ('wireless', 35),
#  ('americanheartmonth', 34),
#  ('ces2022', 34),
#  ('cyberaware', 34),
#  ('devops', 34),
#  ('edgecomputing', 34),
#  ('endhunger', 34),
#  ('engagement', 34),
#  ('fda', 34),
#  ('flagday', 34),
#  ('florence', 34),
#  ('flu', 34),
#  ('foodsafety', 34),
#  ('hbcus', 34),
#  ('microsoft', 34),
#  ('natgas', 34),
#  ('nationalicecreamday', 34),
#  ('oncology', 34),
#  ('periscope', 34),
#  ('plastic', 34),
#  ('proud', 34),
#  ('recruitment', 34),
#  ('santa', 34),
#  ('shopping', 34),
#  ('trust', 34),
#  ('wearables', 34),
#  ('wifi', 34),
#  ('wind', 34),
#  ('biggame', 33),
#  ('charlotte', 33),
#  ('chemistry', 33),
#  ('corpgov', 33),
#  ('customers', 33),
#  ('daylightsavings', 33),
#  ('detroit', 33),
#  ('edtech', 33),
#  ('electrification', 33),
#  ('entrepreneurship', 33),
#  ('firstresponders', 33),
#  ('georgia', 33),
#  ('hongkong', 33),
#  ('hospitality', 33),
#  ('innovators', 33),
#  ('inwed22', 33),
#  ('la', 33),
#  ('mining', 33),
#  ('nationalnursesweek', 33),
#  ('opportunity', 33),
#  ('safe', 33),
#  ('selfie', 33),
#  ('siliconvalley', 33),
#  ('supplierdiversity', 33),
#  ('toronto', 33),
#  ('utility', 33),
#  ('worlddiabetesday', 33),
#  ('apollo50th', 32),
#  ('aprilfools', 32),
#  ('arizona', 32),
#  ('atl', 32),
#  ('autism', 32),
#  ('b2b', 32),
#  ('banks', 32),
#  ('beboldforchange', 32),
#  ('carbonneutral', 32),
#  ('careerdevelopment', 32),
#  ('cei2018', 32),
#  ('companyculture', 32),
#  ('congrats', 32),
#  ('consumer', 32),
#  ('datamanagement', 32),
#  ('deeplearning', 32),
#  ('disruption', 32),
#  ('enterprise', 32),
#  ('feelgoodfriday', 32),
#  ('government', 32),
#  ('humanrightsday', 32),
#  ('internationalnursesday', 32),
#  ('interoperability', 32),
#  ('investments', 32),
#  ('michigan', 32),
#  ('nature', 32),
#  ('nutrition', 32),
#  ('partners', 32),
#  ('partnerships', 32),
#  ('phishing', 32),
#  ('policy', 32),
#  ('robot', 32),
#  ('social', 32),
#  ('stopaapihate', 32),
#  ('triviatuesday', 32),
#  ('worldaidsday', 32),
#  ('apac', 31),
#  ('armedforcesday', 31),
#  ('assetmanagement', 31),
#  ('cto', 31),
#  ('energystorage', 31),
#  ('fashion', 31),
#  ('flattenthecurve', 31),
#  ('foodwaste', 31),
#  ('fun', 31),
#  ('infosec', 31),
#  ('insights', 31),
#  ('internationalcatday', 31),
#  ('internationaldogday', 31),
#  ('leader', 31),
#  ('memorialdayweekend', 31),
#  ('money', 31),
#  ('newyearsresolutions', 31),
#  ('otd', 31),
#  ('purpose', 31),
#  ('remote', 31),
#  ('saas', 31),
#  ('semiconductors', 31),
#  ('skills', 31),
#  ('takeyourchildtoworkday', 31),
#  ('transdayofvisibility', 31),
#  ('washingtondc', 31),
#  ('weather', 31),
#  ('windpower', 31),
#  ('baltimore', 30),
#  ('bestplacestowork', 30),
#  ('bitcoin', 30),
#  ('blacklivesmatter', 30),
#  ('car', 30),
#  ('careeradvice', 30),
#  ('celebrate', 30),
#  ('chro', 30),
#  ('cio100', 30),
#  ('cmo', 30),
#  ('cre', 30),
#  ('customer', 30),
#  ('customerserviceweek', 30),
#  ('davos', 30),
#  ('dayofcaring', 30),
#  ('digitization', 30),
#  ('electronics', 30),
#  ('employee', 30),
#  ('entertainment', 30),
#  ('event', 30),
#  ('fcbestworkplaces', 30),
#  ('financialliteracy', 30),
#  ('foodsecurity', 30),
#  ('girlpower', 30),
#  ('hearthealth', 30),
#  ('hiv', 30),
#  ('hurricaneseason', 30),
#  ('inwed21', 30),
#  ('italy', 30),
#  ('labordayweekend', 30),
#  ('lgbtqia', 30),
#  ('lifescience', 30),
#  ('markets', 30),
#  ('maythe4th', 30),
#  ('media', 30),
#  ('medicaldevices', 30),
#  ('mentalhealthmonth', 30),
#  ('mentor', 30),
#  ('music', 30),
#  ('new', 30),
#  ('patients', 30),
#  ('payments', 30),
#  ('regulatory', 30),
#  ('solareclipse2017', 30),
#  ('springcleaning', 30),
#  ('summersolstice', 30),
#  ('support', 30),
#  ('taxes', 30),
#  ('traveltuesday', 30),
#  ('wintersolstice', 30),
#  ('yearoftheox', 30),
#  ('baseball', 29),
#  ('clinicaltrials', 29),
#  ('datasecurity', 29),
#  ('digitalmarketing', 29),
#  ('events', 29),
#  ('experience', 29),
#  ('fireworks', 29),
#  ('fitness', 29),
#  ('hanukkah', 29),
#  ('hawaii', 29),
#  ('healthequity', 29),
#  ('hydrogen', 29),
#  ('internationaldayofthegirl', 29),
#  ('lng', 29),
#  ('louisiana', 29),
#  ('millennial', 29),
#  ('movember', 29),
#  ('nursesweek', 29),
#  ('plastics', 29),
#  ('recipe', 29),
#  ('risks', 29),
#  ('roi', 29),
#  ('shopsmall', 29),
#  ('socialresponsibility', 29),
#  ('spain', 29),
#  ('stress', 29),
#  ('thankateacher', 29),
#  ('turkey', 29),
#  ('unga', 29),
#  ('wef19', 29),
#  ('wellnesswednesday', 29),
#  ('apple', 28),
#  ('azure', 28),
#  ('ces2021', 28),
#  ('climatecrisis', 28),
#  ('cyberthreats', 28),
#  ('defense', 28),
#  ('fcworldchangingideas', 28),
#  ('funding', 28),
#  ('genderequity', 28),
#  ('google', 28),
#  ('hurricanelaura', 28),
#  ('internationalvolunteerday', 28),
#  ('mfgday22', 28),
#  ('nationalbestfriendsday', 28),
#  ('nobelprize', 28),
#  ('omicron', 28),
#  ('patient', 28),
#  ('phoenix', 28),
#  ('procurement', 28),
#  ('resiliency', 28),
#  ('roadtrip', 28),
#  ('sanantonio', 28),
#  ('selfcare', 28),
#  ('smartphone', 28),
#  ('snow', 28),
#  ('stemcareers', 28),
#  ('tampa', 28),
#  ('taxday', 28),
#  ('thanks', 28),
#  ('trickortreat', 28),
#  ('unitedway', 28),
#  ('waste', 28),
#  ('wine', 28),
#  ('annualreport', 27),
#  ('api', 27),
#  ('apollo11', 27),
#  ('call811', 27),
#  ('cdpalist', 27),
#  ('cdpsupplychain', 27),
#  ('ceraweek', 27),
#  ('ces2018', 27),
#  ('cheddarlive', 27),
#  ('clean', 27),
#  ('coding', 27),
#  ('cybersecuritymonth', 27),
#  ('developer', 27),
#  ('dna', 27),
#  ('earthday2019', 27),
#  ('esports', 27),
#  ('fighthunger', 27),
#  ('finserv', 27),
#  ('firepreventionweek', 27),
#  ('fraud', 27),
#  ('globaldiversityawarenessmonth', 27),
#  ('globalhealth', 27),
#  ('gored', 27),
#  ('housing', 27),
#  ('howto', 27),
#  ('hvac', 27),
#  ('interestrates', 27),
#  ('ip', 27),
#  ('linkedintopcompanies', 27),
#  ('maythefourthbewithyou', 27),
#  ('mfgday19', 27),
#  ('nationalbeerday', 27),
#  ('nationalpizzaday', 27),
#  ('nurses', 27),
#  ('pride2019', 27),
#  ('restoreourearth', 27),
#  ('rewritetomorrow', 27),
#  ('stocks', 27),
#  ('sundayfunday', 27),
#  ('sustainably', 27),
#  ('values', 27),
#  ('washington', 27),
#  ('webinars', 27),
#  ('wef22', 27),
#  ('wildfire', 27),
#  ('wm100best', 27),
#  ('womeninenergy', 27),
#  ('workplacesafety', 27),
#  ('worldsmileday', 27),
#  ('811day', 26),
#  ('alzheimers', 26),
#  ('canadaday', 26),
#  ('commercial', 26),
#  ('connected', 26),
#  ('consumers', 26),
#  ('cop27', 26),
#  ('davosagenda', 26),
#  ('dei22', 26),
#  ('developers', 26),
#  ('distribution', 26),
#  ('dividend', 26),
#  ('dogs', 26),
#  ('ecofriendly', 26),
#  ('energystar', 26),
#  ('eweek2020', 26),
#  ('eweek2022', 26),
#  ('f1', 26),
#  ('financialliteracymonth', 26),
#  ('fire', 26),
#  ('fridaythe13th', 26),
#  ('gameday', 26),
#  ('healthit', 26),
#  ('hpc', 26),
#  ('hunger', 26),
#  ('hybridcloud', 26),
#  ('hybridwork', 26),
#  ('internationalcoffeeday', 26),
#  ('irma', 26),
#  ...]
