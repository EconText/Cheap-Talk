# %% [markdown]
# # Twitter Profile Info

# %% [markdown]
# Gets Twitter profile information (`created_at`, `location`, etc.) for the Twitter handles listed in a CSV.

# %%
# Set path to the outer directory folder so we can access Twitter API keys in twitter_api_xanda.py
import sys
sys.path.append('..')

# %%
import pandas as pd
import tweepy
from twitter_api_xanda import TWITTER_API_BEARER

# %% [markdown]
# Get the Mergr company Twitter handles from `mergr_twitter_subsidiaries_manual.csv`.

# %%
twitter_handle_df = pd.read_csv('../handle_scraping/mergr_twitter_subsidiaries_manual.csv')
twitter_handle_df
# Out:
#     Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0                          Name  \
# 0             49            81         240                         AECOM
# 1             20            43         142                       AerSale
# 2              9            24          87             Arrow Electronics
# 3             23            46         148                    AutoNation
# 4             34            61         182                         Avnet
# 5             46            78         231                         Berry
# 6             36            64         192                          BJ's
# 7              3            13          52                         Bunge
# 8             38            66         197       C.H. Robinson Worldwide
# 9             52            84         245                       Carvana
# 10             8            23          80                     Coca-Cola
# 11             1             8          26                          Dell
# 12             2            12          44               Energy Transfer
# 13             7            22          79  Enterprise Products Partners
# 14             0             7          24                      Facebook
# 15            40            69         208   Fidelity National Financial
# 16            51            83         244                           Fox
# 17            47            79         234                           GAP
# 18            31            57         170                   HF Sinclair
# 19            43            73         219                           ITW
# 20            10            28          98                         Jabil
# 21            26            50         159                           JLL
# 22            25            49         158                       Kohl's
# 23            29            55         166                       Kyndryl
# 24            32            58         175                        Landos
# 25            27            51         161                          Lear
# 26            19            41         134                 Lithia Motors
# 27            48            80         235                         Loews
# 28            13            34         116                        Macy's
# 29            21            44         144                 ManpowerGroup
# 30            50            82         243                        Markel
# 31            41            70         213                     Nordstrom
# 32            11            32         111                           NRG
# 33            28            54         165                        PACCAR
# 34            22            45         146                        Penske
# 35            14            35         119                           PFG
# 36            30            56         169                          PG&E
# 37            17            39         128           Plains All American
# 38            44            75         222                 Qurate Retail
# 39            42            72         217                           RGA
# 40            16            38         123                      Rite Aid
# 41            39            68         203              Rocket Companies
# 42            39            68         203              Rocket Companies
# 43             4            14          59                        StoneX
# 44            35            63         188                       Stryker
# 45            15            36         121                     TD SYNNEX
# 46            33            60         181                  Tenet Health
# 47             6            21          78                           TJX
# 48             5            19          73                         Tyson
# 49            12            33         113                          UNFI
# 50            18            40         132                      US Foods
# 51            45            76         224                       Wayfair
# 52            24            47         150           World Fuel Services
# 53            37            65         196                           XPO
#
#                             Sector  \
# 0                Business Services
# 1                        Aerospace
# 2                     Distribution
# 3                       Automotive
# 4                     Distribution
# 5                         Plastics
# 6                           Retail
# 7                      Agriculture
# 8                   Transportation
# 9                       E-Commerce
# 10                       Beverages
# 11             Technology Hardware
# 12   Energy Services and Equipment
# 13             Oil/Gas Exploration
# 14  Internet Software and Services
# 15                       Insurance
# 16                           Media
# 17                Apparel/Textiles
# 18             Oil/Gas Exploration
# 19                   Manufacturing
# 20                   Manufacturing
# 21                     Real Estate
# 22                          Retail
# 23          Information Technology
# 24                    Life Science
# 25                      Automotive
# 26                      Automotive
# 27                     Diversified
# 28                          Retail
# 29                        Staffing
# 30                       Insurance
# 31                          Retail
# 32                       Utilities
# 33                      Automotive
# 20                                                NaN                    7.0
# 21                                                NaN                   29.0
# 22                                                NaN                    NaN
# 23                                                NaN                    NaN
# 24                                                NaN                    NaN
# 25                                                NaN                   21.0
# 26                                                NaN                   20.0
# 27                                                NaN                    1.0
# 28                                                NaN                    4.0
# 29                                                NaN                   14.0
# 30                                  Alliance Holdings                   13.0
# 31                                                NaN                    7.0
# 32                                                NaN                   15.0
# 33                                                NaN                    2.0
# 34                                                NaN                   23.0
# 35                                                NaN                    6.0
# 36                                                NaN                    NaN
# 37  Kayne Anderson Capital Advisors LP|First Reser...                    7.0
# 38                                                NaN                    1.0
# 39                                                NaN                    4.0
# 40                                                NaN                   12.0
# 41                                                NaN                    1.0
# 42                                                NaN                    1.0
# 43                                                NaN                   17.0
# 44                                                NaN                   43.0
# 45                           Apollo Global Management                   15.0
# 46                                                NaN                    6.0
# 47                                                NaN                    5.0
# 48                                                NaN                   13.0
# 49                                                NaN                    8.0
# 50                                     KKR & Co. L.P.                   23.0
# 51                                                NaN                    3.0
# 52                                                NaN                   16.0
# 53                                                NaN                   17.0
#
#    Avg. Buy Count Per Year (Last 5 Yrs) Sell M&A Count - Total  \
# 0                                   0.2                    5.0
# 1                                   0.4                    NaN
# 2                                   0.2                    1.0
# 3                                   0.2                    1.0
# 4                                   0.4                    6.0
# 5                                   0.4                    2.0
# 6                                   NaN                    NaN
# 7                                   NaN                    4.0
# 8                                   0.8                    1.0
# 9                                   0.4                    NaN
# 10                                  0.4                    8.0
# 11                                  NaN                    7.0
# 12                                  0.6                    1.0
# 13                                  0.4                    5.0
# 14                                  3.2                    NaN
# 15                                  1.0                    8.0
# 16                                  0.8                    NaN
# 17                                  0.6                    4.0
# 18                                  0.6                    2.0
# 19                                  0.2                   13.0
# 20                                  0.2                    NaN
# 21                                  1.8                    NaN
# 22                                  NaN                    NaN
# 23                                  NaN                    NaN
# 24                                  NaN                    NaN
# 25                                  1.0                    1.0
# 26                                  1.6                    NaN
# 27                                  NaN                    1.0
# 28                                  0.2                    2.0
# 29                                  0.2                    NaN
# 30                                  1.0                    NaN
# 31                                  0.4                    5.0
# 32                                  0.2                    6.0
# 33                                  NaN                    NaN
# 34                                  0.8                    NaN
# 35                                  0.6                    1.0
# 36                                  NaN                    NaN
# 37                                  0.2                    2.0
# 38                                  NaN                    NaN
# 39                                  0.2                    1.0
# 40                                  0.4                    1.0
# 41                                  0.2                    NaN
# 42                                  0.2                    NaN
# 43                                  2.4                    NaN
# 44                                  2.2                    5.0
# 45                                  0.4                    NaN
# 46                                  0.2                   10.0
# 47                                  0.2                    1.0
# 48                                  0.6                    6.0
# 49                                  0.2                    NaN
# 50                                  0.4                    NaN
# 51                                  NaN                    1.0
# 52                                  0.4                    1.0
# 53                                  0.2                    2.0
#
#     Avg. Sell Count Per Year (Last 5 Yrs)  \
# 0                                     0.8
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     0.2
# 5                                     0.4
# 6                                     NaN
# 7                                     0.2
# 8                                     NaN
# 9                                     NaN
# 10                                    0.6
# 11                                    0.2
# 12                                    NaN
# 13                                    0.2
# 14                                    NaN
# 15                                    0.6
# 16                                    NaN
# 17                                    0.6
# 18                                    NaN
# 19                                    0.6
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 26                                    NaN
# 27                                    0.2
# 28                                    NaN
# 29                                    NaN
# 30                                    NaN
# 31                                    NaN
# 32                                    0.4
# 33                                    NaN
# 34                                    NaN
# 35                                    NaN
# 36                                    NaN
# 37                                    0.4
# 38                                    NaN
# 39                                    0.2
# 40                                    NaN
# 41                                    NaN
# 42                                    NaN
# 43                                    NaN
# 44                                    0.6
# 45                                    NaN
# 46                                    0.4
# 47                                    NaN
# 48                                    0.6
# 49                                    NaN
# 50                                    NaN
# 51                                    0.2
# 52                                    0.2
# 53                                    0.2
#
#                                 Twitter URL   Twitter Handle  Subsidiary
# 0                 https://twitter.com/AECOM            AECOM       False
# 1               https://twitter.com/aersale          aersale       False
# 2         https://twitter.com/Arrow_dot_com    Arrow_dot_com       False
# 3            https://twitter.com/AutoNation       AutoNation       False
# 4                 https://twitter.com/avnet            avnet       False
# 5        https://twitter.com/berryglobalinc   berryglobalinc       False
# 6          https://twitter.com/BJsWholesale     BJsWholesale       False
# 7                 https://twitter.com/bunge            bunge       False
# 8            https://twitter.com/CHRobinson       CHRobinson       False
# 9               https://twitter.com/carvana          carvana       False
# 10             https://twitter.com/CocaCola         CocaCola       False
# 11             https://twitter.com/delltech         delltech       False
# 12       https://twitter.com/EnergyTransfer   EnergyTransfer       False
# 13                                      NaN              NaN       False
# 14             https://twitter.com/facebook         facebook       False
# 15           https://twitter.com/FidelityNF       FidelityNF       False
# 16                                      NaN              NaN       False
# 17               https://twitter.com/GapInc           GapInc       False
# 18                                      NaN              NaN       False
# 19                                      NaN              NaN       False
# 20                https://twitter.com/Jabil            Jabil       False
# 21                  https://twitter.com/JLL              JLL       False
# 22                https://twitter.com/kohls            kohls       False
# 23              https://twitter.com/kyndryl          kyndryl       False
# 24            https://twitter.com/landosbio        landosbio       False
# 25      https://twitter.com/LearCorporation  LearCorporation       False
# 26     https://www.twitter.com/lithiamotors     lithiamotors       False
# 27                                      NaN              NaN       False
# 28            https://twitter.com/macysnews        macysnews       False
# 29        https://twitter.com/ManpowerGroup    ManpowerGroup       False
# 30          https://twitter.com/MarkelStyle      MarkelStyle       False
# 31            https://twitter.com/nordstrom        nordstrom       False
# 32              https://twitter.com/picknrg          picknrg       False
# 33                                      NaN              NaN       False
# 34           https://twitter.com/penskecars       penskecars       False
# 35                                      NaN              NaN       False
# 36               https://twitter.com/pge4me           pge4me       False
# 37                                      NaN              NaN       False
# 38      https://twitter.com/qurateretailgrp  qurateretailgrp       False
# 39               https://twitter.com/RGA_RE           RGA_RE       False
# 40           http://www.twitter.com/RiteAid          RiteAid       False
# 41  https://www.twitter.com/rocketcompanies  rocketcompanies       False
# 42  https://www.twitter.com/rocketpressroom  rocketpressroom        True
# 43      https://twitter.com/StoneX_Official  StoneX_Official       False
# 44          https://twitter.com/strykercomm      strykercomm       False
# 45               https://twitter.com/SYNNEX           SYNNEX       False
# 46          https://twitter.com/tenethealth      tenethealth       False
# 47               https://twitter.com/tjmaxx           tjmaxx       False
# 48           https://twitter.com/TysonFoods       TysonFoods       False
# 49                 https://twitter.com/UNFI             UNFI       False
# 50              https://twitter.com/usfoods          usfoods       False
# 51              https://twitter.com/Wayfair          Wayfair       False
# 52           https://twitter.com/world_fuel       world_fuel       False
# 53         https://twitter.com/XPOLogistics     XPOLogistics       False
#
# [54 rows x 23 columns]

# %%
twitter_handles = list(twitter_handle_df['Twitter Handle'].dropna())  # Drop nulls (some companies don't have Twitters)
# print(twitter_handles)

# %% [markdown]
# Functions for parsing the `entities` field of a Twitter user object:

# %%
def parse_entity_url(user_obj):
    if not user_obj.entities or 'url' not in user_obj.entities:
        return None
        
    expanded_urls = []
    for url in user_obj.entities['url']['urls']:
        expanded_urls.append(url['expanded_url'])
    
    if len(expanded_urls) > 1:
        print("Saw a Twitter user with more than 1 URL")
        
    return expanded_urls[0] # Just return the first URL. None of the Twitter accounts have multiple URLs on their profiles.

def parse_entity_cashtags(user_obj):
    if not user_obj.entities or 'description' not in user_obj.entities or 'cashtags' not in user_obj.entities['description']:
        return None
        
    cashtags = []
    for cashtag in user_obj.entities['description']['cashtags']:
        cashtags.append(cashtag['tag'])
            
    return cashtags

def parse_entity_hashtags(user_obj):
    if not user_obj.entities or 'description' not in user_obj.entities or 'hashtags' not in user_obj.entities['description']:
        return None
        
    hashtags = []
    for hashtag in user_obj.entities['description']['hashtags']:
        hashtags.append(hashtag['tag'])
            
    return hashtags

def parse_entity_mentions(user_obj):
    if not user_obj.entities or 'description' not in user_obj.entities or 'mentions' not in user_obj.entities['description']:
        return None
        
    mentions = []
    for mention in user_obj.entities['description']['mentions']:
        mentions.append(mention['username'])
            
    return mentions

# %% [markdown]
# Let's get Twitter profile info for the company Twitter handles in our CSV!

# %%
client = tweepy.Client(bearer_token=TWITTER_API_BEARER)

USER_FIELDS = ['created_at', 'description', 'entities', 'id', 'location', 'name', 'pinned_tweet_id', 'profile_image_url', 'protected', 'public_metrics', 'url', 'username', 'verified', 'withheld']

# Get Twitter user objects for all the Twitter handles in our CSV
user_objs = []
for i in range(0, len(twitter_handles), 100): # need for loop since get_users can only get up to 100 users at a time
    user_objs += client.get_users(usernames=twitter_handles[i:i+100], user_fields=USER_FIELDS).data

# Use the Twitter user objects to create a list of lists, where each inner list corresponds to the Twitter profile info for one user
users = []
for obj in user_objs:
    users.append([obj.id, obj.name, obj.username, obj.created_at, obj.location, obj.description, parse_entity_url(obj), obj.pinned_tweet_id, obj.profile_image_url, obj.protected, obj.public_metrics['followers_count'], obj.public_metrics['following_count'], obj.public_metrics['tweet_count'], obj.public_metrics['listed_count'], obj.verified, obj.withheld, parse_entity_cashtags(obj), parse_entity_hashtags(obj), parse_entity_mentions(obj)])

# %%
# Create pandas DataFrame from users (the list of lists)
user_info_df = pd.DataFrame(users, columns=['id', 'name', 'username', 'created_at', 'location', 'description', 'url', 'pinned_tweet_id', 'profile_image_url', 'protected', 'followers_count', 'following_count', 'tweet_count', 'listed_count', 'verified', 'withheld', 'cashtags', 'hashtags', 'mentions'])

# Save Twitter profile info dataframe as a CSV!
user_info_df.to_csv('mergr_twitter_profile_info.csv')
